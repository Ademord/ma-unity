# %%
try:
    import mlagents
    from mlagents_envs.environment import UnityEnvironment as UE
    from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
    print("ml-agents already installed")
except ImportError:
#     !pip install mlagents==0.26.0
    print("Installed ml-agents")
# Out:
# ml-agents already installed

# %%
import torch
from typing import Tuple
from math import floor


class VisualQNetwork(torch.nn.Module):
  def __init__(
    self,
    input_shape: Tuple[int], 
    encoding_size: int, 
    output_size: int
  ):
    """
    Creates a neural network that takes as input a batch of images (3
    dimensional tensors) and outputs a batch of outputs (1 dimensional
    tensors)
    """
    super(VisualQNetwork, self).__init__()
#     height = input_shape[0]
#     width = input_shape[1]
#     initial_channels = input_shape[2]
#     conv_1_hw = self.conv_output_shape((height, width), 8, 4)
#     conv_2_hw = self.conv_output_shape(conv_1_hw, 4, 2)
#     self.final_flat = conv_2_hw[0] * conv_2_hw[1] * 32
    
    
#     self.conv1 = torch.nn.Conv2d(initial_channels, 16, [8, 8], [4, 4])
#     self.conv2 = torch.nn.Conv2d(16, 32, [4, 4], [2, 2])
#     self.dense1 = torch.nn.Linear(self.final_flat, encoding_size)

    
    self.dense1 = torch.nn.Linear(input_shape[0], encoding_size)
    self.dense2 = torch.nn.Linear(encoding_size, encoding_size)
    
    self.dense2_x1 = torch.nn.Linear(encoding_size, output_size)
    self.dense2_x2 = torch.nn.Linear(encoding_size, output_size)
    self.dense2_x3 = torch.nn.Linear(encoding_size, output_size)

    
    
  def forward(self, visual_obs: torch.tensor):
#     print("torch input size:", visual_obs.size())
#     visual_obs = visual_obs.permute(0, 3, 1, 2)
#     conv_1 = torch.relu(self.conv1(visual_obs))
#     conv_2 = torch.relu(self.conv2(conv_1))
#     hidden = self.dense1(conv_2.reshape([-1, self.final_flat]))

    hidden = self.dense1(visual_obs)
    hidden = torch.relu(hidden)

    hidden = self.dense2(hidden)
    hidden = torch.relu(hidden)

    x1 = self.dense2_x1(hidden)
    x1 = torch.relu(x1)
    x2 = self.dense2_x2(hidden)
    x2 = torch.relu(x2)
    x3 = self.dense2_x3(hidden)
    x3 = torch.relu(x3)

    return x1, x2, x3

  @staticmethod
  def conv_output_shape(
    h_w: Tuple[int, int],
    kernel_size: int = 1,
    stride: int = 1,
    pad: int = 0,
    dilation: int = 1,
  ):
    """
    Computes the height and width of the output of a convolution layer.
    """
    h = floor(
      ((h_w[0] + (2 * pad) - (dilation * (kernel_size - 1)) - 1) / stride) + 1
    )
    w = floor(
      ((h_w[1] + (2 * pad) - (dilation * (kernel_size - 1)) - 1) / stride) + 1
    )
    return h, w

# %%
import numpy as np
from typing import NamedTuple, List


class Experience(NamedTuple):
  """
  An experience contains the data of one Agent transition.
  - Observation
  - Action
  - Reward
  - Done flag
  - Next Observation
  """

  obs: np.ndarray
  action: np.ndarray
  reward: float
  done: bool
  next_obs: np.ndarray

# A Trajectory is an ordered sequence of Experiences
Trajectory = List[Experience]

# A Buffer is an unordered list of Experiences from multiple Trajectories
Buffer = List[Experience]

# %%
from mlagents_envs.environment import ActionTuple, BaseEnv
from typing import Dict
import random


class Trainer:
  @staticmethod
  def generate_trajectories(
    env: BaseEnv, q_net: VisualQNetwork, buffer_size: int, epsilon: float
  ):
    """
    Given a Unity Environment and a Q-Network, this method will generate a
    buffer of Experiences obtained by running the Environment with the Policy
    derived from the Q-Network.
    :param BaseEnv: The UnityEnvironment used.
    :param q_net: The Q-Network used to collect the data.
    :param buffer_size: The minimum size of the buffer this method will return.
    :param epsilon: Will add a random normal variable with standard deviation.
    epsilon to the value heads of the Q-Network to encourage exploration.
    :returns: a Tuple containing the created buffer and the average cumulative
    the Agents obtained.
    """
    # Create an empty Buffer
    buffer: Buffer = []

    # Reset the environment
    env.reset()
    # Read and store the Behavior Name of the Environment
    behavior_name = list(env.behavior_specs)[0]
    # Read and store the Behavior Specs of the Environment
    spec = env.behavior_specs[behavior_name]

    # Create a Mapping from AgentId to Trajectories. This will help us create
    # trajectories for each Agents
    dict_trajectories_from_agent: Dict[int, Trajectory] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_obs_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_action_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to cumulative reward (Only for reporting)
    dict_cumulative_reward_from_agent: Dict[int, float] = {}
    # Create a list to store the cumulative rewards obtained so far
    cumulative_rewards: List[float] = []
    
    
    entered_terminal = False
    while len(buffer) < buffer_size:  # While not enough data in the buffer
      # Get the Decision Steps and Terminal Steps of the Agents
      decision_steps, terminal_steps = env.get_steps(behavior_name)
    
        # For all Agents with a Terminal Step:
      for agent_id_terminated in terminal_steps:
#         print("entered agent with terminal step")
#         print(agent_id_terminated)

        # Create its last experience (is last because the Agent terminated)
        last_experience = Experience(
          obs=dict_last_obs_from_agent[agent_id_terminated].copy(),
          reward=terminal_steps[agent_id_terminated].reward,
          done=not terminal_steps[agent_id_terminated].interrupted,
          action=dict_last_action_from_agent[agent_id_terminated].copy(),
          next_obs=terminal_steps[agent_id_terminated].obs[0],
        )
        # Clear its last observation and action (Since the trajectory is over)
        dict_last_obs_from_agent.pop(agent_id_terminated)
        dict_last_action_from_agent.pop(agent_id_terminated)
        # Report the cumulative reward
        cumulative_reward = (
          dict_cumulative_reward_from_agent.pop(agent_id_terminated)
          + terminal_steps[agent_id_terminated].reward
        )
#         print("cumulative reward: ", cumulative_reward)
        cumulative_rewards.append(cumulative_reward) #  - 50
        # Add the Trajectory and the last experience to the buffer
        buffer.extend(dict_trajectories_from_agent.pop(agent_id_terminated))
        buffer.append(last_experience)
        entered_terminal = True

      # For all Agents with a Decision Step:
      for agent_id_decisions in decision_steps:
        # If the Agent does not have a Trajectory, create an empty one
        if agent_id_decisions not in dict_trajectories_from_agent:
          dict_trajectories_from_agent[agent_id_decisions] = []
          dict_cumulative_reward_from_agent[agent_id_decisions] = 0

        # If the Agent requesting a decision has a "last observation"
        if agent_id_decisions in dict_last_obs_from_agent:
          # Create an Experience from the last observation and the Decision Step
          exp = Experience(
            obs=dict_last_obs_from_agent[agent_id_decisions].copy(),
            reward=decision_steps[agent_id_decisions].reward, #  - 0.05
            done=False,
            action=dict_last_action_from_agent[agent_id_decisions].copy(),
            next_obs=decision_steps[agent_id_decisions].obs[0],
          )
          # Update the Trajectory of the Agent and its cumulative reward
          dict_trajectories_from_agent[agent_id_decisions].append(exp)
          dict_cumulative_reward_from_agent[agent_id_decisions] += (
            decision_steps[agent_id_decisions].reward
          )
        # Store the observation as the new "last observation"
        dict_last_obs_from_agent[agent_id_decisions] = (
          decision_steps[agent_id_decisions].obs[0]
        )

      # Generate an action for all the Agents that requested a decision
      # Compute the values for each action given the observation    
      act1, act2, act3 = q_net(torch.from_numpy(decision_steps.obs[0]))
    
      if len(decision_steps) == 0:
#             print("error: no more observations ! ")
            env.step()
            continue
#       if act1.size == 0:
#             print("error: Action space received = 0")
    #         actions_values = np.zeros((3,3))

#             env.step()
#             continue
            
      # get actions as arrays
      act1 = act1.detach().numpy()
      act2 = act2.detach().numpy()
      act3 = act3.detach().numpy()
    
#       print("action received from QNetwork: ", act1)
#       print("action received from QNetwork: ", act2)
#       print("action received from QNetwork: ", act3)
      
      # pick the best action using argmax
      act1 = np.argmax(act1, axis=1)
      act2 = np.argmax(act2, axis=1)
      act3 = np.argmax(act3, axis=1)
      act1 = np.expand_dims(act1, axis=1)
      act2 = np.expand_dims(act2, axis=1)
      act3 = np.expand_dims(act3, axis=1)
      # map action index 2 to -1 for the agent to move backwards, left, and rotate left
      act1[act1 > 1] = -1
      act2[act2 > 1] = -1
      act3[act3 > 1] = -1

      temp = np.hstack((act1, act2, act3))
      actions = temp
      actions.resize((len(decision_steps), 3))


      # Store the action that was picked, it will be put in the trajectory later
      for agent_index, agent_id in enumerate(decision_steps.agent_id):
        dict_last_action_from_agent[agent_id] = actions[agent_index]
#       print("dict last action: ", dict_last_action_from_agent)

        
      # Set the actions in the environment
      # Unity Environments expect ActionTuple instances.
      action_tuple = ActionTuple()
      action_tuple.add_discrete(actions)
#       print("filtered action received from QNetwork: ", action_tuple.discrete)
      env.set_actions(behavior_name, action_tuple)
      # Perform a step in the simulation
      env.step()
    return buffer, np.mean(cumulative_rewards)

  @staticmethod
  def update_q_net(
    q_net: VisualQNetwork, 
    optimizer: torch.optim, 
    buffer: Buffer, 
    action_size: int
  ):
    """
    Performs an update of the Q-Network using the provided optimizer and buffer
    """
    def calculate_bellman_loss(next_pred_action, pred_action, reward, done, GAMMA, batch, action_size, action):
        # Use the Bellman equation to update the Q-Network
        target = (
          reward
          + (1.0 - done)
          * GAMMA
          * torch.max(next_pred_action.detach(), dim=1, keepdim=True).values
        ).double()
#         print("next_act_prediction:", next_pred_action.detach().numpy())
        
#         print("Target:", target)
#         print("Target shape:", target.shape)

#         print("action:", action)
#         print("action shape: ", action.shape)
        assert(action.shape[0] == len(batch))
        action[action < 0] = 2
#         print("action after correction:", action)
        
        mask = np.eye(action_size)[action]
#         mask = torch.zeros((len(batch), action_size))  
#         print("mask: ", mask)
#         print("mask shape: ", mask.shape)
#         mask.scatter_(1, action, 1)
#         print("mask after scatter: ", mask)
        mask = torch.from_numpy(mask).double()
#         print("pred_action: error", pred_action)
#         print(type(pred_action))
#         print(pred_action.dtype)
#         print(type(mask))
#         print(mask.dtype)
        prediction = torch.sum(pred_action.double() * mask, dim=1, keepdim=True)
#         print("act_prediction:", pred_action.detach().numpy())
#         print("prediction: ", prediction)
#         print("prediction shaPE: ", prediction.shape)
#         print("prediction type: ", type(prediction))
#         print("prediction dtype: ", prediction.dtype)
        
        criterion = torch.nn.MSELoss()
        loss = criterion(prediction, target)
        
        return loss

    BATCH_SIZE = 1000
    NUM_EPOCH = 3
    GAMMA = 0.9
    batch_size = min(len(buffer), BATCH_SIZE)
    random.shuffle(buffer)
    # Split the buffer into batches
    batches = [
      buffer[batch_size * start : batch_size * (start + 1)]
      for start in range(int(len(buffer) / batch_size))
    ]
    for _ in range(NUM_EPOCH):
      for batch in batches:
        # Create the Tensors that will be fed in the network
        obs = torch.from_numpy(np.stack([ex.obs for ex in batch]))
        reward = torch.from_numpy(
          np.array([ex.reward for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        done = torch.from_numpy(
          np.array([ex.done for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        action = torch.from_numpy(np.stack([ex.action for ex in batch]))
        next_obs = torch.from_numpy(np.stack([ex.next_obs for ex in batch]))
        
        # Prerequisite: collect outputs
        pnext_a1, pnext_a2, pnext_a3 = q_net(next_obs)
        p_a1, p_a2, p_a3 = q_net(obs)
        
        # bellman equation for each loss
        loss1 = calculate_bellman_loss(pnext_a1, p_a1, reward, done, GAMMA, batch, action_size, action[:, 0])
        loss2 = calculate_bellman_loss(pnext_a2, p_a2, reward, done, GAMMA, batch, action_size, action[:, 1])
        loss3 = calculate_bellman_loss(pnext_a3, p_a3, reward, done, GAMMA, batch, action_size, action[:, 2])
        loss = loss1 + loss2 + loss3
        
        # Perform the backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
# Create a new Q-Network. 
qnet = VisualQNetwork((44, 1), 126, 3)

# %%
# -----------------
# This code is used to close an env that might not have been closed before
try:
  env.close()
except:
  pass
# -----------------

from mlagents_envs.registry import default_registry
from mlagents_envs.environment import UnityEnvironment
import matplotlib.pyplot as plt
# %matplotlib inline

# Create the GridWorld Environment from the registry
env = UE(file_name='run32_training', seed=1, side_channels=[])
# env = default_registry["GridWorld"].make()
print("GridWorld environment created.")

# moved Qnet outside to reuse it

experiences: Buffer = []
optim = torch.optim.Adam(qnet.parameters(), lr= 0.001)

cumulative_rewards: List[float] = []

# The number of training steps that will be performed
NUM_TRAINING_STEPS = 1000000# 70
# The number of experiences to collect per training step
NUM_NEW_EXP = 1000
# The maximum size of the Buffer
BUFFER_SIZE = 10000

for n in range(NUM_TRAINING_STEPS):
  new_exp,_ = Trainer.generate_trajectories(env, qnet, NUM_NEW_EXP, epsilon=0.1)
  random.shuffle(experiences)
  if len(experiences) > BUFFER_SIZE:
    experiences = experiences[:BUFFER_SIZE]
  experiences.extend(new_exp)
  Trainer.update_q_net(qnet, optim, experiences, 3)
  _, rewards = Trainer.generate_trajectories(env, qnet, 100, epsilon=0)
  cumulative_rewards.append(rewards)
  print("Training step ", n+1, "\treward ", rewards)
  print()


env.close()

# Show the training graph
plt.plot(range(NUM_TRAINING_STEPS), cumulative_rewards)
# Out:
# GridWorld environment created.
# Training step  1 	reward  13.69569231569767
#
# Training step  2 	reward  6.163495083649953
#
# Training step  3 	reward  4.471314929425716
#
# Training step  4 	reward  -1.0
#
# Training step  5 	reward  22.843223206698895
#
# Training step  6 	reward  18.239628486335278
#
# Training step  7 	reward  -1.0
#
# Training step  8 	reward  12.623454064130783
#
# Training step  9 	reward  96.38889029622078
#
# Training step  10 	reward  -1.0
#
# Training step  11 	reward  5.722998201847076
#
# Training step  12 	reward  12.604360289871693
#
# Training step  13 	reward  22.63673460483551
#
# Training step  14 	reward  7.255509942770004
#
# Training step  15 	reward  8.798600455125174
#
# Training step  16 	reward  6.715813487768173
#
# Training step  17 	reward  -0.12093669176101685
#
# Training step  18 	reward  5.7463584045569105
#
# Training step  19 	reward  13.733224898576736
#
# Training step  20 	reward  13.442022303740183
#
# Training step  21 	reward  8.642897218465805
#
# Training step  22 	reward  1.2498227192295923
#
# Training step  23 	reward  -1.0
#
# Training step  24 	reward  -1.0
#
# Training step  25 	reward  -1.0
#
# Training step  26 	reward  4.141944507757823
#
# Training step  27 	reward  -1.0
#
# Training step  28 	reward  -1.0
#
# Training step  29 	reward  0.0
#
# Training step  30 	reward  -1.0
#
# Training step  31 	reward  0.0
#
# Training step  32 	reward  0.0
#
# Training step  33 	reward  0.0
#
# Training step  34 	reward  0.0
#
# Training step  35 	reward  0.0
#
# Training step  36 	reward  0.0
#
# Training step  37 	reward  0.0
#
# Training step  38 	reward  0.0
#
# Training step  39 	reward  0.0
#
# Training step  40 	reward  0.0
#
# Training step  41 	reward  0.0
#
# Training step  42 	reward  0.0
#
# Training step  43 	reward  0.0
#
# Training step  44 	reward  0.0
#
# Training step  45 	reward  0.0
#
# Training step  46 	reward  0.0
#
# Training step  47 	reward  0.0
#
# Training step  48 	reward  0.0
#
# Training step  49 	reward  0.0
#
# Training step  50 	reward  0.0
#
# Training step  51 	reward  0.0
#
# Training step  52 	reward  0.0
#
# Training step  53 	reward  0.0
#
# Training step  54 	reward  0.0
#
# Training step  55 	reward  0.0
#
# Training step  56 	reward  0.0
#
# Training step  57 	reward  0.0
#
# Training step  58 	reward  0.0
#
# Training step  59 	reward  0.0
#
# Training step  60 	reward  0.0
#
# Training step  61 	reward  0.0
#
# Training step  62 	reward  0.0
#
# Training step  63 	reward  0.0
#
# Training step  64 	reward  0.0
#
# Training step  65 	reward  0.0
#
# Training step  66 	reward  0.0
#
# Training step  67 	reward  0.0
#
# Training step  68 	reward  0.0
#
# Training step  69 	reward  0.0
#
# Training step  70 	reward  0.0
#
# Training step  71 	reward  0.0
#
# Training step  72 	reward  0.0
#
# Training step  73 	reward  0.0
#
# Training step  74 	reward  0.0
#
# Training step  75 	reward  0.0
#
# Training step  76 	reward  0.0
#
# Training step  77 	reward  0.0
#
# Training step  78 	reward  0.0
#
# Training step  79 	reward  0.0
#
# Training step  80 	reward  0.0
#
# Training step  81 	reward  0.0
#
# Training step  82 	reward  0.0
#
# Training step  83 	reward  0.0
#
# Training step  84 	reward  0.0
#
# Training step  85 	reward  0.0
#
# Training step  86 	reward  0.0
#
# Training step  87 	reward  0.0
#
# Training step  88 	reward  0.0
#
# Training step  89 	reward  0.0
#
# Training step  90 	reward  0.0
#
# Training step  91 	reward  0.0
#
# Training step  92 	reward  0.0
#
# Training step  93 	reward  0.0
#
# Training step  94 	reward  0.0
#
# Training step  95 	reward  0.0
#
# Training step  96 	reward  0.0
#
# Training step  97 	reward  0.0
#
# Training step  98 	reward  0.0
#
# Training step  99 	reward  0.0
#
# Training step  100 	reward  0.0
#
# Training step  101 	reward  0.0
#
# Training step  102 	reward  0.0
#
# Training step  103 	reward  0.0
#
# Training step  104 	reward  0.0
#
# Training step  105 	reward  0.0
#
# Training step  106 	reward  0.0
#
# Training step  107 	reward  0.0
#
# Training step  108 	reward  0.0
#
# Training step  109 	reward  0.0
#
# Training step  110 	reward  0.0
#
# Training step  111 	reward  0.0
#
# Training step  112 	reward  0.0
#
# Training step  113 	reward  0.0
#
# Training step  114 	reward  0.0
#
# Training step  115 	reward  0.0
#
# Training step  116 	reward  0.0
#
# Training step  117 	reward  0.0
#
# Training step  118 	reward  0.0
#
# Training step  119 	reward  0.0
#
# Training step  120 	reward  0.0
#
# Training step  121 	reward  0.0
#
# Training step  122 	reward  0.0
#
# Training step  123 	reward  0.0
#
# Training step  124 	reward  0.0
#
# Training step  125 	reward  0.0
#
# Training step  126 	reward  0.0
#
# Training step  127 	reward  0.0
#
# Training step  128 	reward  0.0
#
# Training step  129 	reward  0.0
#
# Training step  130 	reward  0.0
#
# Training step  131 	reward  0.0
#
# Training step  132 	reward  0.0
#
# Training step  133 	reward  0.0
#
# Training step  134 	reward  0.0
#
# Training step  135 	reward  0.0
#
# Training step  136 	reward  0.0
#
# Training step  137 	reward  0.0
#
# Training step  138 	reward  0.0
#
# Training step  139 	reward  0.0
#
# Training step  140 	reward  0.0
#
# Training step  141 	reward  0.0
#
# Training step  142 	reward  0.0
#
# Training step  143 	reward  0.0
#
# Training step  144 	reward  0.0
#
# Training step  145 	reward  0.0
#
# Training step  146 	reward  0.0
#
# Training step  147 	reward  0.0
#
# Training step  148 	reward  0.0
#
# Training step  149 	reward  0.0
#
# Training step  150 	reward  0.0
#
# Training step  151 	reward  0.0
#
# Training step  152 	reward  0.0
#
# Training step  153 	reward  0.0
#
# Training step  154 	reward  0.0
#
# Training step  155 	reward  0.0
#
# Training step  156 	reward  0.0
#
# Training step  157 	reward  0.0
#
# Training step  158 	reward  0.0
#
# Training step  159 	reward  0.0
#
# Training step  160 	reward  0.0
#
# Training step  161 	reward  0.0
#
# Training step  162 	reward  0.0
#
# Training step  163 	reward  0.0
#
# Training step  164 	reward  0.0
#
# Training step  165 	reward  0.0
#
# Training step  166 	reward  0.0
#
# Training step  167 	reward  0.0
#
# Training step  168 	reward  0.0
#
# Training step  169 	reward  0.0
#
# Training step  170 	reward  0.0
#
# Training step  171 	reward  0.0
#
# Training step  172 	reward  0.0
#
# Training step  173 	reward  0.0
#
# Training step  174 	reward  0.0
#
# Training step  175 	reward  0.0
#
# Training step  176 	reward  0.0
#
# Training step  177 	reward  0.0
#
# Training step  178 	reward  0.0
#
# Training step  179 	reward  0.0
#
# Training step  180 	reward  0.0
#
# Training step  181 	reward  0.0
#
# Training step  182 	reward  0.0
#
# Training step  183 	reward  0.0
#
# Training step  184 	reward  0.0
#
# Training step  185 	reward  0.0
#
# Training step  186 	reward  0.0
#
# Training step  187 	reward  0.0
#
# Training step  188 	reward  0.0
#
# Training step  189 	reward  0.0
#
# Training step  190 	reward  0.0
#
# Training step  191 	reward  0.0
#
# Training step  192 	reward  0.0
#
# Training step  193 	reward  0.0
#
# Training step  194 	reward  0.0
#
# Training step  195 	reward  0.0
#
# Training step  196 	reward  0.0
#
# Training step  197 	reward  0.0
#
# Training step  198 	reward  0.0
#
# Training step  199 	reward  0.0
#
# Training step  200 	reward  0.0
#
# Training step  201 	reward  0.0
#
# Training step  202 	reward  0.0
#
# Training step  203 	reward  0.0
#
# Training step  204 	reward  0.0
#
# Training step  205 	reward  0.0
#
# Training step  206 	reward  0.0
#
# Training step  207 	reward  0.0
#
# Training step  208 	reward  0.0
#
# Training step  209 	reward  0.0
#
# Training step  210 	reward  0.0
#
# Training step  211 	reward  0.0
#
# Training step  212 	reward  0.0
#
# Training step  213 	reward  0.0
#
# Training step  214 	reward  0.0
#
# Training step  215 	reward  0.0
#
# Training step  216 	reward  0.0
#
# Training step  217 	reward  0.0
#
# Training step  218 	reward  0.0
#
# Training step  219 	reward  0.0
#
# Training step  220 	reward  0.0
#
# Training step  221 	reward  0.0
#
# Training step  222 	reward  0.0
#
# Training step  223 	reward  0.0
#
# Training step  224 	reward  0.0
#
# Training step  225 	reward  0.0
#
# Training step  226 	reward  0.0
#
# Training step  227 	reward  0.0
#
# Training step  228 	reward  0.0
#
# Training step  229 	reward  0.0
#
# Training step  230 	reward  0.0
#
# Training step  231 	reward  0.0
#
# Training step  232 	reward  0.0
#
# Training step  233 	reward  0.0
#
# Training step  234 	reward  0.0
#
# Training step  235 	reward  0.0
#
# Training step  236 	reward  0.0
#
# Training step  237 	reward  0.0
#
# Training step  238 	reward  0.0
#
# Training step  239 	reward  0.0
#
# Training step  240 	reward  0.0
#
# Training step  241 	reward  0.0
#
# Training step  242 	reward  0.0
#
# Training step  243 	reward  0.0
#
# Training step  244 	reward  0.0
#
# Training step  245 	reward  0.0
#
# Training step  246 	reward  0.0
#
# Training step  247 	reward  0.0
#
# Training step  248 	reward  0.0
#
# Training step  249 	reward  0.0
#
# Training step  250 	reward  0.0
#
# Training step  251 	reward  0.0
#
# Training step  252 	reward  0.0
#
# Training step  253 	reward  0.0
#
# Training step  254 	reward  0.0
#
# Training step  255 	reward  0.0
#
# Training step  256 	reward  0.0
#
# Training step  257 	reward  0.0
#
# Training step  258 	reward  0.0
#
# Training step  259 	reward  0.0
#
# Training step  260 	reward  0.0
#
# Training step  261 	reward  0.0
#
# Training step  262 	reward  0.0
#
# Training step  263 	reward  0.0
#
# Training step  264 	reward  0.0
#
# Training step  265 	reward  0.0
#
# Training step  266 	reward  0.0
#
# Training step  267 	reward  0.0
#
# Training step  268 	reward  0.0
#
# Training step  269 	reward  0.0
#
# Training step  270 	reward  0.0
#
# Training step  271 	reward  0.0
#
# Training step  272 	reward  0.0
#
# Training step  273 	reward  0.0
#
# Training step  274 	reward  0.0
#
# Training step  275 	reward  0.0
#
# Training step  276 	reward  0.0
#
# Training step  277 	reward  0.0
#
# Training step  278 	reward  0.0
#
# Training step  279 	reward  0.0
#
# Training step  280 	reward  0.0
#
# Training step  281 	reward  0.0
#
# Training step  282 	reward  0.0
#
# Training step  283 	reward  0.0
#
# Training step  284 	reward  0.0
#
# Training step  285 	reward  0.0
#
# Training step  286 	reward  0.0
#
# Training step  287 	reward  0.0
#
# Training step  288 	reward  0.0
#
# Training step  289 	reward  0.0
#
# Training step  290 	reward  0.0
#
# Training step  291 	reward  0.0
#
# Training step  292 	reward  0.0
#
# Training step  293 	reward  0.0
#
# Training step  294 	reward  0.0
#
# Training step  295 	reward  0.0
#
# Training step  296 	reward  0.0
#
# Training step  297 	reward  0.0
#
# Training step  298 	reward  0.0
#
# Training step  299 	reward  0.0
#
# Training step  300 	reward  0.0
#
# Training step  301 	reward  0.0
#
# Training step  302 	reward  0.0
#
# Training step  303 	reward  0.0
#
# Training step  304 	reward  0.0
#
# Training step  305 	reward  0.0
#
# Training step  306 	reward  0.0
#
# Training step  307 	reward  0.0
#
# Training step  308 	reward  0.0
#
# Training step  309 	reward  0.0
#
# Training step  310 	reward  0.0
#
# Training step  311 	reward  0.0
#
# Training step  312 	reward  0.0
#
# Training step  313 	reward  0.0
#
# Training step  314 	reward  0.0
#
# Training step  315 	reward  0.0
#
# Training step  316 	reward  0.0
#
# Training step  317 	reward  0.0
#
# Training step  318 	reward  0.0
#
# Training step  319 	reward  0.0
#
# Training step  320 	reward  0.0
#
# Training step  321 	reward  0.0
#
# Training step  322 	reward  0.0
#
# Training step  323 	reward  0.0
#
# Training step  324 	reward  0.0
#
# Training step  325 	reward  0.0
#
# Training step  326 	reward  0.0
#
# Training step  327 	reward  0.0
#
# Training step  328 	reward  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5184b6facd07> in <module>
#      38   experiences.extend(new_exp)
#      39   Trainer.update_q_net(qnet, optim, experiences, 3)
# ---> 40   _, rewards = Trainer.generate_trajectories(env, qnet, 100, epsilon=0)
#      41   cumulative_rewards.append(rewards)
#      42   print("Training step ", n+1, "\treward ", rewards)
#
# <ipython-input-6-c7fdc2d8af86> in generate_trajectories(env, q_net, buffer_size, epsilon)
#     106       # Generate an action for all the Agents that requested a decision
#     107       # Compute the values for each action given the observation
# --> 108       act1, act2, act3 = q_net(torch.from_numpy(decision_steps.obs[0]))
#     109
#     110       if len(decision_steps) == 0:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-2-571395ef7e28> in forward(self, visual_obs)
#      46 #     hidden = self.dense1(conv_2.reshape([-1, self.final_flat]))
#      47
# ---> 48     hidden = self.dense1(visual_obs)
#      49     hidden = torch.relu(hidden)
#      50
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:

# %%
plt.plot(range(328), cumulative_rewards)

# %%
env.close()
print("Closed environment")
# Out:
# Closed environment

# %%
# pip install --upgrade --user nbconvert
# !sudo apt-get install -y texlive-xetex
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 javascript-common libapache-pom-java
#   libauthen-sasl-perl libcommons-logging-java libcommons-parent-java
#   libdata-dump-perl libencode-locale-perl libfile-basedir-perl
#   libfile-desktopentry-perl libfile-listing-perl libfile-mimeinfo-perl
#   libfont-afm-perl libfontbox-java libgs9 libgs9-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libio-stringy-perl libipc-system-simple-perl
#   libjbig2dec0 libjs-jquery libkpathsea6 liblwp-mediatypes-perl
#   liblwp-protocol-https-perl libmailtools-perl libnet-dbus-perl
#   libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl libpaper-utils
#   libpaper1 libpdfbox-java libptexenc1 libruby2.7 libsynctex2 libteckit0
#   libtexlua53 libtexluajit2 libtext-iconv-perl libtie-ixhash-perl
#   libtimedate-perl libtry-tiny-perl liburi-perl libwww-perl
#   libwww-robotrules-perl libx11-protocol-perl libxml-parser-perl
#   libxml-twig-perl libxml-xpathengine-perl libxxf86dga1 libzzip-0-13 lmodern
#   perl-openssl-defaults poppler-data preview-latex-style rake ruby
#   ruby-minitest ruby-net-telnet ruby-power-assert ruby-test-unit ruby-xmlrpc
#   ruby2.7 rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-extra texlive-latex-recommended texlive-pictures
#   texlive-plain-generic tipa x11-utils x11-xserver-utils xdg-utils zip
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf apache2 | lighttpd
#   | httpd libdigest-hmac-perl libgssapi-perl libavalon-framework-java
#   libcommons-logging-java-doc libexcalibur-logkit-java liblog4j1.2-java
#   libcrypt-ssleay-perl libauthen-ntlm-perl libunicode-map8-perl
#   libunicode-string-perl xml-twig-tools poppler-utils ghostscript
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum ri
#   ruby-dev bundler gv | postscript-viewer perl-tk xpdf | pdf-viewer xzdec
#   texlive-fonts-recommended-doc texlive-latex-base-doc python3-pygments
#   icc-profiles libfile-which-perl libspreadsheet-parseexcel-perl
#   texlive-latex-extra-doc texlive-latex-recommended-doc texlive-luatex
#   texlive-pstricks dot2tex prerex ruby-tcltk | libtcltk-ruby
#   texlive-pictures-doc vprerex default-jre-headless mesa-utils nickle cairo-5c
#   xorg-docs-core
# The following NEW packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 javascript-common libapache-pom-java
#   libauthen-sasl-perl libcommons-logging-java libcommons-parent-java
#   libdata-dump-perl libencode-locale-perl libfile-basedir-perl
#   libfile-desktopentry-perl libfile-listing-perl libfile-mimeinfo-perl
#   libfont-afm-perl libfontbox-java libgs9 libgs9-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libio-stringy-perl libipc-system-simple-perl
#   libjbig2dec0 libjs-jquery libkpathsea6 liblwp-mediatypes-perl
#   liblwp-protocol-https-perl libmailtools-perl libnet-dbus-perl
#   libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl libpaper-utils
#   libpaper1 libpdfbox-java libptexenc1 libruby2.7 libsynctex2 libteckit0
#   libtexlua53 libtexluajit2 libtext-iconv-perl libtie-ixhash-perl
#   libtimedate-perl libtry-tiny-perl liburi-perl libwww-perl
#   libwww-robotrules-perl libx11-protocol-perl libxml-parser-perl
#   libxml-twig-perl libxml-xpathengine-perl libxxf86dga1 libzzip-0-13 lmodern
#   perl-openssl-defaults poppler-data preview-latex-style rake ruby
#   ruby-minitest ruby-net-telnet ruby-power-assert ruby-test-unit ruby-xmlrpc
#   ruby2.7 rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-extra texlive-latex-recommended texlive-pictures
#   texlive-plain-generic texlive-xetex tipa x11-utils x11-xserver-utils
#   xdg-utils zip
# 0 upgraded, 100 newly installed, 0 to remove and 266 not upgraded.
# Need to get 171 MB of archives.
# After this operation, 545 MB of additional disk space will be used.
# Get:1 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1805 kB]
# Get:2 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 fonts-lato all 2.0-2 [2698 kB]
# Get:3 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 poppler-data all 0.4.9-2 [1475 kB]
# Get:4 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 tex-common all 6.13 [32.7 kB]
# Get:5 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtext-iconv-perl amd64 1.7-7 [13.8 kB]
# Get:6 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 fonts-urw-base35 all 20170801.1-3 [6333 kB]
# Get:7 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 libgs9-common all 9.50~dfsg-5ubuntu4.2 [681 kB]
# Get:8 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libijs-0.35 amd64 0.35-15 [15.7 kB]
# Get:9 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libjbig2dec0 amd64 0.18-1ubuntu1 [60.0 kB]
# Get:10 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libpaper1 amd64 1.1.28 [13.0 kB]
# Get:11 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 libgs9 amd64 9.50~dfsg-5ubuntu4.2 [2172 kB]
# Get:12 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libkpathsea6 amd64 2019.20190605.51237-3build2 [57.0 kB]
# Get:13 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 dvisvgm amd64 2.8.1-1build1 [1048 kB]
# Get:14 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 fonts-lmodern all 2.004.5-6 [4532 kB]
# Get:15 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 fonts-noto-mono all 20200323-1build1~ubuntu20.04.1 [80.6 kB]
# Get:16 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 fonts-texgyre all 20180621-3 [10.2 MB]
# Get:17 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 javascript-common all 11 [6066 B]
# Get:18 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libapache-pom-java all 18-1 [4720 B]
# Get:19 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:20 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libcommons-logging-java all 1.2-2 [60.3 kB]
# Get:21 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libdata-dump-perl all 1.23-1 [27.0 kB]
# Get:22 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:23 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libipc-system-simple-perl all 1.26-1 [22.8 kB]
# Get:24 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libfile-basedir-perl all 0.08-1 [16.9 kB]
# Get:25 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 liburi-perl all 1.76-2 [77.5 kB]
# Get:26 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libfile-desktopentry-perl all 0.22-1 [18.2 kB]
# Get:27 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtimedate-perl all 2.3200-1 [34.0 kB]
# Get:28 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhttp-date-perl all 6.05-1 [9920 B]
# Get:29 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libfile-listing-perl all 6.04-1 [9774 B]
# Get:30 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libfile-mimeinfo-perl all 0.29-1 [41.5 kB]
# Get:31 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libfont-afm-perl all 1.20-2 [13.2 kB]
# Get:32 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:33 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhtml-parser-perl amd64 3.72-5 [86.3 kB]
# Get:34 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:35 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:36 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhttp-message-perl all 6.22-1 [76.1 kB]
# Get:37 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhtml-form-perl all 6.07-1 [22.2 kB]
# Get:38 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhtml-tree-perl all 5.07-2 [200 kB]
# Get:39 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhtml-format-perl all 2.12-1 [41.3 kB]
# Get:40 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhttp-cookies-perl all 6.08-1 [18.3 kB]
# Get:41 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhttp-daemon-perl all 6.06-1 [21.4 kB]
# Get:42 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libhttp-negotiate-perl all 6.01-1 [12.5 kB]
# Get:43 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 perl-openssl-defaults amd64 4 [7192 B]
# Get:44 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libnet-ssleay-perl amd64 1.88-2ubuntu1 [291 kB]
# Get:45 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libio-socket-ssl-perl all 2.067-1 [176 kB]
# Get:46 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libio-stringy-perl all 2.111-3 [55.8 kB]
# Get:47 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libjs-jquery all 3.3.1~dfsg-3 [329 kB]
# Get:48 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libnet-http-perl all 6.19-1 [22.8 kB]
# Get:49 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtry-tiny-perl all 0.30-1 [20.5 kB]
# Get:50 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libwww-robotrules-perl all 6.02-1 [12.6 kB]
# Get:51 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libwww-perl all 6.43-1 [140 kB]
# Get:52 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 liblwp-protocol-https-perl all 6.07-2ubuntu2 [8560 B]
# Get:53 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5948 B]
# Get:54 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libmailtools-perl all 2.21-1 [80.7 kB]
# Get:55 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libxml-parser-perl amd64 2.46-1 [193 kB]
# Get:56 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libxml-twig-perl all 1:3.50-2 [155 kB]
# Get:57 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libnet-dbus-perl amd64 1.2.0-1 [177 kB]
# Get:58 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libpaper-utils amd64 1.1.28 [8400 B]
# Get:59 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libptexenc1 amd64 2019.20190605.51237-3build2 [35.5 kB]
# Get:60 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 rubygems-integration all 1.16 [5092 B]
# Get:61 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 ruby2.7 amd64 2.7.0-5ubuntu1.4 [95.6 kB]
# Get:62 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby amd64 1:2.7+1 [5412 B]
# Get:63 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 rake all 13.0.1-4 [61.6 kB]
# Get:64 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby-minitest all 5.13.0-1 [40.9 kB]
# Get:65 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:66 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby-power-assert all 1.1.7-1 [11.4 kB]
# Get:67 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby-test-unit all 3.3.5-1 [73.2 kB]
# Get:68 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 ruby-xmlrpc all 0.3.0-2 [23.8 kB]
# Get:69 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 libruby2.7 amd64 2.7.0-5ubuntu1.4 [3526 kB]
# Get:70 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libsynctex2 amd64 2019.20190605.51237-3build2 [55.0 kB]
# Get:71 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libteckit0 amd64 2.5.8+ds2-5ubuntu2 [320 kB]
# Get:72 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtexlua53 amd64 2019.20190605.51237-3build2 [105 kB]
# Get:73 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtexluajit2 amd64 2019.20190605.51237-3build2 [235 kB]
# Get:74 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libtie-ixhash-perl all 1.23-2 [11.2 kB]
# Get:75 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libx11-protocol-perl all 0.56-7 [149 kB]
# Get:76 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libxml-xpathengine-perl all 0.14-1 [31.8 kB]
# Get:77 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:78 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libzzip-0-13 amd64 0.13.62-3.2ubuntu1 [26.2 kB]
# Get:79 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 lmodern all 2.004.5-6 [9474 kB]
# Get:80 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 preview-latex-style all 11.91-2ubuntu2 [184 kB]
# Get:81 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 t1utils amd64 1.41-3 [56.1 kB]
# Get:82 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 teckit amd64 2.5.8+ds2-5ubuntu2 [687 kB]
# Get:83 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 tex-gyre all 20180621-3 [6209 kB]
# Get:84 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-binaries amd64 2019.20190605.51237-3build2 [8041 kB]
# Get:85 http://pkg.adfinis-sygroup.ch/ubuntu focal-updates/main amd64 xdg-utils all 1.1.3-2ubuntu1.20.04.2 [61.4 kB]
# Get:86 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-base all 2019.20200218-1 [20.8 MB]
# Get:87 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-fonts-recommended all 2019.20200218-1 [4972 kB]
# Get:88 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-latex-base all 2019.20200218-1 [990 kB]
# Get:89 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libfontbox-java all 1:1.8.16-2 [207 kB]
# Get:90 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 libpdfbox-java all 1:1.8.16-2 [5199 kB]
# Get:91 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-latex-recommended all 2019.20200218-1 [15.7 MB]
# Get:92 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-pictures all 2019.20200218-1 [4492 kB]
# Get:93 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-latex-extra all 2019.202000218-1 [12.5 MB]
# Get:94 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-plain-generic all 2019.202000218-1 [24.6 MB]
# Get:95 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 tipa all 2:1.3-20 [2978 kB]
# Get:96 http://pkg.adfinis-sygroup.ch/ubuntu focal/universe amd64 texlive-xetex all 2019.20200218-1 [14.6 MB]
# Get:97 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 x11-utils amd64 7.7+5 [199 kB]
# Get:98 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 x11-xserver-utils amd64 7.7+8 [162 kB]
# Get:99 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 zip amd64 3.0-11build1 [167 kB]
# Get:100 http://pkg.adfinis-sygroup.ch/ubuntu focal/main amd64 libauthen-sasl-perl all 2.1600-1 [48.7 kB]
# Fetched 171 MB in 6s (27.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 100.)
# debconf: falling back to frontend: Readline
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 100155 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package fonts-lato.
# Preparing to unpack .../01-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../02-poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../03-tex-common_6.13_all.deb ...
# Unpacking tex-common (6.13) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../04-libtext-iconv-perl_1.7-7_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../05-fonts-urw-base35_20170801.1-3_all.deb ...
# Unpacking fonts-urw-base35 (20170801.1-3) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../06-libgs9-common_9.50~dfsg-5ubuntu4.2_all.deb ...
# Unpacking libgs9-common (9.50~dfsg-5ubuntu4.2) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../07-libijs-0.35_0.35-15_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../08-libjbig2dec0_0.18-1ubuntu1_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Selecting previously unselected package libpaper1:amd64.
# Preparing to unpack .../09-libpaper1_1.1.28_amd64.deb ...
# Unpacking libpaper1:amd64 (1.1.28) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../10-libgs9_9.50~dfsg-5ubuntu4.2_amd64.deb ...
# Unpacking libgs9:amd64 (9.50~dfsg-5ubuntu4.2) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../11-libkpathsea6_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2019.20190605.51237-3build2) ...
# Selecting previously unselected package dvisvgm.
# Preparing to unpack .../12-dvisvgm_2.8.1-1build1_amd64.deb ...
# Unpacking dvisvgm (2.8.1-1build1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../13-fonts-lmodern_2.004.5-6_all.deb ...
# Unpacking fonts-lmodern (2.004.5-6) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../14-fonts-noto-mono_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../15-fonts-texgyre_20180621-3_all.deb ...
# Unpacking fonts-texgyre (20180621-3) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../16-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../17-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../18-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../19-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../20-libdata-dump-perl_1.23-1_all.deb ...
# Unpacking libdata-dump-perl (1.23-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../21-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libipc-system-simple-perl.
# Preparing to unpack .../22-libipc-system-simple-perl_1.26-1_all.deb ...
# Unpacking libipc-system-simple-perl (1.26-1) ...
# Selecting previously unselected package libfile-basedir-perl.
# Preparing to unpack .../23-libfile-basedir-perl_0.08-1_all.deb ...
# Unpacking libfile-basedir-perl (0.08-1) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../24-liburi-perl_1.76-2_all.deb ...
# Unpacking liburi-perl (1.76-2) ...
# Selecting previously unselected package libfile-desktopentry-perl.
# Preparing to unpack .../25-libfile-desktopentry-perl_0.22-1_all.deb ...
# Unpacking libfile-desktopentry-perl (0.22-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../26-libtimedate-perl_2.3200-1_all.deb ...
# Unpacking libtimedate-perl (2.3200-1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../27-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../28-libfile-listing-perl_6.04-1_all.deb ...
# Unpacking libfile-listing-perl (6.04-1) ...
# Selecting previously unselected package libfile-mimeinfo-perl.
# Preparing to unpack .../29-libfile-mimeinfo-perl_0.29-1_all.deb ...
# Unpacking libfile-mimeinfo-perl (0.29-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../30-libfont-afm-perl_1.20-2_all.deb ...
# Unpacking libfont-afm-perl (1.20-2) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../31-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../32-libhtml-parser-perl_3.72-5_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-5) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../33-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../34-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../35-libhttp-message-perl_6.22-1_all.deb ...
# Unpacking libhttp-message-perl (6.22-1) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../36-libhtml-form-perl_6.07-1_all.deb ...
# Unpacking libhtml-form-perl (6.07-1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../37-libhtml-tree-perl_5.07-2_all.deb ...
# Unpacking libhtml-tree-perl (5.07-2) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../38-libhtml-format-perl_2.12-1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../39-libhttp-cookies-perl_6.08-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.08-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../40-libhttp-daemon-perl_6.06-1_all.deb ...
# Unpacking libhttp-daemon-perl (6.06-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../41-libhttp-negotiate-perl_6.01-1_all.deb ...
# Unpacking libhttp-negotiate-perl (6.01-1) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../42-perl-openssl-defaults_4_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (4) ...
# Selecting previously unselected package libnet-ssleay-perl.
# Preparing to unpack .../43-libnet-ssleay-perl_1.88-2ubuntu1_amd64.deb ...
# Unpacking libnet-ssleay-perl (1.88-2ubuntu1) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../44-libio-socket-ssl-perl_2.067-1_all.deb ...
# Unpacking libio-socket-ssl-perl (2.067-1) ...
# Selecting previously unselected package libio-stringy-perl.
# Preparing to unpack .../45-libio-stringy-perl_2.111-3_all.deb ...
# Unpacking libio-stringy-perl (2.111-3) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../46-libjs-jquery_3.3.1~dfsg-3_all.deb ...
# Unpacking libjs-jquery (3.3.1~dfsg-3) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../47-libnet-http-perl_6.19-1_all.deb ...
# Unpacking libnet-http-perl (6.19-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../48-libtry-tiny-perl_0.30-1_all.deb ...
# Unpacking libtry-tiny-perl (0.30-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../49-libwww-robotrules-perl_6.02-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.02-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../50-libwww-perl_6.43-1_all.deb ...
# Unpacking libwww-perl (6.43-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../51-liblwp-protocol-https-perl_6.07-2ubuntu2_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.07-2ubuntu2) ...
# Selecting previously unselected package libnet-smtp-ssl-perl.
# Preparing to unpack .../52-libnet-smtp-ssl-perl_1.04-1_all.deb ...
# Unpacking libnet-smtp-ssl-perl (1.04-1) ...
# Selecting previously unselected package libmailtools-perl.
# Preparing to unpack .../53-libmailtools-perl_2.21-1_all.deb ...
# Unpacking libmailtools-perl (2.21-1) ...
# Selecting previously unselected package libxml-parser-perl.
# Preparing to unpack .../54-libxml-parser-perl_2.46-1_amd64.deb ...
# Unpacking libxml-parser-perl (2.46-1) ...
# Selecting previously unselected package libxml-twig-perl.
# Preparing to unpack .../55-libxml-twig-perl_1%3a3.50-2_all.deb ...
# Unpacking libxml-twig-perl (1:3.50-2) ...
# Selecting previously unselected package libnet-dbus-perl.
# Preparing to unpack .../56-libnet-dbus-perl_1.2.0-1_amd64.deb ...
# Unpacking libnet-dbus-perl (1.2.0-1) ...
# Selecting previously unselected package libpaper-utils.
# Preparing to unpack .../57-libpaper-utils_1.1.28_amd64.deb ...
# Unpacking libpaper-utils (1.1.28) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../58-libptexenc1_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking libptexenc1:amd64 (2019.20190605.51237-3build2) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../59-rubygems-integration_1.16_all.deb ...
# Unpacking rubygems-integration (1.16) ...
# Selecting previously unselected package ruby2.7.
# Preparing to unpack .../60-ruby2.7_2.7.0-5ubuntu1.4_amd64.deb ...
# Unpacking ruby2.7 (2.7.0-5ubuntu1.4) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../61-ruby_1%3a2.7+1_amd64.deb ...
# Unpacking ruby (1:2.7+1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../62-rake_13.0.1-4_all.deb ...
# Unpacking rake (13.0.1-4) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../63-ruby-minitest_5.13.0-1_all.deb ...
# Unpacking ruby-minitest (5.13.0-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../64-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../65-ruby-power-assert_1.1.7-1_all.deb ...
# Unpacking ruby-power-assert (1.1.7-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../66-ruby-test-unit_3.3.5-1_all.deb ...
# Unpacking ruby-test-unit (3.3.5-1) ...
# Selecting previously unselected package ruby-xmlrpc.
# Preparing to unpack .../67-ruby-xmlrpc_0.3.0-2_all.deb ...
# Unpacking ruby-xmlrpc (0.3.0-2) ...
# Selecting previously unselected package libruby2.7:amd64.
# Preparing to unpack .../68-libruby2.7_2.7.0-5ubuntu1.4_amd64.deb ...
# Unpacking libruby2.7:amd64 (2.7.0-5ubuntu1.4) ...
# Selecting previously unselected package libsynctex2:amd64.
# Preparing to unpack .../69-libsynctex2_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking libsynctex2:amd64 (2019.20190605.51237-3build2) ...
# Selecting previously unselected package libteckit0:amd64.
# Preparing to unpack .../70-libteckit0_2.5.8+ds2-5ubuntu2_amd64.deb ...
# Unpacking libteckit0:amd64 (2.5.8+ds2-5ubuntu2) ...
# Selecting previously unselected package libtexlua53:amd64.
# Preparing to unpack .../71-libtexlua53_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking libtexlua53:amd64 (2019.20190605.51237-3build2) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../72-libtexluajit2_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2019.20190605.51237-3build2) ...
# Selecting previously unselected package libtie-ixhash-perl.
# Preparing to unpack .../73-libtie-ixhash-perl_1.23-2_all.deb ...
# Unpacking libtie-ixhash-perl (1.23-2) ...
# Selecting previously unselected package libx11-protocol-perl.
# Preparing to unpack .../74-libx11-protocol-perl_0.56-7_all.deb ...
# Unpacking libx11-protocol-perl (0.56-7) ...
# Selecting previously unselected package libxml-xpathengine-perl.
# Preparing to unpack .../75-libxml-xpathengine-perl_0.14-1_all.deb ...
# Unpacking libxml-xpathengine-perl (0.14-1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../76-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../77-libzzip-0-13_0.13.62-3.2ubuntu1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.2ubuntu1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../78-lmodern_2.004.5-6_all.deb ...
# Unpacking lmodern (2.004.5-6) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../79-preview-latex-style_11.91-2ubuntu2_all.deb ...
# Unpacking preview-latex-style (11.91-2ubuntu2) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../80-t1utils_1.41-3_amd64.deb ...
# Unpacking t1utils (1.41-3) ...
# Selecting previously unselected package teckit.
# Preparing to unpack .../81-teckit_2.5.8+ds2-5ubuntu2_amd64.deb ...
# Unpacking teckit (2.5.8+ds2-5ubuntu2) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../82-tex-gyre_20180621-3_all.deb ...
# Unpacking tex-gyre (20180621-3) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../83-texlive-binaries_2019.20190605.51237-3build2_amd64.deb ...
# Unpacking texlive-binaries (2019.20190605.51237-3build2) ...
# Selecting previously unselected package xdg-utils.
# Preparing to unpack .../84-xdg-utils_1.1.3-2ubuntu1.20.04.2_all.deb ...
# Unpacking xdg-utils (1.1.3-2ubuntu1.20.04.2) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../85-texlive-base_2019.20200218-1_all.deb ...
# Unpacking texlive-base (2019.20200218-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../86-texlive-fonts-recommended_2019.20200218-1_all.deb ...
# Unpacking texlive-fonts-recommended (2019.20200218-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../87-texlive-latex-base_2019.20200218-1_all.deb ...
# Unpacking texlive-latex-base (2019.20200218-1) ...
# Selecting previously unselected package libfontbox-java.
# Preparing to unpack .../88-libfontbox-java_1%3a1.8.16-2_all.deb ...
# Unpacking libfontbox-java (1:1.8.16-2) ...
# Selecting previously unselected package libpdfbox-java.
# Preparing to unpack .../89-libpdfbox-java_1%3a1.8.16-2_all.deb ...
# Unpacking libpdfbox-java (1:1.8.16-2) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../90-texlive-latex-recommended_2019.20200218-1_all.deb ...
# Unpacking texlive-latex-recommended (2019.20200218-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../91-texlive-pictures_2019.20200218-1_all.deb ...
# Unpacking texlive-pictures (2019.20200218-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../92-texlive-latex-extra_2019.202000218-1_all.deb ...
# Unpacking texlive-latex-extra (2019.202000218-1) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../93-texlive-plain-generic_2019.202000218-1_all.deb ...
# Unpacking texlive-plain-generic (2019.202000218-1) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../94-tipa_2%3a1.3-20_all.deb ...
# Unpacking tipa (2:1.3-20) ...
# Selecting previously unselected package texlive-xetex.
# Preparing to unpack .../95-texlive-xetex_2019.20200218-1_all.deb ...
# Unpacking texlive-xetex (2019.20200218-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../96-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../97-x11-xserver-utils_7.7+8_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+8) ...
# Selecting previously unselected package zip.
# Preparing to unpack .../98-zip_3.0-11build1_amd64.deb ...
# Unpacking zip (3.0-11build1) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../99-libauthen-sasl-perl_2.1600-1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1) ...
# Setting up libtext-iconv-perl (1.7-7) ...
# Setting up javascript-common (11) ...
# Setting up libpaper1:amd64 (1.1.28) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/papersize with new version
# Setting up libtie-ixhash-perl (1.23-2) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Setting up libfont-afm-perl (1.20-2) ...
# Setting up ruby-power-assert (1.1.7-1) ...
# Setting up libtexlua53:amd64 (2019.20190605.51237-3build2) ...
# Setting up libio-stringy-perl (2.111-3) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up libijs-0.35:amd64 (0.35-15) ...
# Setting up libauthen-sasl-perl (2.1600-1) ...
# Setting up libtexluajit2:amd64 (2019.20190605.51237-3build2) ...
# Setting up libfontbox-java (1:1.8.16-2) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libtry-tiny-perl (0.30-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up perl-openssl-defaults:amd64 (4) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up rubygems-integration (1.16) ...
# Setting up libzzip-0-13:amd64 (0.13.62-3.2ubuntu1) ...
# Setting up libpaper-utils (1.1.28) ...
# Setting up fonts-urw-base35 (20170801.1-3) ...
# Setting up x11-xserver-utils (7.7+8) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up ruby-minitest (5.13.0-1) ...
# Setting up tex-common (6.13) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up zip (3.0-11build1) ...
# Setting up ruby-test-unit (3.3.5-1) ...
# Setting up libdata-dump-perl (1.23-1) ...
# Setting up libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Setting up libipc-system-simple-perl (1.26-1) ...
# Setting up libteckit0:amd64 (2.5.8+ds2-5ubuntu2) ...
# Setting up libxml-xpathengine-perl (0.14-1) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up t1utils (1.41-3) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up fonts-texgyre (20180621-3) ...
# Setting up libkpathsea6:amd64 (2019.20190605.51237-3build2) ...
# Setting up libtimedate-perl (2.3200-1) ...
# Setting up x11-utils (7.7+5) ...
# Setting up fonts-lmodern (2.004.5-6) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libjs-jquery (3.3.1~dfsg-3) ...
# Setting up ruby-xmlrpc (0.3.0-2) ...
# Setting up tex-gyre (20180621-3) ...
# Setting up xdg-utils (1.1.3-2ubuntu1.20.04.2) ...
# Setting up liburi-perl (1.76-2) ...
# Setting up libx11-protocol-perl (0.56-7) ...
# Setting up libsynctex2:amd64 (2019.20190605.51237-3build2) ...
# Setting up libnet-ssleay-perl (1.88-2ubuntu1) ...
# Setting up libgs9-common (9.50~dfsg-5ubuntu4.2) ...
# Setting up teckit (2.5.8+ds2-5ubuntu2) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libfile-basedir-perl (0.08-1) ...
# Setting up libfile-listing-perl (6.04-1) ...
# Setting up libpdfbox-java (1:1.8.16-2) ...
# Setting up libgs9:amd64 (9.50~dfsg-5ubuntu4.2) ...
# Setting up preview-latex-style (11.91-2ubuntu2) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up dvisvgm (2.8.1-1build1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libnet-http-perl (6.19-1) ...
# Setting up libptexenc1:amd64 (2019.20190605.51237-3build2) ...
# Setting up libfile-desktopentry-perl (0.22-1) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up texlive-binaries (2019.20190605.51237-3build2) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/bibtex.1.gz because associated file /usr/share/man/man1/bibtex.original.1.gz (of link group bibtex) doesn't exist
# Setting up lmodern (2.004.5-6) ...
# Setting up libhtml-parser-perl (3.72-5) ...
# Setting up texlive-base (2019.20200218-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libio-socket-ssl-perl (2.067-1) ...
# Setting up libhttp-message-perl (6.22-1) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libfile-mimeinfo-perl (0.29-1) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up libhttp-cookies-perl (6.08-1) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up texlive-plain-generic (2019.202000218-1) ...
# Setting up libhtml-format-perl (2.12-1) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up texlive-latex-base (2019.20200218-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up texlive-latex-recommended (2019.20200218-1) ...
# Setting up texlive-pictures (2019.20200218-1) ...
# Setting up libhttp-daemon-perl (6.06-1) ...
# Setting up texlive-fonts-recommended (2019.20200218-1) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up texlive-latex-extra (2019.202000218-1) ...
# Setting up texlive-xetex (2019.20200218-1) ...
# Setting up ruby (1:2.7+1) ...
# Setting up rake (13.0.1-4) ...
# Setting up liblwp-protocol-https-perl (6.07-2ubuntu2) ...
# Setting up libwww-perl (6.43-1) ...
# Setting up libruby2.7:amd64 (2.7.0-5ubuntu1.4) ...
# Setting up libxml-parser-perl (2.46-1) ...
# Setting up libxml-twig-perl (1:3.50-2) ...
# Setting up ruby2.7 (2.7.0-5ubuntu1.4) ...
# Setting up libnet-dbus-perl (1.2.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.1) ...
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-cfg.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-ml.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-compiler.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libcuda.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-ptxjitcompiler.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-opencl.so.455.23.05 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-allocator.so.455.23.05 is empty, not checked.
# Processing triggers for tex-common (6.13) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 743 kB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-macosx_10_9_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 441 kB/s eta 0:00:011
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ribr/.virtualenvs/ultron/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /Users/ribr/.virtualenvs/ultron/lib/python3.7/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ribr/.virtualenvs/ultron/lib/python3.7/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/ribr/.virtualenvs/ultron/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in /Users/ribr/.virtualenvs/ultron/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2
