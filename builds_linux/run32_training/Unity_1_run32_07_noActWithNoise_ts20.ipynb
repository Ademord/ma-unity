# %% [markdown]
# # 🚀 Install, Import, and Log In

# %%
import mlagents
from mlagents_envs.environment import UnityEnvironment as UE
from mlagents_envs.environment import ActionTuple, BaseEnv
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
# import matplotlib.pyplot as plt
# %matplotlib inline
import random
from functools import wraps
from time import time


import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from tqdm.notebook import tqdm
from ipywidgets import IntProgress

from typing import Tuple, Dict
from math import floor

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
def measure(func):
    @wraps(func)
    def _time_it(*args, **kwargs):
        start = int(round(time() * 1000))
        try:
            return func(*args, **kwargs)
        finally:
            end_ = int(round(time() * 1000)) - start
            print(f"Total execution time: {end_/(1000*60) if end_ > 0 else 0} minutes")
    return _time_it

# %% [markdown]
# ### 0️⃣ Step 0: Install W&B

# %%
# %%capture
# !pip install wandb

# %% [markdown]
# ### 1️⃣ Step 1: Import W&B and Login

# %%
import wandb

wandb.login()
# Out:
# True

# %% [markdown]
# # 👩‍🔬 Define the Experiment and Pipeline

# %% [markdown]
# ### 2️⃣ Step 2: Track metadata and hyperparameters with `wandb.init`

# %%
config = dict(
    epochs=5,
    classes=10,
    kernels=[16, 32],
    batch_size=128,
    learning_rate=0.001,
    dataset="MNIST",
    architecture="CNN",
    NUM_TRAINING_STEPS = 100000, #10000000
    NUM_TEST_STEPS = 10,
    NUM_NEW_EXP = 1000,
    BUFFER_SIZE = 10000,
    worker_id=0,
    time_scale=20,
    no_graphics = True
    )
env = None

# %%
def model_pipeline(hyperparameters):
    global env
    
    try:
        env.close()
    except:
        pass

    # tell wandb to get started
    with wandb.init(project="pytorch-DQN", config=hyperparameters):
        # access all HPs through wandb.config, so logging matches execution!
        config = wandb.config

        # make the model, data, and optimization problem
        model, env, criterion, optimizer = make(config)
        print(model)

        # and use them to train the model
        train(model, env, criterion, optimizer, config)

        # and test its final performance
        test(model, env, config)

        env.close()

    return model

# %%
def make(config):
    # Make the data
    env, spec = make_env(config)
    
    # Make the model
    # model = Agent(config.kernels, config.classes).to(device)
    model = QNetwork((44, 1), 126, 3)

    # Make the loss and optimizer
    criterion = torch.nn.MSELoss() # None # nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
    
    return model, env, criterion, optimizer

# %% [markdown]
# # 📡 Define the Env Loading and Model

# %%
def make_env(config):
    channel = EngineConfigurationChannel()
    env = UE("run32_training", seed=1, worker_id=config.worker_id, no_graphics=config.no_graphics, side_channels=[channel])
    channel.set_configuration_parameters(time_scale = config.time_scale)
    print("Environment created.")
    
    env.reset()
    behavior_name = list(env.behavior_specs)[0]
    print(f"Name of the behavior : {behavior_name}")
    
    spec = env.behavior_specs[behavior_name]
    print(f"Type of the spec : {spec}")
    
    return env, spec

# %%
class QNetwork(torch.nn.Module):
    def __init__(
        self,
        input_shape: Tuple[int], 
        encoding_size: int, 
        output_size: int
    ):
        """
        Creates a neural network that takes as input a batch of images (3
        dimensional tensors) and outputs a batch of outputs (1 dimensional
        tensors)
        """
        super(QNetwork, self).__init__()
        self.dense1 = torch.nn.Linear(input_shape[0], encoding_size)
        self.dense2 = torch.nn.Linear(encoding_size, encoding_size)

        self.dense2_x1 = torch.nn.Linear(encoding_size, output_size)
        self.dense2_x2 = torch.nn.Linear(encoding_size, output_size)
        self.dense2_x3 = torch.nn.Linear(encoding_size, output_size)

        self.act = torch.nn.ReLU()
        self.act_out = torch.nn.Sigmoid() # ReLU

    def forward(self, visual_obs: torch.tensor):
        hidden = self.dense1(visual_obs)
        hidden = self.act(hidden)
        hidden = self.dense2(hidden)
        hidden = self.act(hidden)
        x1 = self.dense2_x1(hidden)
        x2 = self.dense2_x2(hidden)
        x3 = self.dense2_x3(hidden)

        #     x1 = self.act(x1)
        #     x2 = self.act(x2)
        #     x3 = self.act(x3)

        return x1, x2, x3

# %%
import numpy as np
from typing import NamedTuple, List


class Experience(NamedTuple):
    """
    An experience contains the data of one Agent transition.
    - Observation
    - Action
    - Reward
    - Done flag
    - Next Observation
    """

    obs: np.ndarray
    action: np.ndarray
    reward: float
    done: bool
    next_obs: np.ndarray

# A Trajectory is an ordered sequence of Experiences
Trajectory = List[Experience]

# A Buffer is an unordered list of Experiences from multiple Trajectories
Buffer = List[Experience]

# %%
from mlagents_envs.environment import ActionTuple, BaseEnv
from typing import Dict
import random


class Trainer:
  @staticmethod
  def generate_trajectories(
    env: BaseEnv, q_net: QNetwork, buffer_size: int, epsilon: float
  ):
    """
    Given a Unity Environment and a Q-Network, this method will generate a
    buffer of Experiences obtained by running the Environment with the Policy
    derived from the Q-Network.
    :param BaseEnv: The UnityEnvironment used.
    :param q_net: The Q-Network used to collect the data.
    :param buffer_size: The minimum size of the buffer this method will return.
    :param epsilon: Will add a random normal variable with standard deviation.
    epsilon to the value heads of the Q-Network to encourage exploration.
    :returns: a Tuple containing the created buffer and the average cumulative
    the Agents obtained.
    """
    # Create an empty Buffer
    buffer: Buffer = []

    # Reset the environment
    env.reset()
    # Read and store the Behavior Name of the Environment
    behavior_name = list(env.behavior_specs)[0]
    # Read and store the Behavior Specs of the Environment
    spec = env.behavior_specs[behavior_name]

    # Create a Mapping from AgentId to Trajectories. This will help us create
    # trajectories for each Agents
    dict_trajectories_from_agent: Dict[int, Trajectory] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_obs_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_action_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to cumulative reward (Only for reporting)
    dict_cumulative_reward_from_agent: Dict[int, float] = {}
    # Create a list to store the cumulative rewards obtained so far
    cumulative_rewards: List[float] = []
    
    
    entered_terminal = False
    while len(buffer) < buffer_size:  # While not enough data in the buffer
      # Get the Decision Steps and Terminal Steps of the Agents
      decision_steps, terminal_steps = env.get_steps(behavior_name)
    
        # For all Agents with a Terminal Step:
      for agent_id_terminated in terminal_steps:
#         print("entered agent with terminal step")
#         print(agent_id_terminated)

        # Create its last experience (is last because the Agent terminated)
        last_experience = Experience(
          obs=dict_last_obs_from_agent[agent_id_terminated].copy(),
          reward=terminal_steps[agent_id_terminated].reward,
          done=not terminal_steps[agent_id_terminated].interrupted,
          action=dict_last_action_from_agent[agent_id_terminated].copy(),
          next_obs=terminal_steps[agent_id_terminated].obs[0],
        )
        # Clear its last observation and action (Since the trajectory is over)
        dict_last_obs_from_agent.pop(agent_id_terminated)
        dict_last_action_from_agent.pop(agent_id_terminated)
        # Report the cumulative reward
        cumulative_reward = (
          dict_cumulative_reward_from_agent.pop(agent_id_terminated)
          + terminal_steps[agent_id_terminated].reward
        )
#         print("cumulative reward: ", cumulative_reward)
        cumulative_rewards.append(cumulative_reward) #  - 50
        # Add the Trajectory and the last experience to the buffer
        buffer.extend(dict_trajectories_from_agent.pop(agent_id_terminated))
        buffer.append(last_experience)
        entered_terminal = True

      # For all Agents with a Decision Step:
      for agent_id_decisions in decision_steps:
        # If the Agent does not have a Trajectory, create an empty one
        if agent_id_decisions not in dict_trajectories_from_agent:
          dict_trajectories_from_agent[agent_id_decisions] = []
          dict_cumulative_reward_from_agent[agent_id_decisions] = 0

        # If the Agent requesting a decision has a "last observation"
        if agent_id_decisions in dict_last_obs_from_agent:
          # Create an Experience from the last observation and the Decision Step
          exp = Experience(
            obs=dict_last_obs_from_agent[agent_id_decisions].copy(),
            reward=decision_steps[agent_id_decisions].reward, #  - 0.05
            done=False,
            action=dict_last_action_from_agent[agent_id_decisions].copy(),
            next_obs=decision_steps[agent_id_decisions].obs[0],
          )
          # Update the Trajectory of the Agent and its cumulative reward
          dict_trajectories_from_agent[agent_id_decisions].append(exp)
          dict_cumulative_reward_from_agent[agent_id_decisions] += (
            decision_steps[agent_id_decisions].reward
          )
        # Store the observation as the new "last observation"
        dict_last_obs_from_agent[agent_id_decisions] = (
          decision_steps[agent_id_decisions].obs[0]
        )

      # Generate an action for all the Agents that requested a decision
      # Compute the values for each action given the observation    
      act1, act2, act3 = q_net(torch.from_numpy(decision_steps.obs[0]))
    
      if len(decision_steps) == 0:
#             print("error: no more observations ! ")
            env.step()
            continue
#       if act1.size == 0:
#             print("error: Action space received = 0")
#             env.step()
#             continue
            
      # get actions as arrays
      act1 = act1.detach().numpy()
      act2 = act2.detach().numpy()
      act3 = act3.detach().numpy()
    
#       print("action received from QNetwork: ", act1)
#       print("action received from QNetwork: ", act2)
#       print("action received from QNetwork: ", act3)
      act1 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      act2 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      act3 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      
      # pick the best action using argmax
      act1 = np.argmax(act1, axis=1)
      act2 = np.argmax(act2, axis=1)
      act3 = np.argmax(act3, axis=1)
#       print("action received from argmax: ", act1)
#       print("action received from argmax: ", act1.shape)
#       act1 = np.array([act1])
#       act2 = np.array([act2])
#       act3 = np.array([act3])
      act1 = np.expand_dims(act1, axis=1)
      act2 = np.expand_dims(act2, axis=1)
      act3 = np.expand_dims(act3, axis=1)
#       print("action received from argmax expanded: ", act1)
#       print("action received from argmax expanded: ", act1.shape)

      # map action index 2 to -1 for the agent to move backwards, left, and rotate left
      act1[act1 > 1] = -1
      act2[act2 > 1] = -1
      act3[act3 > 1] = -1

      # format to numpy arrays
#       print("action received from mapping: ", act1)
#       try:
# #         actions_values = np.array([act1, act2, act3]).reshape(3,3)
#         actions_values = np.vstack((act1, act2, act3))
#       except:
#         actions_values = np.zeros((3,3))
#         print("error: network received an input of size 0 and i caught the error :/")

        #      0-8nt(type(actions_values))
    
    
#       actions =  np.vstack((act1, act2, act3))
#       actions =  np.vstack((act1, act2, act3))

      temp = np.hstack((act1, act2, act3))
#       print("actions stacked with hstack:", temp)
#       print("actions stacked with hstack: shape:", temp.shape)
#       temp = np.concatenate((act1, act2, act3), axis=1)
#       print("actions stacked with concat:", temp)
#       print("actions stacked with concat: shape:", temp.shape)
        
#       actions_values = np.zeros((3,3))
#       # Add some noise with epsilon to the values
#       actions_values += epsilon * np.random.randn(actions_values.shape[0], actions_values.shape[1]).astype(np.float32)
#       actions = np.argmax(actions_values, axis=1)
      
      actions = temp
#       print("final actions: ", actions)
#       print("final actions shape: ", actions.shape)
      actions.resize((len(decision_steps), 3))
#       print("decision steps size:", len(decision_steps))
#       print("final actions after resize: ", actions)
#       print("final actions shape: ", actions.shape)


      # Store the action that was picked, it will be put in the trajectory later
      for agent_index, agent_id in enumerate(decision_steps.agent_id):
        dict_last_action_from_agent[agent_id] = actions[agent_index]
#       print("dict last action: ", dict_last_action_from_agent)

        
      # Set the actions in the environment
      # Unity Environments expect ActionTuple instances.
      action_tuple = ActionTuple()
      action_tuple.add_discrete(actions)
#       print("filtered action received from QNetwork: ", action_tuple.discrete)
      env.set_actions(behavior_name, action_tuple)
      # Perform a step in the simulation
      env.step()
    return buffer, np.mean(cumulative_rewards)

  @staticmethod
  def update_q_net(
    q_net: QNetwork, 
    criterion: torch.nn.modules.loss,
    optimizer: torch.optim, 
    buffer: Buffer, 
    action_size: int
  ):
    """
    Performs an update of the Q-Network using the provided optimizer and buffer
    """
    def calculate_bellman_loss(next_pred_action, pred_action, reward, done, GAMMA, batch, action_size, action):
        # Use the Bellman equation to update the Q-Network
        target = (
          reward
          + (1.0 - done)
          * GAMMA
          * torch.max(next_pred_action.detach(), dim=1, keepdim=True).values
        ).double()
#         print("next_act_prediction:", next_pred_action.detach().numpy())
        
#         print("Target:", target)
#         print("Target shape:", target.shape)

#         print("action:", action)
#         print("action shape: ", action.shape)
        assert(action.shape[0] == len(batch))
        action[action < 0] = 2
#         print("action after correction:", action)
        
        mask = np.eye(action_size)[action]
#         mask = torch.zeros((len(batch), action_size))  
#         print("mask: ", mask)
#         print("mask shape: ", mask.shape)
#         mask.scatter_(1, action, 1)
#         print("mask after scatter: ", mask)
        mask = torch.from_numpy(mask).double()
#         print("pred_action: error", pred_action)
#         print(type(pred_action))
#         print(pred_action.dtype)
#         print(type(mask))
#         print(mask.dtype)
        prediction = torch.sum(pred_action.double() * mask, dim=1, keepdim=True)
#         print("act_prediction:", pred_action.detach().numpy())
#         print("prediction: ", prediction)
#         print("prediction shaPE: ", prediction.shape)
#         print("prediction type: ", type(prediction))
#         print("prediction dtype: ", prediction.dtype)
        
        criterion = torch.nn.MSELoss()
        loss = criterion(prediction, target)
        
        return loss

    BATCH_SIZE = 1000
    NUM_EPOCH = 3
    GAMMA = 0.9
    batch_size = min(len(buffer), BATCH_SIZE)
    random.shuffle(buffer)
    # Split the buffer into batches
    batches = [
      buffer[batch_size * start : batch_size * (start + 1)]
      for start in range(int(len(buffer) / batch_size))
    ]
    for _ in range(NUM_EPOCH):
      for batch in batches:
        # Create the Tensors that will be fed in the network
        obs = torch.from_numpy(np.stack([ex.obs for ex in batch]))
        reward = torch.from_numpy(
          np.array([ex.reward for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        done = torch.from_numpy(
          np.array([ex.done for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        action = torch.from_numpy(np.stack([ex.action for ex in batch]))
        next_obs = torch.from_numpy(np.stack([ex.next_obs for ex in batch]))
        
        # Prerequisite: collect outputs
        pnext_a1, pnext_a2, pnext_a3 = q_net(next_obs)
        p_a1, p_a2, p_a3 = q_net(obs)
        
        # bellman equation for each loss
        loss1 = calculate_bellman_loss(pnext_a1, p_a1, reward, done, GAMMA, batch, action_size, action[:, 0])
        loss2 = calculate_bellman_loss(pnext_a2, p_a2, reward, done, GAMMA, batch, action_size, action[:, 1])
        loss3 = calculate_bellman_loss(pnext_a3, p_a3, reward, done, GAMMA, batch, action_size, action[:, 2])
        loss = loss1 + loss2 + loss3
        
        # Perform the backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# # 👟 Define Training Logic

# %% [markdown]
# ### 3️⃣ Step 3. Track gradients with `wandb.watch` and everything else with `wandb.log`

# %%
@measure
def train(model, env, criterion, optimizer, config):
    wandb.watch(model, criterion, log="all", log_freq=10)
    experiences: Buffer = []

    cumulative_rewards: List[float] = []
    NUM_NEW_EXP = config.NUM_NEW_EXP
    BUFFER_SIZE = config.BUFFER_SIZE

    behavior_name = list(env.behavior_specs)[0]
        
    for episode in range(config.NUM_TRAINING_STEPS):
        new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
        random.shuffle(experiences)
        if len(experiences) > BUFFER_SIZE:
            experiences = experiences[:BUFFER_SIZE]
        experiences.extend(new_exp)
        Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
        _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
        cumulative_rewards.append(rewards)
        # print("Training step ", episode + 1, "\treward ", episode_rewards)
        train_log(rewards, episode)

# %%
# @measure
# def train(model, env, criterion, optimizer, config):
# #     wandb.watch(model, criterion, log="all", log_freq=10)

#     behavior_name = list(env.behavior_specs)[0]
        
#     for episode in range(config.NUM_TRAINING_STEPS):
#         env.reset()
#         decision_steps, terminal_steps = env.get_steps(behavior_name)
#         tracked_agent = -1 # -1 indicates not yet tracking
#         done = False # For the tracked_agent
#         episode_rewards = 0 # For the tracked_agent
        
#         while not done:
#             # Track the first agent we see if not tracking 
#             # Note : len(decision_steps) = [numberb of agents that requested a decision]
#             if tracked_agent == -1 and len(decision_steps) >= 1:
#                 tracked_agent = decision_steps.agent_id[0] 

#             # Generate an action for all agents
#             # these are the observations
# #             print(decision_steps[0])
#             action = model.get_action(decision_steps)
#     #         print(action.discrete)
#             # Set the actions
#             env.set_actions(behavior_name, action)

#             # Move the simulation forward
#             env.step()

#             # Get the new simulation results
#             decision_steps, terminal_steps = env.get_steps(behavior_name)
#             if tracked_agent in decision_steps: # The agent requested a decision
#                 episode_rewards += decision_steps[tracked_agent].reward
#             if tracked_agent in terminal_steps: # The agent terminated its episode
#                 print("reward on terminal step:", terminal_steps[tracked_agent].reward)
#                 episode_rewards += terminal_steps[tracked_agent].reward
#                 done = True
#         # print("Training step ", episode + 1, "\treward ", episode_rewards)
#         train_log(episode_rewards, episode)

# %%
def train_log(reward, episode):
#     loss = float(loss)
    reward = float(reward)
    episode +=1
    
    # where the magic happens
    wandb.log({"episode": episode, "reward": reward}) #, step=example_ct
    print(f"Reward after " + str(episode).zfill(5) + f" episodes: {reward:.3f}")

# %% [markdown]
# # 🧪 Define Testing Logic

# %% [markdown]
# #### 4️⃣ Optional Step 4: Call `wandb.save`

# %%
def test(model, env, config):
    model.eval()

    # Run the model on some test examples
    with torch.no_grad():
        experiences: Buffer = []
        cumulative_rewards: List[float] = []
        NUM_NEW_EXP = config.NUM_NEW_EXP
        BUFFER_SIZE = config.BUFFER_SIZE

        behavior_name = list(env.behavior_specs)[0]

        for episode in range(config.NUM_TEST_STEPS):
            new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
            random.shuffle(experiences)
            if len(experiences) > BUFFER_SIZE:
                experiences = experiences[:BUFFER_SIZE]
            experiences.extend(new_exp)
#                 Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
            _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
            cumulative_rewards.append(rewards)
            # print("Training step ", episode + 1, "\treward ", episode_rewards)

        print(f"Average reward of the model after {config.NUM_TEST_STEPS} " +
              f"test episodes: {numpy.mean(cumulative_rewards)}%")

        wandb.log({"test_average_reward": numpy.mean(cumulative_rewards)})

    # Save the model in the exchangeable ONNX format
    torch.onnx.export(model, [], "model.onnx")
    wandb.save("model.onnx")

# %% [markdown]
# # 🏃‍♀️ Run training and watch your metrics live on [wandb.ai](https://wandb.ai)!

# %%
# Build, train and analyze the model with the pipeline
model, env = model_pipeline(config)
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">still-dragon-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ademord/pytorch-DQN" target="_blank">https://wandb.ai/ademord/pytorch-DQN</a><br/>
#                 Run page: <a href="https://wandb.ai/ademord/pytorch-DQN/runs/3dopwv83" target="_blank">https://wandb.ai/ademord/pytorch-DQN/runs/3dopwv83</a><br/>
#                 Run data is saved locally in <code>/host/unity_builds/run32_training/wandb/run-20210604_211315-3dopwv83</code><br/><br/>
# Environment created.
# Name of the behavior : Hummingbird?team=0
# Type of the spec : BehaviorSpec(observation_specs=[ObservationSpec(shape=(44,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='RayPerceptionSensor'), ObservationSpec(shape=(3,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='StackingSensor_size3_VectorSensor_size1')], action_spec=ActionSpec(continuous_size=0, discrete_branches=(3, 3, 3)))
# QNetwork(
#   (dense1): Linear(in_features=44, out_features=126, bias=True)
#   (dense2): Linear(in_features=126, out_features=126, bias=True)
#   (dense2_x1): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x2): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x3): Linear(in_features=126, out_features=3, bias=True)
#   (act): ReLU()
#   (act_out): Sigmoid()
# )
# Reward after 00001 episodes: 6.029
# Reward after 00002 episodes: 0.042
# Reward after 00003 episodes: 1.612
# Reward after 00004 episodes: 39.285
# Reward after 00005 episodes: 40.256
# Reward after 00006 episodes: -1.000
# Reward after 00007 episodes: 272.247
# Reward after 00008 episodes: 62.615
# Reward after 00009 episodes: -1.000
# Reward after 00010 episodes: -1.000
# Reward after 00011 episodes: -1.000
# Reward after 00012 episodes: 19.451
# Reward after 00013 episodes: 1.863
# Reward after 00014 episodes: 49.759
# Reward after 00015 episodes: -1.000
# Reward after 00016 episodes: -1.000
# Reward after 00017 episodes: 355.237
# Reward after 00018 episodes: 45.872
# Reward after 00019 episodes: 360.494
# Reward after 00020 episodes: -1.000
# Reward after 00021 episodes: 679.166
# Reward after 00022 episodes: -1.000
# Reward after 00023 episodes: -1.000
# Reward after 00024 episodes: 55.796
# Reward after 00025 episodes: 746.125
# Reward after 00026 episodes: 743.608
# Reward after 00027 episodes: 750.089
# Reward after 00028 episodes: 741.671
# Reward after 00029 episodes: 746.709
# Reward after 00030 episodes: 744.732
# Reward after 00031 episodes: 746.099
# Reward after 00032 episodes: 750.290
# Reward after 00033 episodes: 746.930
# Reward after 00034 episodes: 726.164
# Reward after 00035 episodes: 745.917
# Reward after 00036 episodes: 747.656
# Reward after 00037 episodes: 745.929
# Reward after 00038 episodes: 745.578
# Reward after 00039 episodes: 745.687
# Reward after 00040 episodes: 571.142
# Reward after 00041 episodes: 749.801
# Reward after 00042 episodes: 473.029
# Reward after 00043 episodes: 736.065
# Reward after 00044 episodes: 209.828
# Reward after 00045 episodes: 0.000
# Reward after 00046 episodes: 738.336
# Reward after 00047 episodes: 15.884
# Reward after 00048 episodes: 501.639
# Reward after 00049 episodes: 58.559
# Reward after 00050 episodes: 75.960
# Reward after 00051 episodes: 98.341
# Reward after 00052 episodes: 102.999
# Reward after 00053 episodes: -1.000
# Reward after 00054 episodes: -1.000
# Reward after 00055 episodes: 390.520
# Reward after 00056 episodes: 189.912
# Reward after 00057 episodes: 38.603
# Reward after 00058 episodes: 618.991
# Reward after 00059 episodes: -1.000
# Reward after 00060 episodes: -1.000
# Reward after 00061 episodes: 37.985
# Reward after 00062 episodes: -1.000
# Reward after 00063 episodes: 670.101
# Reward after 00064 episodes: 707.077
# Reward after 00065 episodes: 46.374
# Reward after 00066 episodes: 26.082
# Reward after 00067 episodes: 34.885
# Reward after 00068 episodes: 669.288
# Reward after 00069 episodes: 673.773
# Reward after 00070 episodes: 355.973
# Reward after 00071 episodes: 32.031
# Reward after 00072 episodes: 30.719
# Reward after 00073 episodes: 43.448
# Reward after 00074 episodes: 38.232
# Reward after 00075 episodes: 668.720
# Reward after 00076 episodes: 396.051
# Reward after 00077 episodes: 664.105
# Reward after 00078 episodes: 562.355
# Reward after 00079 episodes: 601.006
# Reward after 00080 episodes: 600.222
# Reward after 00081 episodes: 625.269
# Reward after 00082 episodes: 339.025
# Reward after 00083 episodes: 650.444
# Reward after 00084 episodes: 683.140
# Reward after 00085 episodes: 652.507
# Reward after 00086 episodes: 679.732
# Reward after 00087 episodes: 643.550
# Reward after 00088 episodes: 658.616
# Reward after 00089 episodes: 651.880
# Reward after 00090 episodes: 38.427
# Reward after 00091 episodes: 27.344
# Reward after 00092 episodes: 655.402
# Reward after 00093 episodes: 1.923
# Reward after 00094 episodes: 34.486
# Reward after 00095 episodes: 13.046
# Reward after 00096 episodes: 13.251
# Reward after 00097 episodes: 21.255
# Reward after 00098 episodes: 22.648
# Reward after 00099 episodes: 27.966
# Reward after 00100 episodes: 18.328
# Reward after 00101 episodes: 16.422
# Reward after 00102 episodes: 29.580
# Reward after 00103 episodes: 9.980
# Reward after 00104 episodes: 25.040
# Reward after 00105 episodes: 5.645
# Reward after 00106 episodes: 11.710
# Reward after 00107 episodes: 7.523
# Reward after 00108 episodes: 716.919
# Reward after 00109 episodes: 7.137
# Reward after 00110 episodes: 10.700
# Reward after 00111 episodes: 30.083
# Reward after 00112 episodes: 0.082
# Reward after 00113 episodes: 14.356
# Reward after 00114 episodes: 1.334
# Reward after 00115 episodes: 13.850
# Reward after 00116 episodes: 2.127
# Reward after 00117 episodes: 20.912
# Reward after 00118 episodes: 9.308
# Reward after 00119 episodes: 8.415
# Reward after 00120 episodes: 28.838
# Reward after 00121 episodes: 8.316
# Reward after 00122 episodes: 9.705
# Reward after 00123 episodes: 733.989
# Reward after 00124 episodes: -1.000
# Reward after 00125 episodes: 732.466
# Reward after 00126 episodes: 733.659
# Reward after 00127 episodes: 32.017
# Reward after 00128 episodes: 23.601
# Reward after 00129 episodes: 25.993
# Reward after 00130 episodes: 734.091
# Reward after 00131 episodes: 735.232
# Reward after 00132 episodes: 737.899
# Reward after 00133 episodes: 734.358
# Reward after 00134 episodes: 736.033
# Reward after 00135 episodes: 736.823
# Reward after 00136 episodes: 730.492
# Reward after 00137 episodes: 734.179
# Reward after 00138 episodes: 735.137
# Reward after 00139 episodes: 735.583
# Reward after 00140 episodes: 732.748
# Reward after 00141 episodes: 732.159
# Reward after 00142 episodes: 735.026
# Reward after 00143 episodes: 734.450
# Reward after 00144 episodes: 734.366
# Reward after 00145 episodes: 736.157
# Reward after 00146 episodes: 736.467
# Reward after 00147 episodes: 736.360
# Reward after 00148 episodes: 737.339
# Reward after 00149 episodes: 31.774
# Reward after 00150 episodes: -1.000
# Reward after 00151 episodes: 737.564
# Reward after 00152 episodes: 703.258
# Reward after 00153 episodes: 326.309
# Reward after 00154 episodes: 734.699
# Reward after 00155 episodes: 514.326
# Reward after 00156 episodes: 206.494
# Reward after 00157 episodes: 232.204
# Reward after 00158 episodes: 653.581
# Reward after 00159 episodes: 9.805
# Reward after 00160 episodes: -1.000
# Reward after 00161 episodes: 270.885
# Reward after 00162 episodes: 142.492
# Reward after 00163 episodes: -1.000
# Reward after 00164 episodes: -1.000
# Reward after 00165 episodes: 5.842
# Reward after 00166 episodes: 10.151
# Reward after 00167 episodes: 9.377
# Reward after 00168 episodes: 0.842
# Reward after 00169 episodes: 17.243
# Reward after 00170 episodes: 15.919
# Reward after 00171 episodes: 15.363
# Reward after 00172 episodes: 13.217
# Reward after 00173 episodes: 18.088
# Reward after 00174 episodes: 11.800
# Reward after 00175 episodes: 14.921
# Reward after 00176 episodes: 15.737
# Reward after 00177 episodes: 7.777
# Reward after 00178 episodes: -1.000
# Reward after 00179 episodes: 39.847
# Reward after 00180 episodes: 54.058
# Reward after 00181 episodes: 50.819
# Reward after 00182 episodes: 17.720
# Reward after 00183 episodes: 735.498
# Reward after 00184 episodes: 14.550
# Reward after 00185 episodes: 76.637
# Reward after 00186 episodes: 94.249
# Reward after 00187 episodes: 373.263
# Reward after 00188 episodes: 51.797
# Reward after 00189 episodes: 21.840
# Reward after 00190 episodes: 1.005
# Reward after 00191 episodes: 58.517
# Reward after 00192 episodes: 13.797
# Reward after 00193 episodes: 14.718
# Reward after 00194 episodes: 17.864
# Reward after 00195 episodes: 6.797
# Reward after 00196 episodes: 8.675
# Reward after 00197 episodes: 286.139
# Reward after 00198 episodes: 26.581
# Reward after 00199 episodes: 21.144
# Reward after 00200 episodes: 15.720
# Reward after 00201 episodes: 8.499
# Reward after 00202 episodes: 12.460
# Reward after 00203 episodes: 17.934
# Reward after 00204 episodes: 10.464
# Reward after 00205 episodes: 5.898
# Reward after 00206 episodes: 10.618
# Reward after 00207 episodes: 14.306
# Reward after 00208 episodes: 34.537
# Reward after 00209 episodes: 9.178
# Reward after 00210 episodes: -0.545
# Reward after 00211 episodes: 5.529
# Reward after 00212 episodes: 6.633
# Reward after 00213 episodes: 9.216
# Reward after 00214 episodes: 7.535
# Reward after 00215 episodes: 7.817
# Reward after 00216 episodes: 5.164
# Reward after 00217 episodes: 18.111
# Reward after 00218 episodes: 5.279
# Reward after 00219 episodes: 9.022
# Reward after 00220 episodes: 0.280
# Reward after 00221 episodes: 6.174
# Reward after 00222 episodes: 3.958
# Reward after 00223 episodes: 4.292
# Reward after 00224 episodes: 1.054
# Reward after 00225 episodes: 1.593
# Reward after 00226 episodes: 1.497
# Reward after 00227 episodes: 27.442
# Reward after 00228 episodes: 2.667
# Reward after 00229 episodes: 0.344
# Reward after 00230 episodes: 9.297
# Reward after 00231 episodes: -0.553
# Reward after 00232 episodes: 3.869
# Reward after 00233 episodes: 7.924
# Reward after 00234 episodes: 9.982
# Reward after 00235 episodes: 14.884
# Reward after 00236 episodes: 11.249
# Reward after 00237 episodes: 11.206
# Reward after 00238 episodes: 9.507
# Reward after 00239 episodes: 12.373
# Reward after 00240 episodes: 21.749
# Reward after 00241 episodes: 12.041
# Reward after 00242 episodes: 15.370
# Reward after 00243 episodes: 24.000
# Reward after 00244 episodes: 8.795
# Reward after 00245 episodes: 6.570
# Reward after 00246 episodes: 0.579
# Reward after 00247 episodes: 26.668
# Reward after 00248 episodes: 10.368
# Reward after 00249 episodes: 7.859
# Reward after 00250 episodes: 11.649
# Reward after 00251 episodes: -1.000
# Reward after 00252 episodes: 3.406
# Reward after 00253 episodes: -0.458
# Reward after 00254 episodes: 17.691
# Reward after 00255 episodes: 15.656
# Reward after 00256 episodes: 0.000
# Reward after 00257 episodes: 3.627
# Reward after 00258 episodes: -1.000
# Reward after 00259 episodes: 0.000
# Reward after 00260 episodes: 3.252
# Reward after 00261 episodes: 20.042
# Reward after 00262 episodes: 0.580
# Reward after 00263 episodes: 1.247
# Reward after 00264 episodes: 12.331
# Reward after 00265 episodes: 1.306
# Reward after 00266 episodes: -1.000
# Reward after 00267 episodes: -1.000
# Reward after 00268 episodes: 0.075
# Reward after 00269 episodes: -1.000
# Reward after 00270 episodes: 0.000
# Reward after 00271 episodes: 0.158
# Reward after 00272 episodes: 0.394
# Reward after 00273 episodes: -1.000
# Reward after 00274 episodes: 0.295
# Reward after 00275 episodes: 0.000
# Reward after 00276 episodes: 0.069
# Reward after 00277 episodes: 0.000
# Reward after 00278 episodes: 0.000
# Reward after 00279 episodes: 0.000
# Reward after 00280 episodes: 0.000
# Reward after 00281 episodes: 0.912
# Reward after 00282 episodes: 0.000
# Reward after 00283 episodes: -1.000
# Reward after 00284 episodes: -1.000
# Reward after 00285 episodes: 27.258
# Reward after 00286 episodes: 31.703
# Reward after 00287 episodes: 38.189
# Reward after 00288 episodes: 6.450
# Reward after 00289 episodes: 29.799
# Reward after 00290 episodes: 47.967
# Reward after 00291 episodes: 24.212
# Reward after 00292 episodes: 42.442
# Reward after 00293 episodes: 18.557
# Reward after 00294 episodes: 7.417
# Reward after 00295 episodes: 37.263
# Reward after 00296 episodes: 38.177
# Reward after 00297 episodes: 42.921
# Reward after 00298 episodes: 23.959
# Reward after 00299 episodes: 18.688
# Reward after 00300 episodes: 36.650
# Reward after 00301 episodes: 155.858
# Reward after 00302 episodes: 15.622
# Reward after 00303 episodes: 3.175
# Reward after 00304 episodes: 18.676
# Reward after 00305 episodes: 5.446
# Reward after 00306 episodes: 16.305
# Reward after 00307 episodes: 1.170
# Reward after 00308 episodes: 51.120
# Reward after 00309 episodes: 10.274
# Reward after 00310 episodes: 6.960
# Reward after 00311 episodes: 38.380
# Reward after 00312 episodes: 96.923
# Reward after 00313 episodes: 5.380
# Reward after 00314 episodes: 8.165
# Reward after 00315 episodes: 8.425
# Reward after 00316 episodes: 3.525
# Reward after 00317 episodes: -1.000
# Reward after 00318 episodes: -1.000
# Reward after 00319 episodes: 2.384
# Reward after 00320 episodes: 0.000
# Reward after 00321 episodes: 2.242
# Reward after 00322 episodes: 21.265
# Reward after 00323 episodes: 38.921
# Reward after 00324 episodes: 11.627
# Reward after 00325 episodes: 27.475
# Reward after 00326 episodes: 0.000
# Reward after 00327 episodes: 0.000
# Reward after 00328 episodes: 0.000
# Reward after 00329 episodes: 0.000
# Reward after 00330 episodes: 0.000
# Reward after 00331 episodes: 0.000
# Reward after 00332 episodes: 115.692
# Reward after 00333 episodes: 36.678
# Reward after 00334 episodes: 12.559
# Reward after 00335 episodes: 55.220
# Reward after 00336 episodes: 7.511
# Reward after 00337 episodes: 4.792
# Reward after 00338 episodes: 8.507
# Reward after 00339 episodes: 88.137
# Reward after 00340 episodes: 33.228
# Reward after 00341 episodes: 43.897
# Reward after 00342 episodes: 149.189
# Reward after 00343 episodes: 16.512
# Reward after 00344 episodes: 421.125
# Reward after 00345 episodes: 187.030
# Reward after 00346 episodes: 53.056
# Reward after 00347 episodes: 23.674
# Reward after 00348 episodes: 48.537
# Reward after 00349 episodes: 14.449
# Reward after 00350 episodes: 17.680
# Reward after 00351 episodes: 20.151
# Reward after 00352 episodes: 630.686
# Reward after 00353 episodes: 7.702
# Reward after 00354 episodes: 5.294
# Reward after 00355 episodes: 15.737
# Reward after 00356 episodes: 129.889
# Reward after 00357 episodes: 48.780
# Reward after 00358 episodes: 41.307
# Reward after 00359 episodes: 52.912
# Reward after 00360 episodes: 60.580
# Reward after 00361 episodes: 9.104
# Reward after 00362 episodes: 26.356
# Reward after 00363 episodes: 0.000
# Reward after 00364 episodes: 22.591
# Reward after 00365 episodes: 4.912
# Reward after 00366 episodes: 59.991
# Reward after 00367 episodes: 1.251
# Reward after 00368 episodes: 60.044
# Reward after 00369 episodes: 20.021
# Reward after 00370 episodes: 20.317
# Reward after 00371 episodes: 3.662
# Reward after 00372 episodes: 50.656
# Reward after 00373 episodes: 15.354
# Reward after 00374 episodes: 9.702
# Reward after 00375 episodes: 5.953
# Reward after 00376 episodes: 1.313
# Reward after 00377 episodes: 21.169
# Reward after 00378 episodes: 9.540
# Reward after 00379 episodes: 6.122
# Reward after 00380 episodes: 18.671
# Reward after 00381 episodes: 47.545
# Reward after 00382 episodes: 14.517
# Reward after 00383 episodes: 28.012
# Reward after 00384 episodes: 21.695
# Reward after 00385 episodes: 13.559
# Reward after 00386 episodes: 49.497
# Reward after 00387 episodes: -1.000
# Reward after 00388 episodes: 41.608
# Reward after 00389 episodes: 317.786
# Reward after 00390 episodes: 16.424
# Reward after 00391 episodes: 172.885
# Reward after 00392 episodes: 11.136
# Reward after 00393 episodes: 101.719
# Reward after 00394 episodes: 281.006
# Reward after 00395 episodes: 288.144
# Reward after 00396 episodes: 359.567
# Reward after 00397 episodes: 727.674
# Reward after 00398 episodes: 185.607
# Reward after 00399 episodes: 735.499
# Reward after 00400 episodes: 710.569
# Reward after 00401 episodes: 679.606
# Reward after 00402 episodes: 80.082
# Reward after 00403 episodes: 703.050
# Reward after 00404 episodes: 703.491
# Reward after 00405 episodes: 660.165
# Reward after 00406 episodes: 708.226
# Reward after 00407 episodes: 697.637
# Reward after 00408 episodes: 686.823
# Reward after 00409 episodes: 690.972
# Reward after 00410 episodes: 673.079
# Reward after 00411 episodes: 693.017
# Reward after 00412 episodes: 679.031
# Reward after 00413 episodes: 664.372
# Reward after 00414 episodes: 683.194
# Reward after 00415 episodes: 671.501
# Reward after 00416 episodes: 708.957
# Reward after 00417 episodes: 684.606
# Reward after 00418 episodes: 222.507
# Reward after 00419 episodes: 681.567
# Reward after 00420 episodes: 676.371
# Reward after 00421 episodes: 657.247
# Reward after 00422 episodes: 18.266
# Reward after 00423 episodes: 360.467
# Reward after 00424 episodes: 691.122
# Reward after 00425 episodes: 690.758
# Reward after 00426 episodes: 675.749
# Reward after 00427 episodes: 688.471
# Reward after 00428 episodes: 686.130
# Reward after 00429 episodes: 670.013
# Reward after 00430 episodes: 673.882
# Reward after 00431 episodes: 676.915
# Reward after 00432 episodes: 683.816
# Reward after 00433 episodes: 64.512
# Reward after 00434 episodes: 124.215
# Reward after 00435 episodes: 140.291
# Reward after 00436 episodes: 168.734
# Reward after 00437 episodes: 118.698
# Reward after 00438 episodes: 742.430
# Reward after 00439 episodes: 736.792
# Reward after 00440 episodes: 689.747
# Reward after 00441 episodes: 386.135
# Reward after 00442 episodes: 747.055
# Reward after 00443 episodes: 732.975
# Reward after 00444 episodes: 685.689
# Reward after 00445 episodes: 687.425
# Reward after 00446 episodes: 705.476
# Reward after 00447 episodes: 665.830
# Reward after 00448 episodes: 706.416
# Reward after 00449 episodes: 698.187
# Reward after 00450 episodes: 728.947
# Reward after 00451 episodes: 704.824
# Reward after 00452 episodes: 731.705
# Reward after 00453 episodes: 737.279
# Reward after 00454 episodes: 250.623
# Reward after 00455 episodes: 173.185
# Reward after 00456 episodes: 745.520
# Reward after 00457 episodes: 310.476
# Reward after 00458 episodes: 717.471
# Reward after 00459 episodes: 730.071
# Reward after 00460 episodes: -1.000
# Reward after 00461 episodes: 728.118
# Reward after 00462 episodes: -1.000
# Reward after 00463 episodes: 385.513
# Reward after 00464 episodes: 698.797
# Reward after 00465 episodes: 698.786
# Reward after 00466 episodes: 696.636
# Reward after 00467 episodes: 30.778
# Reward after 00468 episodes: 699.815
# Reward after 00469 episodes: 695.888
# Reward after 00470 episodes: 180.277
# Reward after 00471 episodes: 685.789
# Reward after 00472 episodes: 697.197
# Reward after 00473 episodes: 363.312
# Reward after 00474 episodes: 702.069
# Reward after 00475 episodes: 719.570
# Reward after 00476 episodes: 689.648
# Reward after 00477 episodes: 7.465
# Reward after 00478 episodes: 699.085
# Reward after 00479 episodes: 685.293
# Reward after 00480 episodes: 684.029
# Reward after 00481 episodes: 26.523
# Reward after 00482 episodes: 672.455
# Reward after 00483 episodes: 696.485
# Reward after 00484 episodes: 358.630
# Reward after 00485 episodes: 694.057
# Reward after 00486 episodes: 674.982
# Reward after 00487 episodes: 733.199
# Reward after 00488 episodes: 722.621
# Reward after 00489 episodes: 685.398
# Reward after 00490 episodes: 391.637
# Reward after 00491 episodes: 742.627
# Reward after 00492 episodes: 684.801
# Reward after 00493 episodes: 192.040
# Reward after 00494 episodes: 26.204
# Reward after 00495 episodes: 376.884
# Reward after 00496 episodes: 677.306
# Reward after 00497 episodes: 728.742
# Reward after 00498 episodes: 40.348
# Reward after 00499 episodes: 738.336
# Reward after 00500 episodes: 742.254
# Reward after 00501 episodes: 746.435
# Reward after 00502 episodes: 692.865
# Reward after 00503 episodes: 723.611
# Reward after 00504 episodes: 703.620
# Reward after 00505 episodes: 742.092
# Reward after 00506 episodes: 270.402
# Reward after 00507 episodes: 716.395
# Reward after 00508 episodes: 738.315
# Reward after 00509 episodes: 739.961
# Reward after 00510 episodes: 734.997
# Reward after 00511 episodes: 700.865
# Reward after 00512 episodes: 35.933
# Reward after 00513 episodes: 748.130
# Reward after 00514 episodes: 737.937
# Reward after 00515 episodes: 748.968
# Reward after 00516 episodes: 743.533
# Reward after 00517 episodes: 680.252
# Reward after 00518 episodes: 744.415
# Reward after 00519 episodes: 740.247
# Reward after 00520 episodes: 719.688
# Reward after 00521 episodes: 746.143
# Reward after 00522 episodes: 716.207
# Reward after 00523 episodes: 741.015
# Reward after 00524 episodes: 734.803
# Reward after 00525 episodes: 692.163
# Reward after 00526 episodes: 740.174
# Reward after 00527 episodes: 731.434
# Reward after 00528 episodes: 738.526
# Reward after 00529 episodes: 740.260
# Reward after 00530 episodes: 746.074
# Reward after 00531 episodes: 747.940
# Reward after 00532 episodes: 732.095
# Reward after 00533 episodes: 744.990
# Reward after 00534 episodes: 740.849
# Reward after 00535 episodes: 736.372
# Reward after 00536 episodes: 735.351
# Reward after 00537 episodes: 744.725
# Reward after 00538 episodes: 717.274
# Reward after 00539 episodes: 719.013
# Reward after 00540 episodes: 701.111
# Reward after 00541 episodes: 730.660
# Reward after 00542 episodes: 716.377
# Reward after 00543 episodes: 700.007
# Reward after 00544 episodes: 727.689
# Reward after 00545 episodes: 688.669
# Reward after 00546 episodes: 726.592
# Reward after 00547 episodes: 702.082
# Reward after 00548 episodes: 722.906
# Reward after 00549 episodes: 693.538
# Reward after 00550 episodes: 732.310
# Reward after 00551 episodes: 742.625
# Reward after 00552 episodes: 708.209
# Reward after 00553 episodes: 743.341
# Reward after 00554 episodes: 704.023
# Reward after 00555 episodes: 704.641
# Reward after 00556 episodes: 166.095
# Reward after 00557 episodes: 694.525
# Reward after 00558 episodes: 718.337
# Reward after 00559 episodes: 390.511
# Reward after 00560 episodes: 680.571
# Reward after 00561 episodes: 689.434
# Reward after 00562 episodes: 746.778
# Reward after 00563 episodes: 739.918
# Reward after 00564 episodes: 742.840
# Reward after 00565 episodes: 743.929
# Reward after 00566 episodes: 723.538
# Reward after 00567 episodes: 702.163
# Reward after 00568 episodes: 711.911
# Reward after 00569 episodes: 743.285
# Reward after 00570 episodes: 707.066
# Reward after 00571 episodes: 740.788
# Reward after 00572 episodes: 741.862
# Reward after 00573 episodes: 742.537
# Reward after 00574 episodes: 694.525
# Reward after 00575 episodes: 740.979
# Reward after 00576 episodes: 720.764
# Reward after 00577 episodes: 727.414
# Reward after 00578 episodes: 691.848
# Reward after 00579 episodes: 695.433
# Reward after 00580 episodes: 725.798
# Reward after 00581 episodes: 700.218
# Reward after 00582 episodes: 727.868
# Reward after 00583 episodes: 740.078
# Reward after 00584 episodes: 687.523
# Reward after 00585 episodes: 683.886
# Reward after 00586 episodes: 61.774
# Reward after 00587 episodes: 725.706
# Reward after 00588 episodes: 709.621
# Reward after 00589 episodes: 716.686
# Reward after 00590 episodes: 736.719
# Reward after 00591 episodes: 718.834
# Reward after 00592 episodes: 741.829
# Reward after 00593 episodes: 703.626
# Reward after 00594 episodes: 720.983
# Reward after 00595 episodes: -1.000
# Reward after 00596 episodes: 732.274
# Reward after 00597 episodes: 745.902
# Reward after 00598 episodes: 706.996
# Reward after 00599 episodes: 709.581
# Reward after 00600 episodes: 746.057
# Reward after 00601 episodes: 744.287
# Reward after 00602 episodes: 711.415
# Reward after 00603 episodes: 742.627
# Reward after 00604 episodes: 746.395
# Reward after 00605 episodes: 739.862
# Reward after 00606 episodes: 746.555
# Reward after 00607 episodes: 744.227
# Reward after 00608 episodes: 745.714
# Reward after 00609 episodes: 744.616
# Reward after 00610 episodes: 746.085
# Reward after 00611 episodes: 730.295
# Reward after 00612 episodes: 697.693
# Reward after 00613 episodes: 746.557
# Reward after 00614 episodes: 728.333
# Reward after 00615 episodes: 701.718
# Reward after 00616 episodes: 729.112
# Reward after 00617 episodes: -1.000
# Reward after 00618 episodes: 742.418
# Reward after 00619 episodes: 704.492
# Reward after 00620 episodes: 705.102
# Reward after 00621 episodes: 702.939
# Reward after 00622 episodes: 683.792
# Reward after 00623 episodes: 740.113
# Reward after 00624 episodes: 691.316
# Reward after 00625 episodes: 712.860
# Reward after 00626 episodes: 682.907
# Reward after 00627 episodes: 741.915
# Reward after 00628 episodes: 748.203
# Reward after 00629 episodes: 739.334
# Reward after 00630 episodes: 719.781
# Reward after 00631 episodes: 719.820
# Reward after 00632 episodes: 745.693
# Reward after 00633 episodes: 671.529
# Reward after 00634 episodes: 740.112
# Reward after 00635 episodes: 745.027
# Reward after 00636 episodes: 747.167
# Reward after 00637 episodes: 745.529
# Reward after 00638 episodes: 743.187
# Reward after 00639 episodes: 742.688
# Reward after 00640 episodes: 724.640
# Reward after 00641 episodes: 679.089
# Reward after 00642 episodes: 708.736
# Reward after 00643 episodes: 746.344
# Reward after 00644 episodes: 705.942
# Reward after 00645 episodes: 717.238
# Reward after 00646 episodes: 672.858
# Reward after 00647 episodes: 723.372
# Reward after 00648 episodes: 733.420
# Reward after 00649 episodes: 708.195
# Reward after 00650 episodes: 374.317
# Reward after 00651 episodes: 747.458
# Reward after 00652 episodes: 694.676
# Reward after 00653 episodes: -1.000
# Reward after 00654 episodes: -1.000
# Reward after 00655 episodes: 740.605
# Reward after 00656 episodes: 704.353
# Reward after 00657 episodes: 724.175
# Reward after 00658 episodes: 742.123
# Reward after 00659 episodes: 744.624
# Reward after 00660 episodes: 741.792
# Reward after 00661 episodes: 724.635
# Reward after 00662 episodes: 720.988
# Reward after 00663 episodes: 702.290
# Reward after 00664 episodes: 701.405
# Reward after 00665 episodes: 722.364
# Reward after 00666 episodes: 737.083
# Reward after 00667 episodes: 701.056
# Reward after 00668 episodes: 701.778
# Reward after 00669 episodes: 687.745
# Reward after 00670 episodes: 747.448
# Reward after 00671 episodes: 720.782
# Reward after 00672 episodes: 719.884
# Reward after 00673 episodes: 742.418
# Reward after 00674 episodes: 715.848
# Reward after 00675 episodes: 721.523
# Reward after 00676 episodes: 724.092
# Reward after 00677 episodes: 744.265
# Reward after 00678 episodes: 724.529
# Reward after 00679 episodes: 740.563
# Reward after 00680 episodes: 743.446
# Reward after 00681 episodes: 745.300
# Reward after 00682 episodes: 744.448
# Reward after 00683 episodes: 744.182
# Reward after 00684 episodes: 742.260
# Reward after 00685 episodes: 718.258
# Reward after 00686 episodes: 389.145
# Reward after 00687 episodes: 726.871
# Reward after 00688 episodes: 724.643
# Reward after 00689 episodes: 713.322
# Reward after 00690 episodes: 718.899
# Reward after 00691 episodes: 716.558
# Reward after 00692 episodes: 745.821
# Reward after 00693 episodes: 742.298
# Reward after 00694 episodes: 731.122
# Reward after 00695 episodes: 714.076
# Reward after 00696 episodes: 743.446
# Reward after 00697 episodes: 745.785
# Reward after 00698 episodes: 717.537
# Reward after 00699 episodes: 745.222
# Reward after 00700 episodes: 739.082
# Reward after 00701 episodes: 747.636
# Reward after 00702 episodes: 742.891
# Reward after 00703 episodes: 723.664
# Reward after 00704 episodes: 741.844
# Reward after 00705 episodes: 746.762
# Reward after 00706 episodes: 711.089
# Reward after 00707 episodes: 749.980
# Reward after 00708 episodes: 716.668
# Reward after 00709 episodes: 746.267
# Reward after 00710 episodes: 730.260
# Reward after 00711 episodes: 724.132
# Reward after 00712 episodes: 737.104
# Reward after 00713 episodes: 744.108
# Reward after 00714 episodes: 726.407
# Reward after 00715 episodes: 738.143
# Reward after 00716 episodes: 700.412
# Reward after 00717 episodes: 704.955
# Reward after 00718 episodes: 704.903
# Reward after 00719 episodes: 696.280
# Reward after 00720 episodes: 697.932
# Reward after 00721 episodes: 709.643
# Reward after 00722 episodes: 690.160
# Reward after 00723 episodes: 699.095
# Reward after 00724 episodes: 714.343
# Reward after 00725 episodes: 709.805
# Reward after 00726 episodes: 713.548
# Reward after 00727 episodes: 691.158
# Reward after 00728 episodes: 698.632
# Reward after 00729 episodes: 720.427
# Reward after 00730 episodes: 718.057
# Reward after 00731 episodes: 729.339
# Reward after 00732 episodes: 718.024
# Reward after 00733 episodes: 708.230
# Reward after 00734 episodes: 678.000
# Reward after 00735 episodes: 737.429
# Reward after 00736 episodes: 711.764
# Reward after 00737 episodes: 730.398
# Reward after 00738 episodes: 703.979
# Reward after 00739 episodes: 712.045
# Reward after 00740 episodes: 711.041
# Reward after 00741 episodes: 746.850
# Reward after 00742 episodes: 731.333
# Reward after 00743 episodes: 722.013
# Reward after 00744 episodes: 725.164
# Reward after 00745 episodes: 740.673
# Reward after 00746 episodes: 746.787
# Reward after 00747 episodes: 717.278
# Reward after 00748 episodes: 744.097
# Reward after 00749 episodes: 392.641
# Reward after 00750 episodes: 725.996
# Reward after 00751 episodes: 718.180
# Reward after 00752 episodes: 713.508
# Reward after 00753 episodes: 733.928
# Reward after 00754 episodes: 719.948
# Reward after 00755 episodes: 677.844
# Reward after 00756 episodes: 680.588
# Reward after 00757 episodes: 682.835
# Reward after 00758 episodes: 742.314
# Reward after 00759 episodes: 740.799
# Reward after 00760 episodes: 682.279
# Reward after 00761 episodes: 724.955
# Reward after 00762 episodes: 723.683
# Reward after 00763 episodes: 727.602
# Reward after 00764 episodes: 746.118
# Reward after 00765 episodes: 721.985
# Reward after 00766 episodes: 722.005
# Reward after 00767 episodes: 728.407
# Reward after 00768 episodes: 728.917
# Reward after 00769 episodes: 741.610
# Reward after 00770 episodes: 734.319
# Reward after 00771 episodes: 744.346
# Reward after 00772 episodes: 710.078
# Reward after 00773 episodes: 724.858
# Reward after 00774 episodes: 721.973
# Reward after 00775 episodes: 726.390
# Reward after 00776 episodes: 718.998
# Reward after 00777 episodes: 393.478
# Reward after 00778 episodes: 723.692
# Reward after 00779 episodes: 711.397
# Reward after 00780 episodes: 740.551
# Reward after 00781 episodes: 744.467
# Reward after 00782 episodes: 739.498
# Reward after 00783 episodes: 746.475
# Reward after 00784 episodes: 362.521
# Reward after 00785 episodes: 694.207
# Reward after 00786 episodes: 359.608
# Reward after 00787 episodes: 730.286
# Reward after 00788 episodes: 727.303
# Reward after 00789 episodes: 709.736
# Reward after 00790 episodes: 719.148
# Reward after 00791 episodes: 732.362
# Reward after 00792 episodes: 688.842
# Reward after 00793 episodes: 728.379
# Reward after 00794 episodes: 690.019
# Reward after 00795 episodes: 708.505
# Reward after 00796 episodes: 711.733
# Reward after 00797 episodes: 690.283
# Reward after 00798 episodes: 713.738
# Reward after 00799 episodes: 722.244
# Reward after 00800 episodes: 723.142
# Reward after 00801 episodes: 699.557
# Reward after 00802 episodes: 28.729
# Reward after 00803 episodes: 387.753
# Reward after 00804 episodes: 727.746
# Reward after 00805 episodes: 734.945
# Reward after 00806 episodes: 724.422
# Reward after 00807 episodes: 706.344
# Reward after 00808 episodes: 714.222
# Reward after 00809 episodes: 737.779
# Reward after 00810 episodes: 721.958
# Reward after 00811 episodes: 724.813
# Reward after 00812 episodes: 726.139
# Reward after 00813 episodes: 708.862
# Reward after 00814 episodes: 711.767
# Reward after 00815 episodes: 708.022
# Reward after 00816 episodes: 706.662
# Reward after 00817 episodes: 704.641
# Reward after 00818 episodes: 737.529
# Reward after 00819 episodes: 722.523
# Reward after 00820 episodes: 731.954
# Reward after 00821 episodes: 283.086
# Reward after 00822 episodes: 704.672
# Reward after 00823 episodes: 706.065
# Reward after 00824 episodes: 681.576
# Reward after 00825 episodes: 703.530
# Reward after 00826 episodes: 658.248
# Reward after 00827 episodes: 734.047
# Reward after 00828 episodes: 737.836
# Reward after 00829 episodes: 729.674
# Reward after 00830 episodes: 714.087
# Reward after 00831 episodes: 703.726
# Reward after 00832 episodes: 695.798
# Reward after 00833 episodes: 392.726
# Reward after 00834 episodes: 720.139
# Reward after 00835 episodes: 713.992
# Reward after 00836 episodes: 740.551
# Reward after 00837 episodes: 713.918
# Reward after 00838 episodes: 729.676
# Reward after 00839 episodes: 704.609
# Reward after 00840 episodes: 704.284
# Reward after 00841 episodes: 717.310
# Reward after 00842 episodes: 725.901
# Reward after 00843 episodes: 715.941
# Reward after 00844 episodes: 724.345
# Reward after 00845 episodes: 714.214
# Reward after 00846 episodes: 732.374
# Reward after 00847 episodes: 710.160
# Reward after 00848 episodes: 711.447
# Reward after 00849 episodes: 746.209
# Reward after 00850 episodes: 710.773
# Reward after 00851 episodes: 710.669
# Reward after 00852 episodes: 713.650
# Reward after 00853 episodes: 733.451
# Reward after 00854 episodes: 705.265
# Reward after 00855 episodes: 717.146
# Reward after 00856 episodes: 711.744
# Reward after 00857 episodes: 717.218
# Reward after 00858 episodes: 708.438
# Reward after 00859 episodes: 713.235
# Reward after 00860 episodes: 724.829
# Reward after 00861 episodes: 701.445
# Reward after 00862 episodes: 705.438
# Reward after 00863 episodes: 749.887
# Reward after 00864 episodes: 715.953
# Reward after 00865 episodes: 712.576
# Reward after 00866 episodes: 705.834
# Reward after 00867 episodes: 696.475
# Reward after 00868 episodes: 723.564
# Reward after 00869 episodes: 722.569
# Reward after 00870 episodes: 684.852
# Reward after 00871 episodes: 713.259
# Reward after 00872 episodes: 703.166
# Reward after 00873 episodes: 704.380
# Reward after 00874 episodes: 739.103
# Reward after 00875 episodes: 714.658
# Reward after 00876 episodes: 730.511
# Reward after 00877 episodes: 724.178
# Reward after 00878 episodes: 692.190
# Reward after 00879 episodes: 723.618
# Reward after 00880 episodes: 695.192
# Reward after 00881 episodes: 720.412
# Reward after 00882 episodes: 710.475
# Reward after 00883 episodes: 708.024
# Reward after 00884 episodes: 704.401
# Reward after 00885 episodes: 735.237
# Reward after 00886 episodes: 700.688
# Reward after 00887 episodes: 710.042
# Reward after 00888 episodes: 725.693
# Reward after 00889 episodes: 742.504
# Reward after 00890 episodes: 735.297
# Reward after 00891 episodes: 710.877
# Reward after 00892 episodes: 716.836
# Reward after 00893 episodes: 710.660
# Reward after 00894 episodes: 725.222
# Reward after 00895 episodes: 726.141
# Reward after 00896 episodes: 697.420
# Reward after 00897 episodes: 740.203
# Reward after 00898 episodes: 702.233
# Reward after 00899 episodes: 746.741
# Reward after 00900 episodes: 714.654
# Reward after 00901 episodes: 741.706
# Reward after 00902 episodes: 704.284
# Reward after 00903 episodes: 375.046
# Reward after 00904 episodes: 36.271
# Reward after 00905 episodes: 722.489
# Reward after 00906 episodes: 741.931
# Reward after 00907 episodes: 718.929
# Reward after 00908 episodes: 717.255
# Reward after 00909 episodes: 729.781
# Reward after 00910 episodes: 736.466
# Reward after 00911 episodes: 731.795
# Reward after 00912 episodes: 702.099
# Reward after 00913 episodes: 746.744
# Reward after 00914 episodes: 727.988
# Reward after 00915 episodes: 734.154
# Reward after 00916 episodes: 701.761
# Reward after 00917 episodes: 736.299
# Reward after 00918 episodes: 693.816
# Reward after 00919 episodes: 731.952
# Reward after 00920 episodes: 723.482
# Reward after 00921 episodes: 696.333
# Reward after 00922 episodes: 698.336
# Reward after 00923 episodes: 689.342
# Reward after 00924 episodes: 706.319
# Reward after 00925 episodes: 696.087
# Reward after 00926 episodes: 704.350
# Reward after 00927 episodes: 706.592
# Reward after 00928 episodes: 724.606
# Reward after 00929 episodes: 737.793
# Reward after 00930 episodes: 725.139
# Reward after 00931 episodes: 483.988
# Reward after 00932 episodes: 710.446
# Reward after 00933 episodes: 724.418
# Reward after 00934 episodes: 728.478
# Reward after 00935 episodes: 739.526
# Reward after 00936 episodes: 717.153
# Reward after 00937 episodes: 88.740
# Reward after 00938 episodes: 704.791
# Reward after 00939 episodes: 735.612
# Reward after 00940 episodes: 725.529
# Reward after 00941 episodes: 707.359
# Reward after 00942 episodes: 371.654
# Reward after 00943 episodes: 733.046
# Reward after 00944 episodes: 746.671
# Reward after 00945 episodes: 716.528
# Reward after 00946 episodes: 714.889
# Reward after 00947 episodes: 731.532
# Reward after 00948 episodes: 714.469
# Reward after 00949 episodes: 725.307
# Reward after 00950 episodes: 733.736
# Reward after 00951 episodes: 718.389
# Reward after 00952 episodes: 733.518
# Reward after 00953 episodes: 743.539
# Reward after 00954 episodes: 751.046
# Reward after 00955 episodes: 737.314
# Reward after 00956 episodes: 730.709
# Reward after 00957 episodes: 712.726
# Reward after 00958 episodes: 717.108
# Reward after 00959 episodes: 394.227
# Reward after 00960 episodes: 729.832
# Reward after 00961 episodes: 736.442
# Reward after 00962 episodes: 733.754
# Reward after 00963 episodes: 706.625
# Reward after 00964 episodes: 725.564
# Reward after 00965 episodes: 732.910
# Reward after 00966 episodes: 713.528
# Reward after 00967 episodes: 729.307
# Reward after 00968 episodes: 747.069
# Reward after 00969 episodes: 736.542
# Reward after 00970 episodes: 738.894
# Reward after 00971 episodes: 749.876
# Reward after 00972 episodes: 718.092
# Reward after 00973 episodes: 711.859
# Reward after 00974 episodes: 724.228
# Reward after 00975 episodes: 741.400
# Reward after 00976 episodes: 731.340
# Reward after 00977 episodes: 728.201
# Reward after 00978 episodes: 714.839
# Reward after 00979 episodes: 705.191
# Reward after 00980 episodes: 745.492
# Reward after 00981 episodes: 698.346
# Reward after 00982 episodes: 702.188
# Reward after 00983 episodes: 741.677
# Reward after 00984 episodes: 722.060
# Reward after 00985 episodes: 733.729
# Reward after 00986 episodes: 728.253
# Reward after 00987 episodes: 710.883
# Reward after 00988 episodes: 714.088
# Reward after 00989 episodes: 725.132
# Reward after 00990 episodes: 742.553
# Reward after 00991 episodes: 697.657
# Reward after 00992 episodes: 728.022
# Reward after 00993 episodes: 723.991
# Reward after 00994 episodes: 709.628
# Reward after 00995 episodes: 738.708
# Reward after 00996 episodes: 731.880
# Reward after 00997 episodes: 719.912
# Reward after 00998 episodes: 727.424
# Reward after 00999 episodes: 717.652
# Reward after 01000 episodes: 730.084
# Reward after 01001 episodes: 732.470
# Reward after 01002 episodes: 743.836
# Reward after 01003 episodes: 721.304
# Reward after 01004 episodes: 727.833
# Reward after 01005 episodes: 733.838
# Reward after 01006 episodes: 483.282
# Reward after 01007 episodes: 709.526
# Reward after 01008 episodes: 708.303
# Reward after 01009 episodes: 741.336
# Reward after 01010 episodes: 713.939
# Reward after 01011 episodes: 720.088
# Reward after 01012 episodes: 715.407
# Reward after 01013 episodes: 728.211
# Reward after 01014 episodes: 702.929
# Reward after 01015 episodes: 720.018
# Reward after 01016 episodes: 718.214
# Reward after 01017 episodes: 738.667
# Reward after 01018 episodes: 717.927
# Reward after 01019 episodes: 717.575
# Reward after 01020 episodes: 721.575
# Reward after 01021 episodes: 727.398
# Reward after 01022 episodes: 723.477
# Reward after 01023 episodes: 736.649
# Reward after 01024 episodes: 744.610
# Reward after 01025 episodes: 723.940
# Reward after 01026 episodes: 707.616
# Reward after 01027 episodes: 694.679
# Reward after 01028 episodes: 726.533
# Reward after 01029 episodes: 724.546
# Reward after 01030 episodes: 744.451
# Reward after 01031 episodes: 725.775
# Reward after 01032 episodes: 744.351
# Reward after 01033 episodes: 742.399
# Reward after 01034 episodes: 746.757
# Reward after 01035 episodes: 744.918
# Reward after 01036 episodes: 732.611
# Reward after 01037 episodes: 729.292
# Reward after 01038 episodes: 710.108
# Reward after 01039 episodes: 726.951
# Reward after 01040 episodes: 746.393
# Reward after 01041 episodes: 708.719
# Reward after 01042 episodes: 732.534
# Reward after 01043 episodes: 730.853
# Reward after 01044 episodes: 731.459
# Reward after 01045 episodes: 708.200
# Reward after 01046 episodes: 717.434
# Reward after 01047 episodes: 729.396
# Reward after 01048 episodes: 737.594
# Reward after 01049 episodes: 718.713
# Reward after 01050 episodes: 735.848
# Reward after 01051 episodes: 709.437
# Reward after 01052 episodes: 730.761
# Reward after 01053 episodes: 732.802
# Reward after 01054 episodes: 700.366
# Reward after 01055 episodes: 720.151
# Reward after 01056 episodes: 707.237
# Reward after 01057 episodes: 716.951
# Reward after 01058 episodes: 731.224
# Reward after 01059 episodes: 727.707
# Reward after 01060 episodes: 721.923
# Reward after 01061 episodes: 21.064
# Reward after 01062 episodes: 707.459
# Reward after 01063 episodes: 718.574
# Reward after 01064 episodes: 694.121
# Reward after 01065 episodes: 710.557
# Reward after 01066 episodes: 719.367
# Reward after 01067 episodes: 738.603
# Reward after 01068 episodes: 722.014
# Reward after 01069 episodes: 728.748
# Reward after 01070 episodes: 719.880
# Reward after 01071 episodes: 716.967
# Reward after 01072 episodes: 712.478
# Reward after 01073 episodes: 716.124
# Reward after 01074 episodes: 746.380
# Reward after 01075 episodes: 717.209
# Reward after 01076 episodes: 741.206
# Reward after 01077 episodes: 709.050
# Reward after 01078 episodes: -1.000
# Reward after 01079 episodes: 719.897
# Reward after 01080 episodes: 723.610
# Reward after 01081 episodes: 746.029
# Reward after 01082 episodes: 715.004
# Reward after 01083 episodes: 714.732
# Reward after 01084 episodes: 599.693
# Reward after 01085 episodes: 751.073
# Reward after 01086 episodes: 722.585
# Reward after 01087 episodes: 738.757
# Reward after 01088 episodes: 715.723
# Reward after 01089 episodes: 711.978
# Reward after 01090 episodes: 737.131
# Reward after 01091 episodes: 728.763
# Reward after 01092 episodes: 719.601
# Reward after 01093 episodes: 721.142
# Reward after 01094 episodes: 698.985
# Reward after 01095 episodes: 674.528
# Reward after 01096 episodes: 747.896
# Reward after 01097 episodes: 732.567
# Reward after 01098 episodes: 719.306
# Reward after 01099 episodes: 713.305
# Reward after 01100 episodes: 728.058
# Reward after 01101 episodes: 718.185
# Reward after 01102 episodes: 731.556
# Reward after 01103 episodes: 722.841
# Reward after 01104 episodes: 733.076
# Reward after 01105 episodes: 707.171
# Reward after 01106 episodes: 736.369
# Reward after 01107 episodes: 735.423
# Reward after 01108 episodes: 707.884
# Reward after 01109 episodes: 743.632
# Reward after 01110 episodes: 731.496
# Reward after 01111 episodes: 738.832
# Reward after 01112 episodes: 716.133
# Reward after 01113 episodes: 716.086
# Reward after 01114 episodes: 746.174
# Reward after 01115 episodes: 729.964
# Reward after 01116 episodes: 721.517
# Reward after 01117 episodes: 722.329
# Reward after 01118 episodes: 703.661
# Reward after 01119 episodes: 708.984
# Reward after 01120 episodes: 719.612
# Reward after 01121 episodes: 27.027
# Reward after 01122 episodes: 712.152
# Reward after 01123 episodes: 61.532
# Reward after 01124 episodes: 713.120
# Reward after 01125 episodes: 753.368
# Reward after 01126 episodes: 754.341
# Reward after 01127 episodes: 750.405
# Reward after 01128 episodes: 746.229
# Reward after 01129 episodes: 714.166
# Reward after 01130 episodes: 742.102
# Reward after 01131 episodes: 725.568
# Reward after 01132 episodes: 728.109
# Reward after 01133 episodes: 734.320
# Reward after 01134 episodes: 723.903
# Reward after 01135 episodes: 734.958
# Reward after 01136 episodes: 733.729
# Reward after 01137 episodes: 744.587
# Reward after 01138 episodes: 721.205
# Reward after 01139 episodes: 744.144
# Reward after 01140 episodes: 729.504
# Reward after 01141 episodes: 720.602
# Reward after 01142 episodes: 720.405
# Reward after 01143 episodes: 747.562
# Reward after 01144 episodes: 721.061
# Reward after 01145 episodes: 735.899
# Reward after 01146 episodes: 749.687
# Reward after 01147 episodes: 746.883
# Reward after 01148 episodes: 752.464
# Reward after 01149 episodes: 24.074
# Reward after 01150 episodes: 725.204
# Reward after 01151 episodes: 729.708
# Reward after 01152 episodes: 742.860
# Reward after 01153 episodes: 742.362
# Reward after 01154 episodes: 737.294
# Reward after 01155 episodes: 736.802
# Reward after 01156 episodes: 149.314
# Reward after 01157 episodes: 720.662
# Reward after 01158 episodes: 729.298
# Reward after 01159 episodes: 749.290
# Reward after 01160 episodes: 749.207
# Reward after 01161 episodes: 748.811
# Reward after 01162 episodes: 740.544
# Reward after 01163 episodes: 746.161
# Reward after 01164 episodes: 722.567
# Reward after 01165 episodes: 737.062
# Reward after 01166 episodes: 730.010
# Reward after 01167 episodes: 723.072
# Reward after 01168 episodes: 747.162
# Reward after 01169 episodes: 749.241
# Reward after 01170 episodes: 714.058
# Reward after 01171 episodes: 752.680
# Reward after 01172 episodes: 729.936
# Reward after 01173 episodes: 730.203
# Reward after 01174 episodes: 739.616
# Reward after 01175 episodes: 744.427
# Reward after 01176 episodes: 747.378
# Reward after 01177 episodes: 736.019
# Reward after 01178 episodes: 733.563
# Reward after 01179 episodes: 742.482
# Reward after 01180 episodes: 727.169
# Reward after 01181 episodes: 730.950
# Reward after 01182 episodes: 746.339
# Reward after 01183 episodes: 723.957
# Reward after 01184 episodes: 746.678
# Reward after 01185 episodes: 748.532
# Reward after 01186 episodes: 747.930
# Reward after 01187 episodes: 742.109
# Reward after 01188 episodes: 732.711
# Reward after 01189 episodes: 720.017
# Reward after 01190 episodes: 728.647
# Reward after 01191 episodes: 747.116
# Reward after 01192 episodes: 716.482
# Reward after 01193 episodes: 718.681
# Reward after 01194 episodes: 745.768
# Reward after 01195 episodes: 715.691
# Reward after 01196 episodes: 732.772
# Reward after 01197 episodes: 732.529
# Reward after 01198 episodes: 748.428
# Reward after 01199 episodes: 727.478
# Reward after 01200 episodes: 739.801
# Reward after 01201 episodes: 747.679
# Reward after 01202 episodes: 751.229
# Reward after 01203 episodes: 715.951
# Reward after 01204 episodes: 741.320
# Reward after 01205 episodes: 736.324
# Reward after 01206 episodes: 734.232
# Reward after 01207 episodes: 715.175
# Reward after 01208 episodes: 722.114
# Reward after 01209 episodes: 747.964
# Reward after 01210 episodes: 722.443
# Reward after 01211 episodes: 720.556
# Reward after 01212 episodes: 733.772
# Reward after 01213 episodes: 750.896
# Reward after 01214 episodes: 747.006
# Reward after 01215 episodes: 745.372
# Reward after 01216 episodes: 733.959
# Reward after 01217 episodes: 711.615
# Reward after 01218 episodes: 740.185
# Reward after 01219 episodes: 747.769
# Reward after 01220 episodes: 733.615
# Reward after 01221 episodes: 719.601
# Reward after 01222 episodes: 752.022
# Reward after 01223 episodes: 714.014
# Reward after 01224 episodes: 739.222
# Reward after 01225 episodes: 749.900
# Reward after 01226 episodes: 745.415
# Reward after 01227 episodes: 723.511
# Reward after 01228 episodes: 730.285
# Reward after 01229 episodes: 754.808
# Reward after 01230 episodes: 725.095
# Reward after 01231 episodes: 739.875
# Reward after 01232 episodes: 696.257
# Reward after 01233 episodes: 720.201
# Reward after 01234 episodes: 720.634
# Reward after 01235 episodes: 742.160
# Reward after 01236 episodes: 729.641
# Reward after 01237 episodes: 753.250
# Reward after 01238 episodes: 735.316
# Reward after 01239 episodes: 737.412
# Reward after 01240 episodes: 712.552
# Reward after 01241 episodes: 741.688
# Reward after 01242 episodes: 711.507
# Reward after 01243 episodes: 714.215
# Reward after 01244 episodes: 706.321
# Reward after 01245 episodes: 722.678
# Reward after 01246 episodes: 715.599
# Reward after 01247 episodes: 713.420
# Reward after 01248 episodes: 353.072
# Reward after 01249 episodes: 737.715
# Reward after 01250 episodes: 712.506
# Reward after 01251 episodes: 722.375
# Reward after 01252 episodes: 744.103
# Reward after 01253 episodes: 718.716
# Reward after 01254 episodes: 723.155
# Reward after 01255 episodes: 730.087
# Reward after 01256 episodes: 732.026
# Reward after 01257 episodes: 719.953
# Reward after 01258 episodes: 724.294
# Reward after 01259 episodes: 743.896
# Reward after 01260 episodes: 23.617
# Reward after 01261 episodes: 739.159
# Reward after 01262 episodes: 231.668
# Reward after 01263 episodes: 741.400
# Reward after 01264 episodes: 101.812
# ...
# Reward after 02381 episodes: 730.722
# Reward after 02382 episodes: 735.433
# Reward after 02383 episodes: 736.549
# Reward after 02384 episodes: 725.803
# Reward after 02385 episodes: 718.115
# Reward after 02386 episodes: 731.759
# Reward after 02387 episodes: 723.839
# Reward after 02388 episodes: 740.128
# Reward after 02389 episodes: 749.518
# Reward after 02390 episodes: 732.815
# Reward after 02391 episodes: 740.709
# Reward after 02392 episodes: 748.002
# Reward after 02393 episodes: 728.881
# Reward after 02394 episodes: 729.756
# Reward after 02395 episodes: 727.370
# Reward after 02396 episodes: 727.326
# Reward after 02397 episodes: 724.102
# Reward after 02398 episodes: 729.593
# Reward after 02399 episodes: 733.816
# Reward after 02400 episodes: 723.531
# Reward after 02401 episodes: 734.931
# Reward after 02402 episodes: 733.650
# Reward after 02403 episodes: 724.226
# Reward after 02404 episodes: 745.825
# Reward after 02405 episodes: 739.357
# Reward after 02406 episodes: 731.677
# Reward after 02407 episodes: 741.430
# Reward after 02408 episodes: 738.063
# Reward after 02409 episodes: 737.588
# Reward after 02410 episodes: 741.884
# Reward after 02411 episodes: 738.916
# Reward after 02412 episodes: 729.531
# Reward after 02413 episodes: 728.413
# Reward after 02414 episodes: 741.432
# Reward after 02415 episodes: 740.473
# Reward after 02416 episodes: 730.014
# Reward after 02417 episodes: 727.615
# Reward after 02418 episodes: 729.151
# Reward after 02419 episodes: 740.165
# Reward after 02420 episodes: 727.712
# Reward after 02421 episodes: 728.768
# Reward after 02422 episodes: 740.090
# Reward after 02423 episodes: 730.248
# Reward after 02424 episodes: 742.412
# Reward after 02425 episodes: 732.053
# Reward after 02426 episodes: 735.674
# Reward after 02427 episodes: 737.162
# Reward after 02428 episodes: 723.654
# Reward after 02429 episodes: 737.421
# Reward after 02430 episodes: 728.434
# Reward after 02431 episodes: 736.901
# Reward after 02432 episodes: 731.524
# Reward after 02433 episodes: 723.814
# Reward after 02434 episodes: 731.034
# Reward after 02435 episodes: 727.793
# Reward after 02436 episodes: 728.304
# Reward after 02437 episodes: 733.579
# Reward after 02438 episodes: 725.762
# Reward after 02439 episodes: 727.882
# Reward after 02440 episodes: 727.974
# Reward after 02441 episodes: 729.773
# Reward after 02442 episodes: 740.594
# Reward after 02443 episodes: 746.918
# Reward after 02444 episodes: 736.858
# Reward after 02445 episodes: 735.877
# Reward after 02446 episodes: 747.742
# Reward after 02447 episodes: 732.762
# Reward after 02448 episodes: 732.998
# Reward after 02449 episodes: 739.705
# Reward after 02450 episodes: 731.233
# Reward after 02451 episodes: 736.907
# Reward after 02452 episodes: 739.255
# Reward after 02453 episodes: 715.232
# Reward after 02454 episodes: 730.950
# Reward after 02455 episodes: 729.407
# Reward after 02456 episodes: 727.601
# Reward after 02457 episodes: 727.709
# Reward after 02458 episodes: 731.464
# Reward after 02459 episodes: 726.239
# Reward after 02460 episodes: 728.328
# Reward after 02461 episodes: 0.000
# Reward after 02462 episodes: 0.000
# Reward after 02463 episodes: 0.000
# Reward after 02464 episodes: 0.000
# Reward after 02465 episodes: 0.000
# Reward after 02466 episodes: 0.000
# Reward after 02467 episodes: 0.000
# Reward after 02468 episodes: 0.000
# Reward after 02469 episodes: 0.000
# Reward after 02470 episodes: 0.000
# Reward after 02471 episodes: 0.000
# Reward after 02472 episodes: 0.000
# Reward after 02473 episodes: 0.000
# Reward after 02474 episodes: 0.000
# Reward after 02475 episodes: 0.000
# Reward after 02476 episodes: 0.000
# Reward after 02477 episodes: 0.000
# Reward after 02478 episodes: 0.000
# Reward after 02479 episodes: 0.000
# Reward after 02480 episodes: 0.000
# Reward after 02481 episodes: 0.000
# Reward after 02482 episodes: 0.000
# Reward after 02483 episodes: 0.000
# Reward after 02484 episodes: 0.000
# Reward after 02485 episodes: 0.000
# Reward after 02486 episodes: 0.000
# Reward after 02487 episodes: 0.000
# Reward after 02488 episodes: 0.000
# Reward after 02489 episodes: 0.000
# Reward after 02490 episodes: 0.000
# Reward after 02491 episodes: 0.000
# Reward after 02492 episodes: 0.000
# Reward after 02493 episodes: 0.000
# Reward after 02494 episodes: 0.000
# Reward after 02495 episodes: 0.000
# Reward after 02496 episodes: 0.000
# Reward after 02497 episodes: 0.000
# Reward after 02498 episodes: 0.000
# Reward after 02499 episodes: 0.000
# Reward after 02500 episodes: 0.000
# Reward after 02501 episodes: 0.000
# Reward after 02502 episodes: 0.000
# Reward after 02503 episodes: 0.000
# Reward after 02504 episodes: -1.000
# Reward after 02505 episodes: -1.000
# Reward after 02506 episodes: -1.000
# Reward after 02507 episodes: -1.000
# Reward after 02508 episodes: 0.000
# Reward after 02509 episodes: 0.000
# Reward after 02510 episodes: 0.000
# Reward after 02511 episodes: 0.000
# Reward after 02512 episodes: 0.000
# Reward after 02513 episodes: 0.000
# Reward after 02514 episodes: 0.000
# Reward after 02515 episodes: 0.000
# Reward after 02516 episodes: 0.000
# Reward after 02517 episodes: 0.000
# Reward after 02518 episodes: 0.000
# Reward after 02519 episodes: 0.000
# Reward after 02520 episodes: 0.000
# Reward after 02521 episodes: 0.000
# Reward after 02522 episodes: 4.201
# Reward after 02523 episodes: 0.000
# Reward after 02524 episodes: 11.241
# Reward after 02525 episodes: 0.000
# Reward after 02526 episodes: 7.915
# Reward after 02527 episodes: 7.062
# Reward after 02528 episodes: 0.000
# Reward after 02529 episodes: 15.931
# Reward after 02530 episodes: 8.900
# Reward after 02531 episodes: 0.000
# Reward after 02532 episodes: 0.000
# Reward after 02533 episodes: 0.000
# Reward after 02534 episodes: 0.000
# Reward after 02535 episodes: 0.000
# Reward after 02536 episodes: 0.000
# Reward after 02537 episodes: 0.000
# Reward after 02538 episodes: 0.000
# Reward after 02539 episodes: 0.000
# Reward after 02540 episodes: 0.000
# Reward after 02541 episodes: 0.000
# Reward after 02542 episodes: 0.000
# Reward after 02543 episodes: 0.000
# Reward after 02544 episodes: 2.438
# Reward after 02545 episodes: 0.085
# Reward after 02546 episodes: 0.260
# Reward after 02547 episodes: 3.168
# Reward after 02548 episodes: 7.158
# Reward after 02549 episodes: 0.387
# Reward after 02550 episodes: 7.455
# Reward after 02551 episodes: 0.082
# Reward after 02552 episodes: 2.576
# Reward after 02553 episodes: 0.835
# Reward after 02554 episodes: 2.835
# Reward after 02555 episodes: 0.000
# Reward after 02556 episodes: 0.398
# Reward after 02557 episodes: 0.000
# Reward after 02558 episodes: 0.190
# Reward after 02559 episodes: 0.000
# Reward after 02560 episodes: 0.239
# Reward after 02561 episodes: 6.298
# Reward after 02562 episodes: 366.596
# Reward after 02563 episodes: 7.363
# Reward after 02564 episodes: 13.306
# Reward after 02565 episodes: 1.131
# Reward after 02566 episodes: 26.529
# Reward after 02567 episodes: 8.483
# Reward after 02568 episodes: 34.922
# Reward after 02569 episodes: 0.000
# Reward after 02570 episodes: 11.643
# Reward after 02571 episodes: 40.002
# Reward after 02572 episodes: 6.027
# Reward after 02573 episodes: 20.036
# Reward after 02574 episodes: 8.435
# Reward after 02575 episodes: 21.171
# Reward after 02576 episodes: 16.077
# Reward after 02577 episodes: 16.418
# Reward after 02578 episodes: 15.669
# Reward after 02579 episodes: 44.777
# Reward after 02580 episodes: 39.419
# Reward after 02581 episodes: 185.074
# Reward after 02582 episodes: 26.937
# Reward after 02583 episodes: -1.000
# Reward after 02584 episodes: -1.000
# Reward after 02585 episodes: 11.193
# Reward after 02586 episodes: 22.467
# Reward after 02587 episodes: 10.427
# Reward after 02588 episodes: 4.253
# Reward after 02589 episodes: 8.576
# Reward after 02590 episodes: 12.984
# Reward after 02591 episodes: -1.000
# Reward after 02592 episodes: 20.820
# Reward after 02593 episodes: 24.363
# Reward after 02594 episodes: 564.407
# Reward after 02595 episodes: 53.347
# Reward after 02596 episodes: 28.115
# Reward after 02597 episodes: 44.652
# Reward after 02598 episodes: 41.937
# Reward after 02599 episodes: 4.427
# Reward after 02600 episodes: 10.461
# Reward after 02601 episodes: 4.185
# Reward after 02602 episodes: 11.725
# Reward after 02603 episodes: 1.855
# Reward after 02604 episodes: 3.722
# Reward after 02605 episodes: 0.081
# Reward after 02606 episodes: 0.101
# Reward after 02607 episodes: 0.000
# Reward after 02608 episodes: 0.000
# Reward after 02609 episodes: 0.000
# Reward after 02610 episodes: 0.000
# Reward after 02611 episodes: 4.668
# Reward after 02612 episodes: 0.640
# Reward after 02613 episodes: 0.000
# Reward after 02614 episodes: 0.000
# Reward after 02615 episodes: -1.000
# Reward after 02616 episodes: 0.000
# Reward after 02617 episodes: 0.030
# Reward after 02618 episodes: -1.000
# Reward after 02619 episodes: 0.000
# Reward after 02620 episodes: -1.000
# Reward after 02621 episodes: -1.000
# Reward after 02622 episodes: -1.000
# Reward after 02623 episodes: -1.000
# Reward after 02624 episodes: -1.000
# Reward after 02625 episodes: 0.000
# Reward after 02626 episodes: 0.000
# Reward after 02627 episodes: 0.000
# Reward after 02628 episodes: 0.000
# Reward after 02629 episodes: 0.000
# Reward after 02630 episodes: 0.000
# Reward after 02631 episodes: 0.000
# Reward after 02632 episodes: -1.000
# Reward after 02633 episodes: -1.000
# Reward after 02634 episodes: 4.329
# Reward after 02635 episodes: 0.000
# Reward after 02636 episodes: 0.000
# Reward after 02637 episodes: 0.000
# Reward after 02638 episodes: 0.000
# Reward after 02639 episodes: -1.000
# Reward after 02640 episodes: 0.000
# Reward after 02641 episodes: -1.000
# Reward after 02642 episodes: 0.000
# Reward after 02643 episodes: -1.000
# Reward after 02644 episodes: -1.000
# Reward after 02645 episodes: -1.000
# Reward after 02646 episodes: 0.000
# Reward after 02647 episodes: -1.000
# Reward after 02648 episodes: 0.000
# Reward after 02649 episodes: -1.000
# Reward after 02650 episodes: 4.020
# Reward after 02651 episodes: 0.000
# Reward after 02652 episodes: 0.000
# Reward after 02653 episodes: 0.000
# Reward after 02654 episodes: 4.188
# Reward after 02655 episodes: 0.000
# Reward after 02656 episodes: 0.000
# Reward after 02657 episodes: 4.044
# Reward after 02658 episodes: 8.102
# Reward after 02659 episodes: 4.294
# Reward after 02660 episodes: 0.000
# Reward after 02661 episodes: 0.000
# Reward after 02662 episodes: 0.000
# Reward after 02663 episodes: 0.000
# Reward after 02664 episodes: 9.150
# Reward after 02665 episodes: 0.000
# Reward after 02666 episodes: 0.000
# Reward after 02667 episodes: 4.183
# Reward after 02668 episodes: -1.000
# Reward after 02669 episodes: -1.000
# Reward after 02670 episodes: 0.000
# Reward after 02671 episodes: -1.000
# Reward after 02672 episodes: -1.000
# Reward after 02673 episodes: -1.000
# Reward after 02674 episodes: 2.736
# Reward after 02675 episodes: 0.000
# Reward after 02676 episodes: 0.000
# Reward after 02677 episodes: 0.000
# Reward after 02678 episodes: 0.000
# Reward after 02679 episodes: 0.000
# Reward after 02680 episodes: 0.000
# Reward after 02681 episodes: -1.000
# Reward after 02682 episodes: 0.000
# Reward after 02683 episodes: 0.000
# Reward after 02684 episodes: 0.000
# Reward after 02685 episodes: 4.614
# Reward after 02686 episodes: -1.000
# Reward after 02687 episodes: 0.000
# Reward after 02688 episodes: 0.000
# Reward after 02689 episodes: 0.000
# Total execution time: 940.4263833333333 minutes
# <br/>Waiting for W&B process to finish, PID 14347<br/>Program failed with code 1.  Press ctrl-c to abort syncing.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/host/unity_builds/run32_training/wandb/run-20210604_211315-3dopwv83/logs/debug.log</code>
# Find internal logs for this run at: <code>/host/unity_builds/run32_training/wandb/run-20210604_211315-3dopwv83/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>2689</td></tr><tr><td>reward</td><td>0.0</td></tr><tr><td>_runtime</td><td>56428</td></tr><tr><td>_timestamp</td><td>1622897623</td></tr><tr><td>_step</td><td>2689</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>reward</td><td>█▁▁▁▁▇█▇████▇█████▄█▁██▁█▁▁▁▁▂▁▁████▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇█</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇█</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">still-dragon-1</strong>: <a href="https://wandb.ai/ademord/pytorch-DQN/runs/3dopwv83" target="_blank">https://wandb.ai/ademord/pytorch-DQN/runs/3dopwv83</a><br/>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-318ae2ededa3> in <module>
#       1 # Build, train and analyze the model with the pipeline
# ----> 2 model, env = model_pipeline(config)
#
# <ipython-input-33-d0bd6fe89dd6> in model_pipeline(hyperparameters)
#      17
#      18         # and use them to train the model
# ---> 19         train(model, env, criterion, optimizer, config)
#      20
#      21         # and test its final performance
#
# <ipython-input-29-2872183460f3> in _time_it(*args, **kwargs)
#       4         start = int(round(time() * 1000))
#       5         try:
# ----> 6             return func(*args, **kwargs)
#       7         finally:
#       8             end_ = int(round(time() * 1000)) - start
#
# <ipython-input-39-501153d9a4c7> in train(model, env, criterion, optimizer, config)
#      17         experiences.extend(new_exp)
#      18         Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
# ---> 19         _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
#      20         cumulative_rewards.append(rewards)
#      21         # print("Training step ", episode + 1, "\treward ", episode_rewards)
#
# <ipython-input-38-f28499b2bc09> in generate_trajectories(env, q_net, buffer_size, epsilon)
#     106       # Generate an action for all the Agents that requested a decision
#     107       # Compute the values for each action given the observation
# --> 108       act1, act2, act3 = q_net(torch.from_numpy(decision_steps.obs[0]))
#     109
#     110       if len(decision_steps) == 0:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-36-b05a41dfaa23> in forward(self, visual_obs)
#      23
#      24     def forward(self, visual_obs: torch.tensor):
# ---> 25         hidden = self.dense1(visual_obs)
#      26         hidden = self.act(hidden)
#      27         hidden = self.dense2(hidden)
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:

# %% [markdown]
# # 🧹 Test Hyperparameters with Sweeps

# %% [markdown]
# ## [Check out Hyperparameter Optimization in PyTorch using W&B Sweep $\rightarrow$](https://colab.research.google.com/drive/1QTIK23LBuAkdejbrvdP5hwBGyYlyEJpT?usp=sharing)
#
# Running a hyperparameter sweep with Weights & Biases is very easy. There are just 3 simple steps:
#
# 1. **Define the sweep:** We do this by creating a dictionary or a [YAML file](https://docs.wandb.com/library/sweeps/configuration) that specifies the parameters to search through, the search strategy, the optimization metric et all.
#
# 2. **Initialize the sweep:**
# `sweep_id = wandb.sweep(sweep_config)`
#
# 3. **Run the sweep agent:**
# `wandb.agent(sweep_id, function=train)`
#
# And voila! That's all there is to running a hyperparameter sweep!
# <img src="https://imgur.com/UiQKg0L.png" alt="Weights & Biases" />

# %% [markdown]
# # 🤓 Advanced Setup
# 1. [Environment variables](https://docs.wandb.com/library/environment-variables): Set API keys in environment variables so you can run training on a managed cluster.
# 2. [Offline mode](https://docs.wandb.com/library/technical-faq#can-i-run-wandb-offline): Use `dryrun` mode to train offline and sync results later.
# 3. [On-prem](https://docs.wandb.com/self-hosted): Install W&B in a private cloud or air-gapped servers in your own infrastructure. We have local installations for everyone from academics to enterprise teams.
# 4. [Sweeps](https://docs.wandb.com/sweeps): Set up hyperparameter search quickly with our lightweight tool for tuning.

# %%
# for n in range(NUM_TRAINING_STEPS):
#   new_exp,_ = Trainer.generate_trajectories(env, qnet, NUM_NEW_EXP, epsilon=0.1)
#   random.shuffle(experiences)
#   if len(experiences) > BUFFER_SIZE:
#     experiences = experiences[:BUFFER_SIZE]
#   experiences.extend(new_exp)
#   Trainer.update_q_net(qnet, optim, experiences, 3)
#   _, rewards = Trainer.generate_trajectories(env, qnet, 100, epsilon=0)
#   cumulative_rewards.append(rewards)
#   print("Training step ", n+1, "\treward ", rewards)
#   print()


# env.close()

# # Show the training graph
# plt.plot(range(NUM_TRAINING_STEPS), cumulative_rewards)

# %%
#  class UnityEnv(gym.Env):
#     """
#     Provides Gym wrapper for Unity Learning Environments.
#     Multi-agent environments use lists for object types, as done here:
#     https://github.com/openai/multiagent-particle-envs
#     """
 
#     def __init__(
#         self,
#         environment_filename: str,
#         dimensions: int = [],   #Added
#         timescale: int = 1,     #Added
#         worker_id: int = 0,
#         use_visual: bool = False,
#         uint8_visual: bool = False,
#         multiagent: bool = False,
#         flatten_branched: bool = False,
#         no_graphics: bool = False,
#         allow_multiple_visual_obs: bool = False,
#         set_config: bool = True,    #Added
#     ):
#         """
#         Environment initialization
#         :param environment_filename: The UnityEnvironment path or file to be wrapped in the gym.
#         :param worker_id: Worker number for environment.
#         :param use_visual: Whether to use visual observation or vector observation.
#         :param uint8_visual: Return visual observations as uint8 (0-255) matrices instead of float (0.0-1.0).
#         :param multiagent: Whether to run in multi-agent mode (lists of obs, reward, done).
#         :param flatten_branched: If True, turn branched discrete action spaces into a Discrete space rather than
#             MultiDiscrete.
#         :param no_graphics: Whether to run the Unity simulator in no-graphics mode
#         :param allow_multiple_visual_obs: If True, return a list of visual observations instead of only one.
#         """
#         base_port = 5005
#         if environment_filename is None:
#             base_port = UnityEnvironment.DEFAULT_EDITOR_PORT
 
#         channel = EngineConfigurationChannel()        # Added
 
 
#         #Added
#         if set_config == True:
#             channel.set_configuration_parameters(time_scale=timescale, width=dimensions[0], height=dimensions[1])
#         #Added
 
#         self._env = UnityEnvironment(
#             environment_filename,
#             worker_id,
#             base_port=base_port,
#             no_graphics=no_graphics,
#             side_channels=[channel],        # Added
#         )
