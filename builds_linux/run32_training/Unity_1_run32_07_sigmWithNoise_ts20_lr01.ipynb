# %% [markdown]
# # 🚀 Install, Import, and Log In

# %%
import mlagents
from mlagents_envs.environment import UnityEnvironment as UE
from mlagents_envs.environment import ActionTuple, BaseEnv
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
# import matplotlib.pyplot as plt
# %matplotlib inline
import random
from functools import wraps
from time import time


import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from tqdm.notebook import tqdm
from ipywidgets import IntProgress

from typing import Tuple, Dict
from math import floor

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
def measure(func):
    @wraps(func)
    def _time_it(*args, **kwargs):
        start = int(round(time() * 1000))
        try:
            return func(*args, **kwargs)
        finally:
            end_ = int(round(time() * 1000)) - start
            print(f"Total execution time: {end_/(1000*60) if end_ > 0 else 0} minutes")
    return _time_it

# %% [markdown]
# ### 0️⃣ Step 0: Install W&B

# %%
# %%capture
# !pip install wandb

# %% [markdown]
# ### 1️⃣ Step 1: Import W&B and Login

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: ademord (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# # 👩‍🔬 Define the Experiment and Pipeline

# %% [markdown]
# ### 2️⃣ Step 2: Track metadata and hyperparameters with `wandb.init`

# %%
config = dict(
    epochs=5,
    classes=10,
    kernels=[16, 32],
    batch_size=128,
    learning_rate=0.0001,
    dataset="MNIST",
    architecture="CNN",
    NUM_TRAINING_STEPS = 3000, #10000000
    NUM_TEST_STEPS = 10,
    NUM_NEW_EXP = 1000,
    BUFFER_SIZE = 10000,
    worker_id=2,
    time_scale=20,
    no_graphics = True
    )
env = None

# %%
def model_pipeline(hyperparameters):
    global env
    
    try:
        env.close()
    except:
        pass

    # tell wandb to get started
    with wandb.init(project="pytorch-DQN", config=hyperparameters):
        # access all HPs through wandb.config, so logging matches execution!
        config = wandb.config

        # make the model, data, and optimization problem
        model, env, criterion, optimizer = make(config)
        print(model)

        # and use them to train the model
        train(model, env, criterion, optimizer, config)

        # and test its final performance
        test(model, env, config)

        env.close()

    return model

# %%
def make(config):
    # Make the data
    env, spec = make_env(config)
    
    # Make the model
    # model = Agent(config.kernels, config.classes).to(device)
    model = QNetwork((44, 1), 126, 3)

    # Make the loss and optimizer
    criterion = torch.nn.MSELoss() # None # nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
    
    return model, env, criterion, optimizer

# %% [markdown]
# # 📡 Define the Env Loading and Model

# %%
def make_env(config):
    channel = EngineConfigurationChannel()
    env = UE("run32_training", seed=1, worker_id=config.worker_id, no_graphics=config.no_graphics, side_channels=[channel])
    channel.set_configuration_parameters(time_scale = config.time_scale)
    print("Environment created.")
    
    env.reset()
    behavior_name = list(env.behavior_specs)[0]
    print(f"Name of the behavior : {behavior_name}")
    
    spec = env.behavior_specs[behavior_name]
    print(f"Type of the spec : {spec}")
    
    return env, spec

# %%
class QNetwork(torch.nn.Module):
    def __init__(
        self,
        input_shape: Tuple[int], 
        encoding_size: int, 
        output_size: int
    ):
        """
        Creates a neural network that takes as input a batch of images (3
        dimensional tensors) and outputs a batch of outputs (1 dimensional
        tensors)
        """
        super(QNetwork, self).__init__()
        self.dense1 = torch.nn.Linear(input_shape[0], encoding_size)
        self.dense2 = torch.nn.Linear(encoding_size, encoding_size)

        self.dense2_x1 = torch.nn.Linear(encoding_size, output_size)
        self.dense2_x2 = torch.nn.Linear(encoding_size, output_size)
        self.dense2_x3 = torch.nn.Linear(encoding_size, output_size)

        self.act = torch.nn.ReLU()
        self.act_out = torch.nn.Sigmoid() # ReLU

    def forward(self, visual_obs: torch.tensor):
        hidden = self.dense1(visual_obs)
        hidden = self.act(hidden)
        hidden = self.dense2(hidden)
        hidden = self.act(hidden)
        x1 = self.dense2_x1(hidden)
        x2 = self.dense2_x2(hidden)
        x3 = self.dense2_x3(hidden)

        x1 = self.act(x1)
        x2 = self.act(x2)
        x3 = self.act(x3)

        return x1, x2, x3

# %%
import numpy as np
from typing import NamedTuple, List


class Experience(NamedTuple):
    """
    An experience contains the data of one Agent transition.
    - Observation
    - Action
    - Reward
    - Done flag
    - Next Observation
    """

    obs: np.ndarray
    action: np.ndarray
    reward: float
    done: bool
    next_obs: np.ndarray

# A Trajectory is an ordered sequence of Experiences
Trajectory = List[Experience]

# A Buffer is an unordered list of Experiences from multiple Trajectories
Buffer = List[Experience]

# %%
from mlagents_envs.environment import ActionTuple, BaseEnv
from typing import Dict
import random


class Trainer:
  @staticmethod
  def generate_trajectories(
    env: BaseEnv, q_net: QNetwork, buffer_size: int, epsilon: float
  ):
    """
    Given a Unity Environment and a Q-Network, this method will generate a
    buffer of Experiences obtained by running the Environment with the Policy
    derived from the Q-Network.
    :param BaseEnv: The UnityEnvironment used.
    :param q_net: The Q-Network used to collect the data.
    :param buffer_size: The minimum size of the buffer this method will return.
    :param epsilon: Will add a random normal variable with standard deviation.
    epsilon to the value heads of the Q-Network to encourage exploration.
    :returns: a Tuple containing the created buffer and the average cumulative
    the Agents obtained.
    """
    # Create an empty Buffer
    buffer: Buffer = []

    # Reset the environment
    env.reset()
    # Read and store the Behavior Name of the Environment
    behavior_name = list(env.behavior_specs)[0]
    # Read and store the Behavior Specs of the Environment
    spec = env.behavior_specs[behavior_name]

    # Create a Mapping from AgentId to Trajectories. This will help us create
    # trajectories for each Agents
    dict_trajectories_from_agent: Dict[int, Trajectory] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_obs_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to the last observation of the Agent
    dict_last_action_from_agent: Dict[int, np.ndarray] = {}
    # Create a Mapping from AgentId to cumulative reward (Only for reporting)
    dict_cumulative_reward_from_agent: Dict[int, float] = {}
    # Create a list to store the cumulative rewards obtained so far
    cumulative_rewards: List[float] = []
    
    
    entered_terminal = False
    while len(buffer) < buffer_size:  # While not enough data in the buffer
      # Get the Decision Steps and Terminal Steps of the Agents
      decision_steps, terminal_steps = env.get_steps(behavior_name)
    
        # For all Agents with a Terminal Step:
      for agent_id_terminated in terminal_steps:
#         print("entered agent with terminal step")
#         print(agent_id_terminated)

        # Create its last experience (is last because the Agent terminated)
        last_experience = Experience(
          obs=dict_last_obs_from_agent[agent_id_terminated].copy(),
          reward=terminal_steps[agent_id_terminated].reward,
          done=not terminal_steps[agent_id_terminated].interrupted,
          action=dict_last_action_from_agent[agent_id_terminated].copy(),
          next_obs=terminal_steps[agent_id_terminated].obs[0],
        )
        # Clear its last observation and action (Since the trajectory is over)
        dict_last_obs_from_agent.pop(agent_id_terminated)
        dict_last_action_from_agent.pop(agent_id_terminated)
        # Report the cumulative reward
        cumulative_reward = (
          dict_cumulative_reward_from_agent.pop(agent_id_terminated)
          + terminal_steps[agent_id_terminated].reward
        )
#         print("cumulative reward: ", cumulative_reward)
        cumulative_rewards.append(cumulative_reward) #  - 50
        # Add the Trajectory and the last experience to the buffer
        buffer.extend(dict_trajectories_from_agent.pop(agent_id_terminated))
        buffer.append(last_experience)
        entered_terminal = True

      # For all Agents with a Decision Step:
      for agent_id_decisions in decision_steps:
        # If the Agent does not have a Trajectory, create an empty one
        if agent_id_decisions not in dict_trajectories_from_agent:
          dict_trajectories_from_agent[agent_id_decisions] = []
          dict_cumulative_reward_from_agent[agent_id_decisions] = 0

        # If the Agent requesting a decision has a "last observation"
        if agent_id_decisions in dict_last_obs_from_agent:
          # Create an Experience from the last observation and the Decision Step
          exp = Experience(
            obs=dict_last_obs_from_agent[agent_id_decisions].copy(),
            reward=decision_steps[agent_id_decisions].reward, #  - 0.05
            done=False,
            action=dict_last_action_from_agent[agent_id_decisions].copy(),
            next_obs=decision_steps[agent_id_decisions].obs[0],
          )
          # Update the Trajectory of the Agent and its cumulative reward
          dict_trajectories_from_agent[agent_id_decisions].append(exp)
          dict_cumulative_reward_from_agent[agent_id_decisions] += (
            decision_steps[agent_id_decisions].reward
          )
        # Store the observation as the new "last observation"
        dict_last_obs_from_agent[agent_id_decisions] = (
          decision_steps[agent_id_decisions].obs[0]
        )

      # Generate an action for all the Agents that requested a decision
      # Compute the values for each action given the observation    
      act1, act2, act3 = q_net(torch.from_numpy(decision_steps.obs[0]))
    
      if len(decision_steps) == 0:
#             print("error: no more observations ! ")
            env.step()
            continue
#       if act1.size == 0:
#             print("error: Action space received = 0")
#             env.step()
#             continue
            
      # get actions as arrays
      act1 = act1.detach().numpy()
      act2 = act2.detach().numpy()
      act3 = act3.detach().numpy()
    
#       print("action received from QNetwork: ", act1)
#       print("action received from QNetwork: ", act2)
#       print("action received from QNetwork: ", act3)
      act1 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      act2 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      act3 += epsilon * np.random.randn(act1.shape[0], act1.shape[1]).astype(np.float32)
      
      # pick the best action using argmax
      act1 = np.argmax(act1, axis=1)
      act2 = np.argmax(act2, axis=1)
      act3 = np.argmax(act3, axis=1)
#       print("action received from argmax: ", act1)
#       print("action received from argmax: ", act1.shape)
#       act1 = np.array([act1])
#       act2 = np.array([act2])
#       act3 = np.array([act3])
      act1 = np.expand_dims(act1, axis=1)
      act2 = np.expand_dims(act2, axis=1)
      act3 = np.expand_dims(act3, axis=1)
#       print("action received from argmax expanded: ", act1)
#       print("action received from argmax expanded: ", act1.shape)

      # map action index 2 to -1 for the agent to move backwards, left, and rotate left
      act1[act1 > 1] = -1
      act2[act2 > 1] = -1
      act3[act3 > 1] = -1

      # format to numpy arrays
#       print("action received from mapping: ", act1)
#       try:
# #         actions_values = np.array([act1, act2, act3]).reshape(3,3)
#         actions_values = np.vstack((act1, act2, act3))
#       except:
#         actions_values = np.zeros((3,3))
#         print("error: network received an input of size 0 and i caught the error :/")

        #      0-8nt(type(actions_values))
    
    
#       actions =  np.vstack((act1, act2, act3))
#       actions =  np.vstack((act1, act2, act3))

      temp = np.hstack((act1, act2, act3))
#       print("actions stacked with hstack:", temp)
#       print("actions stacked with hstack: shape:", temp.shape)
#       temp = np.concatenate((act1, act2, act3), axis=1)
#       print("actions stacked with concat:", temp)
#       print("actions stacked with concat: shape:", temp.shape)
        
#       actions_values = np.zeros((3,3))
#       # Add some noise with epsilon to the values
#       actions_values += epsilon * np.random.randn(actions_values.shape[0], actions_values.shape[1]).astype(np.float32)
#       actions = np.argmax(actions_values, axis=1)
      
      actions = temp
#       print("final actions: ", actions)
#       print("final actions shape: ", actions.shape)
      actions.resize((len(decision_steps), 3))
#       print("decision steps size:", len(decision_steps))
#       print("final actions after resize: ", actions)
#       print("final actions shape: ", actions.shape)


      # Store the action that was picked, it will be put in the trajectory later
      for agent_index, agent_id in enumerate(decision_steps.agent_id):
        dict_last_action_from_agent[agent_id] = actions[agent_index]
#       print("dict last action: ", dict_last_action_from_agent)

        
      # Set the actions in the environment
      # Unity Environments expect ActionTuple instances.
      action_tuple = ActionTuple()
      action_tuple.add_discrete(actions)
#       print("filtered action received from QNetwork: ", action_tuple.discrete)
      env.set_actions(behavior_name, action_tuple)
      # Perform a step in the simulation
      env.step()
    return buffer, np.mean(cumulative_rewards)

  @staticmethod
  def update_q_net(
    q_net: QNetwork, 
    criterion: torch.nn.modules.loss,
    optimizer: torch.optim, 
    buffer: Buffer, 
    action_size: int
  ):
    """
    Performs an update of the Q-Network using the provided optimizer and buffer
    """
    def calculate_bellman_loss(next_pred_action, pred_action, reward, done, GAMMA, batch, action_size, action):
        # Use the Bellman equation to update the Q-Network
        target = (
          reward
          + (1.0 - done)
          * GAMMA
          * torch.max(next_pred_action.detach(), dim=1, keepdim=True).values
        ).double()
#         print("next_act_prediction:", next_pred_action.detach().numpy())
        
#         print("Target:", target)
#         print("Target shape:", target.shape)

#         print("action:", action)
#         print("action shape: ", action.shape)
        assert(action.shape[0] == len(batch))
        action[action < 0] = 2
#         print("action after correction:", action)
        
        mask = np.eye(action_size)[action]
#         mask = torch.zeros((len(batch), action_size))  
#         print("mask: ", mask)
#         print("mask shape: ", mask.shape)
#         mask.scatter_(1, action, 1)
#         print("mask after scatter: ", mask)
        mask = torch.from_numpy(mask).double()
#         print("pred_action: error", pred_action)
#         print(type(pred_action))
#         print(pred_action.dtype)
#         print(type(mask))
#         print(mask.dtype)
        prediction = torch.sum(pred_action.double() * mask, dim=1, keepdim=True)
#         print("act_prediction:", pred_action.detach().numpy())
#         print("prediction: ", prediction)
#         print("prediction shaPE: ", prediction.shape)
#         print("prediction type: ", type(prediction))
#         print("prediction dtype: ", prediction.dtype)
        
        criterion = torch.nn.MSELoss()
        loss = criterion(prediction, target)
        
        return loss

    BATCH_SIZE = 1000
    NUM_EPOCH = 3
    GAMMA = 0.9
    batch_size = min(len(buffer), BATCH_SIZE)
    random.shuffle(buffer)
    # Split the buffer into batches
    batches = [
      buffer[batch_size * start : batch_size * (start + 1)]
      for start in range(int(len(buffer) / batch_size))
    ]
    for _ in range(NUM_EPOCH):
      for batch in batches:
        # Create the Tensors that will be fed in the network
        obs = torch.from_numpy(np.stack([ex.obs for ex in batch]))
        reward = torch.from_numpy(
          np.array([ex.reward for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        done = torch.from_numpy(
          np.array([ex.done for ex in batch], dtype=np.float32).reshape(-1, 1)
        )
        action = torch.from_numpy(np.stack([ex.action for ex in batch]))
        next_obs = torch.from_numpy(np.stack([ex.next_obs for ex in batch]))
        
        # Prerequisite: collect outputs
        pnext_a1, pnext_a2, pnext_a3 = q_net(next_obs)
        p_a1, p_a2, p_a3 = q_net(obs)
        
        # bellman equation for each loss
        loss1 = calculate_bellman_loss(pnext_a1, p_a1, reward, done, GAMMA, batch, action_size, action[:, 0])
        loss2 = calculate_bellman_loss(pnext_a2, p_a2, reward, done, GAMMA, batch, action_size, action[:, 1])
        loss3 = calculate_bellman_loss(pnext_a3, p_a3, reward, done, GAMMA, batch, action_size, action[:, 2])
        loss = loss1 + loss2 + loss3
        
        # Perform the backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# # 👟 Define Training Logic

# %% [markdown]
# ### 3️⃣ Step 3. Track gradients with `wandb.watch` and everything else with `wandb.log`

# %%
@measure
def train(model, env, criterion, optimizer, config):
    wandb.watch(model, criterion, log="all", log_freq=10)
    experiences: Buffer = []

    cumulative_rewards: List[float] = []
    NUM_NEW_EXP = config.NUM_NEW_EXP
    BUFFER_SIZE = config.BUFFER_SIZE

    behavior_name = list(env.behavior_specs)[0]
        
    for episode in range(config.NUM_TRAINING_STEPS):
        new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
        random.shuffle(experiences)
        if len(experiences) > BUFFER_SIZE:
            experiences = experiences[:BUFFER_SIZE]
        experiences.extend(new_exp)
        Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
        _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
        cumulative_rewards.append(rewards)
        # print("Training step ", episode + 1, "\treward ", episode_rewards)
        train_log(rewards, episode)

# %%
# @measure
# def train(model, env, criterion, optimizer, config):
# #     wandb.watch(model, criterion, log="all", log_freq=10)

#     behavior_name = list(env.behavior_specs)[0]
        
#     for episode in range(config.NUM_TRAINING_STEPS):
#         env.reset()
#         decision_steps, terminal_steps = env.get_steps(behavior_name)
#         tracked_agent = -1 # -1 indicates not yet tracking
#         done = False # For the tracked_agent
#         episode_rewards = 0 # For the tracked_agent
        
#         while not done:
#             # Track the first agent we see if not tracking 
#             # Note : len(decision_steps) = [numberb of agents that requested a decision]
#             if tracked_agent == -1 and len(decision_steps) >= 1:
#                 tracked_agent = decision_steps.agent_id[0] 

#             # Generate an action for all agents
#             # these are the observations
# #             print(decision_steps[0])
#             action = model.get_action(decision_steps)
#     #         print(action.discrete)
#             # Set the actions
#             env.set_actions(behavior_name, action)

#             # Move the simulation forward
#             env.step()

#             # Get the new simulation results
#             decision_steps, terminal_steps = env.get_steps(behavior_name)
#             if tracked_agent in decision_steps: # The agent requested a decision
#                 episode_rewards += decision_steps[tracked_agent].reward
#             if tracked_agent in terminal_steps: # The agent terminated its episode
#                 print("reward on terminal step:", terminal_steps[tracked_agent].reward)
#                 episode_rewards += terminal_steps[tracked_agent].reward
#                 done = True
#         # print("Training step ", episode + 1, "\treward ", episode_rewards)
#         train_log(episode_rewards, episode)

# %%
def train_log(reward, episode):
#     loss = float(loss)
    reward = float(reward)
    episode +=1
    
    # where the magic happens
    wandb.log({"episode": episode, "reward": reward}) #, step=example_ct
    print(f"Reward after " + str(episode).zfill(5) + f" episodes: {reward:.3f}")

# %% [markdown]
# # 🧪 Define Testing Logic

# %% [markdown]
# #### 4️⃣ Optional Step 4: Call `wandb.save`

# %%
def test(model, env, config):
    model.eval()

    # Run the model on some test examples
    with torch.no_grad():
        experiences: Buffer = []
        cumulative_rewards: List[float] = []
        NUM_NEW_EXP = config.NUM_NEW_EXP
        BUFFER_SIZE = config.BUFFER_SIZE

        behavior_name = list(env.behavior_specs)[0]

        for episode in range(config.NUM_TEST_STEPS):
            new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
            random.shuffle(experiences)
            if len(experiences) > BUFFER_SIZE:
                experiences = experiences[:BUFFER_SIZE]
            experiences.extend(new_exp)
#                 Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
            _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
            cumulative_rewards.append(rewards)
            # print("Training step ", episode + 1, "\treward ", episode_rewards)

        print(f"Average reward of the model after {config.NUM_TEST_STEPS} " +
              f"test episodes: {numpy.mean(cumulative_rewards)}%")

        wandb.log({"test_average_reward": numpy.mean(cumulative_rewards)})

    # Save the model in the exchangeable ONNX format
    torch.onnx.export(model, [], "model.onnx")
    wandb.save("model.onnx")

# %% [markdown]
# # 🏃‍♀️ Run training and watch your metrics live on [wandb.ai](https://wandb.ai)!

# %%
# Build, train and analyze the model with the pipeline
model, env = model_pipeline(config)
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">eager-shape-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ademord/pytorch-DQN" target="_blank">https://wandb.ai/ademord/pytorch-DQN</a><br/>
#                 Run page: <a href="https://wandb.ai/ademord/pytorch-DQN/runs/1qddottr" target="_blank">https://wandb.ai/ademord/pytorch-DQN/runs/1qddottr</a><br/>
#                 Run data is saved locally in <code>/host/unity_builds/run32_training/wandb/run-20210605_154708-1qddottr</code><br/><br/>
# Environment created.
# Name of the behavior : Hummingbird?team=0
# Type of the spec : BehaviorSpec(observation_specs=[ObservationSpec(shape=(44,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='RayPerceptionSensor'), ObservationSpec(shape=(3,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='StackingSensor_size3_VectorSensor_size1')], action_spec=ActionSpec(continuous_size=0, discrete_branches=(3, 3, 3)))
# QNetwork(
#   (dense1): Linear(in_features=44, out_features=126, bias=True)
#   (dense2): Linear(in_features=126, out_features=126, bias=True)
#   (dense2_x1): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x2): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x3): Linear(in_features=126, out_features=3, bias=True)
#   (act): ReLU()
#   (act_out): Sigmoid()
# )
# Reward after 00001 episodes: -1.000
# Reward after 00002 episodes: 49.424
# Reward after 00003 episodes: 20.949
# Reward after 00004 episodes: -1.000
# Reward after 00005 episodes: 43.457
# Reward after 00006 episodes: 28.868
# Reward after 00007 episodes: 13.832
# Reward after 00008 episodes: 28.686
# Reward after 00009 episodes: 33.284
# Reward after 00010 episodes: 27.957
# Reward after 00011 episodes: 66.572
# Reward after 00012 episodes: 40.227
# Reward after 00013 episodes: 47.404
# Reward after 00014 episodes: 41.232
# Reward after 00015 episodes: 43.394
# Reward after 00016 episodes: 25.972
# Reward after 00017 episodes: 37.788
# Reward after 00018 episodes: 40.122
# Reward after 00019 episodes: 43.676
# Reward after 00020 episodes: 34.035
# Reward after 00021 episodes: 86.751
# Reward after 00022 episodes: 38.666
# Reward after 00023 episodes: 59.996
# Reward after 00024 episodes: 41.331
# Reward after 00025 episodes: 36.091
# Reward after 00026 episodes: 35.277
# Reward after 00027 episodes: 42.818
# Reward after 00028 episodes: 41.105
# Reward after 00029 episodes: 69.775
# Reward after 00030 episodes: 36.106
# Reward after 00031 episodes: 33.295
# Reward after 00032 episodes: 58.132
# Reward after 00033 episodes: 80.829
# Reward after 00034 episodes: 46.729
# Reward after 00035 episodes: 100.631
# Reward after 00036 episodes: 53.931
# Reward after 00037 episodes: 41.114
# Reward after 00038 episodes: 47.643
# Reward after 00039 episodes: 89.069
# Reward after 00040 episodes: 207.250
# Reward after 00041 episodes: 48.873
# Reward after 00042 episodes: 437.806
# Reward after 00043 episodes: 110.873
# Reward after 00044 episodes: 87.145
# Reward after 00045 episodes: 56.754
# Reward after 00046 episodes: 115.357
# Reward after 00047 episodes: 232.383
# Reward after 00048 episodes: 55.273
# Reward after 00049 episodes: 49.815
# Reward after 00050 episodes: 40.332
# Reward after 00051 episodes: 59.126
# Reward after 00052 episodes: 484.541
# Reward after 00053 episodes: 555.046
# Reward after 00054 episodes: 207.041
# Reward after 00055 episodes: 360.677
# Reward after 00056 episodes: 85.235
# Reward after 00057 episodes: 243.970
# Reward after 00058 episodes: 85.260
# Reward after 00059 episodes: 78.592
# Reward after 00060 episodes: 49.333
# Reward after 00061 episodes: 47.538
# Reward after 00062 episodes: 93.705
# Reward after 00063 episodes: 71.443
# Reward after 00064 episodes: 38.331
# Reward after 00065 episodes: 36.600
# Reward after 00066 episodes: 59.881
# Reward after 00067 episodes: 61.428
# Reward after 00068 episodes: 49.606
# Reward after 00069 episodes: 53.886
# Reward after 00070 episodes: 46.399
# Reward after 00071 episodes: 39.689
# Reward after 00072 episodes: 63.931
# Reward after 00073 episodes: 70.489
# Reward after 00074 episodes: 51.905
# Reward after 00075 episodes: 65.909
# Reward after 00076 episodes: 56.913
# Reward after 00077 episodes: 51.141
# Reward after 00078 episodes: 62.194
# Reward after 00079 episodes: 66.266
# Reward after 00080 episodes: 53.736
# Reward after 00081 episodes: 45.575
# Reward after 00082 episodes: 51.693
# Reward after 00083 episodes: 53.648
# Reward after 00084 episodes: 47.539
# Reward after 00085 episodes: 77.311
# Reward after 00086 episodes: 66.783
# Reward after 00087 episodes: 52.876
# Reward after 00088 episodes: 69.505
# Reward after 00089 episodes: 47.202
# Reward after 00090 episodes: 58.325
# Reward after 00091 episodes: 60.291
# Reward after 00092 episodes: 85.756
# Reward after 00093 episodes: 45.886
# Reward after 00094 episodes: 89.513
# Reward after 00095 episodes: 62.206
# Reward after 00096 episodes: 70.031
# Reward after 00097 episodes: 89.204
# Reward after 00098 episodes: 52.258
# Reward after 00099 episodes: 73.210
# Reward after 00100 episodes: 92.106
# Reward after 00101 episodes: 56.696
# Reward after 00102 episodes: 87.902
# Reward after 00103 episodes: 53.092
# Reward after 00104 episodes: 51.469
# Reward after 00105 episodes: 78.365
# Reward after 00106 episodes: 51.704
# Reward after 00107 episodes: 69.878
# Reward after 00108 episodes: 101.371
# Reward after 00109 episodes: 95.153
# Reward after 00110 episodes: 76.379
# Reward after 00111 episodes: 106.974
# Reward after 00112 episodes: 98.248
# Reward after 00113 episodes: 53.833
# Reward after 00114 episodes: 84.781
# Reward after 00115 episodes: 55.161
# Reward after 00116 episodes: 49.660
# Reward after 00117 episodes: 70.367
# Reward after 00118 episodes: 68.894
# Reward after 00119 episodes: 56.526
# Reward after 00120 episodes: 74.732
# Reward after 00121 episodes: 52.617
# Reward after 00122 episodes: 65.235
# Reward after 00123 episodes: 76.462
# Reward after 00124 episodes: 53.564
# Reward after 00125 episodes: 61.225
# Reward after 00126 episodes: 68.141
# Reward after 00127 episodes: 80.404
# Reward after 00128 episodes: 93.403
# Reward after 00129 episodes: 89.881
# Reward after 00130 episodes: 98.937
# Reward after 00131 episodes: 67.128
# Reward after 00132 episodes: 90.921
# Reward after 00133 episodes: 93.887
# Reward after 00134 episodes: 99.378
# Reward after 00135 episodes: 89.258
# Reward after 00136 episodes: 89.660
# Reward after 00137 episodes: 85.457
# Reward after 00138 episodes: 74.376
# Reward after 00139 episodes: 84.782
# Reward after 00140 episodes: 84.062
# Reward after 00141 episodes: 88.179
# Reward after 00142 episodes: 69.350
# Reward after 00143 episodes: 92.812
# Reward after 00144 episodes: 76.008
# Reward after 00145 episodes: 87.336
# Reward after 00146 episodes: 96.001
# Reward after 00147 episodes: 75.870
# Reward after 00148 episodes: 80.988
# Reward after 00149 episodes: 109.925
# Reward after 00150 episodes: 90.023
# Reward after 00151 episodes: 99.437
# Reward after 00152 episodes: 100.342
# Reward after 00153 episodes: 94.132
# Reward after 00154 episodes: 90.790
# Reward after 00155 episodes: 73.261
# Reward after 00156 episodes: 93.036
# Reward after 00157 episodes: 103.823
# Reward after 00158 episodes: 66.691
# Reward after 00159 episodes: 100.939
# Reward after 00160 episodes: 80.021
# Reward after 00161 episodes: 88.145
# Reward after 00162 episodes: 68.105
# Reward after 00163 episodes: 93.051
# Reward after 00164 episodes: 96.656
# Reward after 00165 episodes: 23.131
# Reward after 00166 episodes: 80.814
# Reward after 00167 episodes: 73.357
# Reward after 00168 episodes: 40.255
# Reward after 00169 episodes: 29.363
# Reward after 00170 episodes: 25.906
# Reward after 00171 episodes: 92.321
# Reward after 00172 episodes: 74.188
# Reward after 00173 episodes: 82.470
# Reward after 00174 episodes: 72.061
# Reward after 00175 episodes: 24.308
# Reward after 00176 episodes: 88.115
# Reward after 00177 episodes: 27.322
# Reward after 00178 episodes: 42.708
# Reward after 00179 episodes: 41.863
# Reward after 00180 episodes: 60.422
# Reward after 00181 episodes: 89.677
# Reward after 00182 episodes: 82.918
# Reward after 00183 episodes: 135.682
# Reward after 00184 episodes: 74.862
# Reward after 00185 episodes: 94.509
# Reward after 00186 episodes: 106.301
# Reward after 00187 episodes: 55.130
# Reward after 00188 episodes: 47.309
# Reward after 00189 episodes: 40.766
# Reward after 00190 episodes: 31.548
# Reward after 00191 episodes: 30.502
# Reward after 00192 episodes: 62.270
# Reward after 00193 episodes: 57.633
# Reward after 00194 episodes: 54.621
# Reward after 00195 episodes: 229.806
# Reward after 00196 episodes: 59.353
# Reward after 00197 episodes: 86.418
# Reward after 00198 episodes: 73.112
# Reward after 00199 episodes: 137.759
# Reward after 00200 episodes: 95.857
# Reward after 00201 episodes: 144.584
# Reward after 00202 episodes: 77.977
# Reward after 00203 episodes: 224.710
# Reward after 00204 episodes: 85.620
# Reward after 00205 episodes: 96.795
# Reward after 00206 episodes: 93.137
# Reward after 00207 episodes: 80.409
# Reward after 00208 episodes: 106.075
# Reward after 00209 episodes: 282.146
# Reward after 00210 episodes: 99.306
# Reward after 00211 episodes: 77.995
# Reward after 00212 episodes: 75.073
# Reward after 00213 episodes: 99.885
# Reward after 00214 episodes: 74.564
# Reward after 00215 episodes: 67.864
# Reward after 00216 episodes: 79.762
# Reward after 00217 episodes: 134.960
# Reward after 00218 episodes: 213.787
# Reward after 00219 episodes: 41.396
# Reward after 00220 episodes: 115.045
# Reward after 00221 episodes: 16.585
# Reward after 00222 episodes: 15.074
# Reward after 00223 episodes: 17.595
# Reward after 00224 episodes: 119.070
# Reward after 00225 episodes: 42.684
# Reward after 00226 episodes: 35.360
# Reward after 00227 episodes: 35.420
# Reward after 00228 episodes: 144.006
# Reward after 00229 episodes: 103.656
# Reward after 00230 episodes: 145.450
# Reward after 00231 episodes: 96.641
# Reward after 00232 episodes: 117.415
# Reward after 00233 episodes: 286.453
# Reward after 00234 episodes: 245.184
# Reward after 00235 episodes: 268.869
# Reward after 00236 episodes: 268.653
# Reward after 00237 episodes: 189.904
# Reward after 00238 episodes: 66.887
# Reward after 00239 episodes: 75.121
# Reward after 00240 episodes: 297.665
# Reward after 00241 episodes: 57.321
# Reward after 00242 episodes: 80.972
# Reward after 00243 episodes: 101.975
# Reward after 00244 episodes: 124.789
# Reward after 00245 episodes: 133.329
# Reward after 00246 episodes: 59.204
# Reward after 00247 episodes: 109.771
# Reward after 00248 episodes: 64.009
# Reward after 00249 episodes: 63.295
# Reward after 00250 episodes: 171.008
# Reward after 00251 episodes: 53.032
# Reward after 00252 episodes: 310.468
# Reward after 00253 episodes: 360.438
# Reward after 00254 episodes: 207.085
# Reward after 00255 episodes: 361.660
# Reward after 00256 episodes: 361.007
# Reward after 00257 episodes: 228.398
# Reward after 00258 episodes: 72.701
# Reward after 00259 episodes: 114.050
# Reward after 00260 episodes: 115.963
# Reward after 00261 episodes: 417.753
# Reward after 00262 episodes: 220.041
# Reward after 00263 episodes: 376.596
# Reward after 00264 episodes: 286.534
# Reward after 00265 episodes: 375.985
# Reward after 00266 episodes: 364.253
# Reward after 00267 episodes: 388.416
# Reward after 00268 episodes: 58.201
# Reward after 00269 episodes: 101.112
# Reward after 00270 episodes: 433.863
# Reward after 00271 episodes: 45.551
# Reward after 00272 episodes: 394.090
# Reward after 00273 episodes: 355.836
# Reward after 00274 episodes: 134.545
# Reward after 00275 episodes: 111.740
# Reward after 00276 episodes: 166.957
# Reward after 00277 episodes: 167.033
# Reward after 00278 episodes: 358.232
# Reward after 00279 episodes: 347.736
# Reward after 00280 episodes: 341.589
# Reward after 00281 episodes: 403.110
# Reward after 00282 episodes: 420.774
# Reward after 00283 episodes: 325.987
# Reward after 00284 episodes: 337.082
# Reward after 00285 episodes: 194.165
# Reward after 00286 episodes: 246.948
# Reward after 00287 episodes: 217.986
# Reward after 00288 episodes: 332.768
# Reward after 00289 episodes: 434.964
# Reward after 00290 episodes: 421.196
# Reward after 00291 episodes: 319.341
# Reward after 00292 episodes: 293.722
# Reward after 00293 episodes: 331.035
# Reward after 00294 episodes: 226.409
# Reward after 00295 episodes: 190.550
# Reward after 00296 episodes: 211.416
# Reward after 00297 episodes: 180.509
# Reward after 00298 episodes: 90.950
# Reward after 00299 episodes: 102.579
# Reward after 00300 episodes: 161.830
# Reward after 00301 episodes: 42.833
# Reward after 00302 episodes: 108.004
# Reward after 00303 episodes: 109.204
# Reward after 00304 episodes: 84.141
# Reward after 00305 episodes: 106.313
# Reward after 00306 episodes: 156.650
# Reward after 00307 episodes: 94.611
# Reward after 00308 episodes: 111.799
# Reward after 00309 episodes: 134.107
# Reward after 00310 episodes: 142.501
# Reward after 00311 episodes: 165.561
# Reward after 00312 episodes: 162.358
# Reward after 00313 episodes: 95.606
# Reward after 00314 episodes: 114.908
# Reward after 00315 episodes: 128.354
# Reward after 00316 episodes: 141.459
# Reward after 00317 episodes: 293.306
# Reward after 00318 episodes: 99.275
# Reward after 00319 episodes: 139.481
# Reward after 00320 episodes: 70.191
# Reward after 00321 episodes: 113.504
# Reward after 00322 episodes: 161.839
# Reward after 00323 episodes: 71.518
# Reward after 00324 episodes: 106.324
# Reward after 00325 episodes: 153.535
# Reward after 00326 episodes: 87.956
# Reward after 00327 episodes: 88.632
# Reward after 00328 episodes: 200.288
# Reward after 00329 episodes: 118.498
# Reward after 00330 episodes: 250.580
# Reward after 00331 episodes: 101.931
# Reward after 00332 episodes: 230.476
# Reward after 00333 episodes: 220.264
# Reward after 00334 episodes: 220.427
# Reward after 00335 episodes: 128.350
# Reward after 00336 episodes: 207.230
# Reward after 00337 episodes: 130.509
# Reward after 00338 episodes: 161.058
# Reward after 00339 episodes: 374.546
# Reward after 00340 episodes: 173.020
# Reward after 00341 episodes: 377.463
# Reward after 00342 episodes: 178.825
# Reward after 00343 episodes: 213.763
# Reward after 00344 episodes: 412.862
# Reward after 00345 episodes: 435.618
# Reward after 00346 episodes: 447.696
# Reward after 00347 episodes: 418.072
# Reward after 00348 episodes: 436.034
# Reward after 00349 episodes: 460.975
# Reward after 00350 episodes: 425.931
# Reward after 00351 episodes: 84.216
# Reward after 00352 episodes: 381.800
# Reward after 00353 episodes: 244.297
# Reward after 00354 episodes: 189.072
# Reward after 00355 episodes: 262.017
# Reward after 00356 episodes: 365.230
# Reward after 00357 episodes: 148.839
# Reward after 00358 episodes: 246.413
# Reward after 00359 episodes: 121.757
# Reward after 00360 episodes: 173.274
# Reward after 00361 episodes: 79.362
# Reward after 00362 episodes: 146.704
# Reward after 00363 episodes: 307.572
# Reward after 00364 episodes: 86.873
# Reward after 00365 episodes: 110.484
# Reward after 00366 episodes: 89.274
# Reward after 00367 episodes: 358.119
# Reward after 00368 episodes: 357.834
# Reward after 00369 episodes: 146.451
# Reward after 00370 episodes: 96.170
# Reward after 00371 episodes: 119.326
# Reward after 00372 episodes: 74.419
# Reward after 00373 episodes: 114.137
# Reward after 00374 episodes: 122.474
# Reward after 00375 episodes: 85.863
# Reward after 00376 episodes: 189.992
# Reward after 00377 episodes: 186.612
# Reward after 00378 episodes: 238.629
# Reward after 00379 episodes: 112.331
# Reward after 00380 episodes: 109.235
# Reward after 00381 episodes: 94.509
# Reward after 00382 episodes: 134.597
# Reward after 00383 episodes: 205.240
# Reward after 00384 episodes: 216.103
# Reward after 00385 episodes: 135.195
# Reward after 00386 episodes: 411.574
# Reward after 00387 episodes: 217.049
# Reward after 00388 episodes: 66.921
# Reward after 00389 episodes: 58.278
# Reward after 00390 episodes: 39.215
# Reward after 00391 episodes: 35.070
# Reward after 00392 episodes: 43.379
# Reward after 00393 episodes: 50.120
# Reward after 00394 episodes: 38.168
# Reward after 00395 episodes: 57.637
# Reward after 00396 episodes: 63.188
# Reward after 00397 episodes: 53.077
# Reward after 00398 episodes: 42.467
# Reward after 00399 episodes: 82.246
# Reward after 00400 episodes: 67.585
# Reward after 00401 episodes: 70.871
# Reward after 00402 episodes: 58.436
# Reward after 00403 episodes: 70.077
# Reward after 00404 episodes: 50.269
# Reward after 00405 episodes: 77.037
# Reward after 00406 episodes: 108.663
# Reward after 00407 episodes: 69.224
# Reward after 00408 episodes: 42.506
# Reward after 00409 episodes: 73.699
# Reward after 00410 episodes: 74.503
# Reward after 00411 episodes: 60.316
# Reward after 00412 episodes: 101.155
# Reward after 00413 episodes: 100.883
# Reward after 00414 episodes: 39.609
# Reward after 00415 episodes: 98.242
# Reward after 00416 episodes: 87.446
# Reward after 00417 episodes: 64.733
# Reward after 00418 episodes: 107.816
# Reward after 00419 episodes: 47.111
# Reward after 00420 episodes: 94.235
# Reward after 00421 episodes: 78.147
# Reward after 00422 episodes: 107.269
# Reward after 00423 episodes: 128.026
# Reward after 00424 episodes: 120.313
# Reward after 00425 episodes: 122.687
# Reward after 00426 episodes: 108.199
# Reward after 00427 episodes: 116.846
# Reward after 00428 episodes: 120.834
# Reward after 00429 episodes: 104.718
# Reward after 00430 episodes: 129.203
# Reward after 00431 episodes: 123.585
# Reward after 00432 episodes: 86.154
# Reward after 00433 episodes: 109.617
# Reward after 00434 episodes: 144.179
# Reward after 00435 episodes: 117.809
# Reward after 00436 episodes: 203.883
# Reward after 00437 episodes: 193.198
# Reward after 00438 episodes: 103.209
# Reward after 00439 episodes: 119.902
# Reward after 00440 episodes: 242.783
# Reward after 00441 episodes: 137.340
# Reward after 00442 episodes: 167.698
# Reward after 00443 episodes: 130.057
# Reward after 00444 episodes: 124.191
# Reward after 00445 episodes: 134.920
# Reward after 00446 episodes: 151.382
# Reward after 00447 episodes: -1.000
# Reward after 00448 episodes: 307.333
# Reward after 00449 episodes: 158.037
# Reward after 00450 episodes: 430.643
# Reward after 00451 episodes: 398.206
# Reward after 00452 episodes: 414.543
# Reward after 00453 episodes: 468.553
# Reward after 00454 episodes: 323.095
# Reward after 00455 episodes: 90.271
# Reward after 00456 episodes: 142.921
# Reward after 00457 episodes: 134.783
# Reward after 00458 episodes: 145.591
# Reward after 00459 episodes: 149.080
# Reward after 00460 episodes: 115.992
# Reward after 00461 episodes: 134.553
# Reward after 00462 episodes: 122.113
# Reward after 00463 episodes: 178.216
# Reward after 00464 episodes: 123.006
# Reward after 00465 episodes: 174.085
# Reward after 00466 episodes: 180.156
# Reward after 00467 episodes: 129.416
# Reward after 00468 episodes: 153.281
# Reward after 00469 episodes: 155.628
# Reward after 00470 episodes: 129.923
# Reward after 00471 episodes: 193.379
# Reward after 00472 episodes: 391.953
# Reward after 00473 episodes: 156.421
# Reward after 00474 episodes: 163.299
# Reward after 00475 episodes: 154.246
# Reward after 00476 episodes: 174.980
# Reward after 00477 episodes: 235.746
# Reward after 00478 episodes: 158.506
# Reward after 00479 episodes: 193.742
# Reward after 00480 episodes: 168.002
# Reward after 00481 episodes: 146.641
# Reward after 00482 episodes: 312.363
# Reward after 00483 episodes: 153.690
# Reward after 00484 episodes: 331.271
# Reward after 00485 episodes: 269.734
# Reward after 00486 episodes: 386.276
# Reward after 00487 episodes: 336.198
# Reward after 00488 episodes: 347.681
# Reward after 00489 episodes: 313.042
# Reward after 00490 episodes: 236.337
# Reward after 00491 episodes: 296.697
# Reward after 00492 episodes: 316.782
# Reward after 00493 episodes: 314.645
# Reward after 00494 episodes: 311.965
# Reward after 00495 episodes: 315.494
# Reward after 00496 episodes: 233.019
# Reward after 00497 episodes: 236.644
# Reward after 00498 episodes: 421.645
# Reward after 00499 episodes: 341.023
# Reward after 00500 episodes: 419.106
# Reward after 00501 episodes: 400.797
# Reward after 00502 episodes: 369.918
# Reward after 00503 episodes: 44.070
# Reward after 00504 episodes: 42.014
# Reward after 00505 episodes: 69.818
# Reward after 00506 episodes: 303.609
# Reward after 00507 episodes: 45.812
# Reward after 00508 episodes: 386.692
# Reward after 00509 episodes: 52.113
# Reward after 00510 episodes: 51.114
# Reward after 00511 episodes: 375.217
# Reward after 00512 episodes: 212.737
# Reward after 00513 episodes: 363.476
# Reward after 00514 episodes: 299.190
# Reward after 00515 episodes: 487.619
# Reward after 00516 episodes: 390.180
# Reward after 00517 episodes: 413.135
# Reward after 00518 episodes: 428.202
# Reward after 00519 episodes: 438.114
# Reward after 00520 episodes: 149.447
# Reward after 00521 episodes: 503.021
# Reward after 00522 episodes: 415.221
# Reward after 00523 episodes: 438.020
# Reward after 00524 episodes: 388.516
# Reward after 00525 episodes: 180.381
# Reward after 00526 episodes: 458.136
# Reward after 00527 episodes: 296.725
# Reward after 00528 episodes: 260.533
# Reward after 00529 episodes: 391.911
# Reward after 00530 episodes: 176.124
# Reward after 00531 episodes: 256.921
# Reward after 00532 episodes: 311.960
# Reward after 00533 episodes: 299.291
# Reward after 00534 episodes: 378.226
# Reward after 00535 episodes: 462.902
# Reward after 00536 episodes: 318.976
# Reward after 00537 episodes: 444.136
# Reward after 00538 episodes: 353.185
# Reward after 00539 episodes: 463.371
# Reward after 00540 episodes: 319.892
# Reward after 00541 episodes: 501.618
# Reward after 00542 episodes: 496.351
# Reward after 00543 episodes: 451.764
# Reward after 00544 episodes: 465.351
# Reward after 00545 episodes: 456.584
# Reward after 00546 episodes: 480.074
# Reward after 00547 episodes: 433.330
# Reward after 00548 episodes: 445.537
# Reward after 00549 episodes: 444.544
# Reward after 00550 episodes: 165.204
# Reward after 00551 episodes: 241.552
# Reward after 00552 episodes: 491.041
# Reward after 00553 episodes: 136.750
# Reward after 00554 episodes: 496.671
# Reward after 00555 episodes: 517.302
# Reward after 00556 episodes: 494.125
# Reward after 00557 episodes: 167.967
# Reward after 00558 episodes: 575.810
# Reward after 00559 episodes: 563.501
# Reward after 00560 episodes: 501.554
# Reward after 00561 episodes: 322.295
# Reward after 00562 episodes: 553.388
# Reward after 00563 episodes: 474.262
# Reward after 00564 episodes: 402.613
# Reward after 00565 episodes: 521.313
# Reward after 00566 episodes: 546.157
# Reward after 00567 episodes: 528.505
# Reward after 00568 episodes: 529.816
# Reward after 00569 episodes: 196.598
# Reward after 00570 episodes: 157.233
# Reward after 00571 episodes: 167.804
# Reward after 00572 episodes: 92.740
# Reward after 00573 episodes: 82.765
# Reward after 00574 episodes: 39.954
# Reward after 00575 episodes: 15.343
# Reward after 00576 episodes: 70.469
# Reward after 00577 episodes: 374.154
# Reward after 00578 episodes: 613.132
# Reward after 00579 episodes: 576.843
# Reward after 00580 episodes: 227.037
# Reward after 00581 episodes: 216.580
# Reward after 00582 episodes: 543.845
# Reward after 00583 episodes: 593.316
# Reward after 00584 episodes: 291.432
# Reward after 00585 episodes: 321.044
# Reward after 00586 episodes: 275.820
# Reward after 00587 episodes: 314.941
# Reward after 00588 episodes: 292.053
# Reward after 00589 episodes: 276.090
# Reward after 00590 episodes: 209.339
# Reward after 00591 episodes: 229.279
# Reward after 00592 episodes: 186.261
# Reward after 00593 episodes: -1.000
# Reward after 00594 episodes: 92.656
# Reward after 00595 episodes: 129.638
# Reward after 00596 episodes: 157.388
# Reward after 00597 episodes: 118.479
# Reward after 00598 episodes: 21.045
# Reward after 00599 episodes: 102.921
# Reward after 00600 episodes: 64.247
# Reward after 00601 episodes: 127.997
# Reward after 00602 episodes: 163.561
# Reward after 00603 episodes: 155.892
# Reward after 00604 episodes: 122.942
# Reward after 00605 episodes: 153.591
# Reward after 00606 episodes: 137.366
# Reward after 00607 episodes: 171.516
# Reward after 00608 episodes: 171.667
# Reward after 00609 episodes: 131.816
# Reward after 00610 episodes: 143.918
# Reward after 00611 episodes: 153.487
# Reward after 00612 episodes: 175.685
# Reward after 00613 episodes: 189.148
# Reward after 00614 episodes: 201.255
# Reward after 00615 episodes: 173.954
# Reward after 00616 episodes: 237.289
# Reward after 00617 episodes: 272.805
# Reward after 00618 episodes: 232.319
# Reward after 00619 episodes: 310.347
# Reward after 00620 episodes: 213.718
# Reward after 00621 episodes: 196.293
# Reward after 00622 episodes: 210.490
# Reward after 00623 episodes: 179.893
# Reward after 00624 episodes: 167.930
# Reward after 00625 episodes: 235.123
# Reward after 00626 episodes: 128.604
# Reward after 00627 episodes: 189.443
# Reward after 00628 episodes: 127.078
# Reward after 00629 episodes: 281.986
# Reward after 00630 episodes: 193.446
# Reward after 00631 episodes: 180.871
# Reward after 00632 episodes: 287.132
# Reward after 00633 episodes: 208.239
# Reward after 00634 episodes: 124.959
# Reward after 00635 episodes: 178.618
# Reward after 00636 episodes: 155.413
# Reward after 00637 episodes: 213.231
# Reward after 00638 episodes: 318.336
# Reward after 00639 episodes: 211.672
# Reward after 00640 episodes: 219.056
# Reward after 00641 episodes: 226.063
# Reward after 00642 episodes: 170.219
# Reward after 00643 episodes: 168.475
# Reward after 00644 episodes: 50.106
# Reward after 00645 episodes: 57.549
# Reward after 00646 episodes: 78.543
# Reward after 00647 episodes: 160.528
# Reward after 00648 episodes: 116.133
# Reward after 00649 episodes: 114.121
# Reward after 00650 episodes: 178.661
# Reward after 00651 episodes: 161.452
# Reward after 00652 episodes: 196.571
# Reward after 00653 episodes: 153.320
# Reward after 00654 episodes: 208.930
# Reward after 00655 episodes: 139.772
# Reward after 00656 episodes: 64.223
# Reward after 00657 episodes: 65.598
# Reward after 00658 episodes: 83.631
# Reward after 00659 episodes: 142.101
# Reward after 00660 episodes: 630.628
# Reward after 00661 episodes: 665.936
# Reward after 00662 episodes: 120.334
# Reward after 00663 episodes: 53.743
# Reward after 00664 episodes: 102.410
# Reward after 00665 episodes: 53.818
# Reward after 00666 episodes: 86.372
# Reward after 00667 episodes: 74.415
# Reward after 00668 episodes: 122.512
# Reward after 00669 episodes: 118.793
# Reward after 00670 episodes: 139.891
# Reward after 00671 episodes: 259.316
# Reward after 00672 episodes: 155.049
# Reward after 00673 episodes: 200.488
# Reward after 00674 episodes: 175.780
# Reward after 00675 episodes: 116.247
# Reward after 00676 episodes: 204.188
# Reward after 00677 episodes: 162.316
# Reward after 00678 episodes: 154.587
# Reward after 00679 episodes: -0.713
# Reward after 00680 episodes: -1.000
# Reward after 00681 episodes: 187.777
# Reward after 00682 episodes: 261.983
# Reward after 00683 episodes: 233.156
# Reward after 00684 episodes: -1.000
# Reward after 00685 episodes: 115.827
# Reward after 00686 episodes: 191.252
# Reward after 00687 episodes: 243.047
# Reward after 00688 episodes: -1.000
# Reward after 00689 episodes: -1.000
# Reward after 00690 episodes: -1.000
# Reward after 00691 episodes: -1.000
# Reward after 00692 episodes: -1.000
# Reward after 00693 episodes: -1.000
# Reward after 00694 episodes: -0.737
# Reward after 00695 episodes: -1.000
# Reward after 00696 episodes: 286.144
# Reward after 00697 episodes: 435.398
# Reward after 00698 episodes: 449.152
# Reward after 00699 episodes: 413.030
# Reward after 00700 episodes: 235.728
# Reward after 00701 episodes: 380.090
# Reward after 00702 episodes: 369.854
# Reward after 00703 episodes: 695.637
# Reward after 00704 episodes: 266.842
# Reward after 00705 episodes: 249.763
# Reward after 00706 episodes: 206.595
# Reward after 00707 episodes: -1.000
# Reward after 00708 episodes: 58.649
# Reward after 00709 episodes: 139.236
# Reward after 00710 episodes: 82.283
# Reward after 00711 episodes: 150.495
# Reward after 00712 episodes: 117.039
# Reward after 00713 episodes: 101.414
# Reward after 00714 episodes: 232.195
# Reward after 00715 episodes: 260.747
# Reward after 00716 episodes: 238.244
# Reward after 00717 episodes: 189.152
# Reward after 00718 episodes: 244.905
# Reward after 00719 episodes: 226.192
# Reward after 00720 episodes: 696.667
# Reward after 00721 episodes: 179.393
# Reward after 00722 episodes: 698.563
# Reward after 00723 episodes: 106.904
# Reward after 00724 episodes: 184.228
# Reward after 00725 episodes: 693.129
# Reward after 00726 episodes: 700.152
# Reward after 00727 episodes: 159.209
# Reward after 00728 episodes: 118.088
# Reward after 00729 episodes: 149.742
# Reward after 00730 episodes: 133.120
# Reward after 00731 episodes: 69.429
# Reward after 00732 episodes: 99.210
# Reward after 00733 episodes: 118.951
# Reward after 00734 episodes: 118.701
# Reward after 00735 episodes: 134.718
# Reward after 00736 episodes: 122.477
# Reward after 00737 episodes: 184.615
# Reward after 00738 episodes: 108.125
# Reward after 00739 episodes: 132.325
# Reward after 00740 episodes: 98.562
# Reward after 00741 episodes: 664.569
# Reward after 00742 episodes: 94.380
# Reward after 00743 episodes: 165.840
# Reward after 00744 episodes: 314.136
# Reward after 00745 episodes: 241.985
# Reward after 00746 episodes: 301.373
# Reward after 00747 episodes: 261.837
# Reward after 00748 episodes: 229.926
# Reward after 00749 episodes: 21.020
# Reward after 00750 episodes: 24.426
# Reward after 00751 episodes: -1.000
# Reward after 00752 episodes: -1.000
# Reward after 00753 episodes: -1.000
# Reward after 00754 episodes: 152.251
# Reward after 00755 episodes: 95.337
# Reward after 00756 episodes: 140.091
# Reward after 00757 episodes: 121.180
# Reward after 00758 episodes: 148.633
# Reward after 00759 episodes: 168.892
# Reward after 00760 episodes: 149.124
# Reward after 00761 episodes: 128.857
# Reward after 00762 episodes: 114.025
# Reward after 00763 episodes: 132.044
# Reward after 00764 episodes: 113.459
# Reward after 00765 episodes: 146.138
# Reward after 00766 episodes: 151.975
# Reward after 00767 episodes: 123.694
# Reward after 00768 episodes: 137.224
# Reward after 00769 episodes: 1.547
# Reward after 00770 episodes: -0.995
# Reward after 00771 episodes: 137.348
# Reward after 00772 episodes: 130.763
# Reward after 00773 episodes: 95.791
# Reward after 00774 episodes: 138.366
# Reward after 00775 episodes: 153.630
# Reward after 00776 episodes: 180.645
# Reward after 00777 episodes: 221.695
# Reward after 00778 episodes: 181.590
# Reward after 00779 episodes: 143.299
# Reward after 00780 episodes: 143.046
# Reward after 00781 episodes: 104.567
# Reward after 00782 episodes: 120.028
# Reward after 00783 episodes: 130.352
# Reward after 00784 episodes: 130.263
# Reward after 00785 episodes: 118.435
# Reward after 00786 episodes: 196.490
# Reward after 00787 episodes: 198.266
# Reward after 00788 episodes: 171.945
# Reward after 00789 episodes: 180.608
# Reward after 00790 episodes: 48.343
# Reward after 00791 episodes: 34.299
# Reward after 00792 episodes: 176.808
# Reward after 00793 episodes: 212.567
# Reward after 00794 episodes: 150.343
# Reward after 00795 episodes: 140.435
# Reward after 00796 episodes: 123.011
# Reward after 00797 episodes: 152.813
# Reward after 00798 episodes: 210.474
# Reward after 00799 episodes: 169.073
# Reward after 00800 episodes: 161.602
# Reward after 00801 episodes: 185.532
# Reward after 00802 episodes: 226.064
# Reward after 00803 episodes: 210.385
# Reward after 00804 episodes: 228.257
# Reward after 00805 episodes: 652.491
# Reward after 00806 episodes: 640.817
# Reward after 00807 episodes: 639.418
# Reward after 00808 episodes: 646.019
# Reward after 00809 episodes: 178.885
# Reward after 00810 episodes: 650.125
# Reward after 00811 episodes: 184.452
# Reward after 00812 episodes: 117.030
# Reward after 00813 episodes: 152.754
# Reward after 00814 episodes: 261.324
# Reward after 00815 episodes: 177.458
# Reward after 00816 episodes: 186.816
# Reward after 00817 episodes: 242.262
# Reward after 00818 episodes: 132.849
# Reward after 00819 episodes: 167.789
# Reward after 00820 episodes: 205.349
# Reward after 00821 episodes: -1.000
# Reward after 00822 episodes: -1.000
# Reward after 00823 episodes: 153.467
# Reward after 00824 episodes: 71.418
# Reward after 00825 episodes: 168.317
# Reward after 00826 episodes: 184.758
# Reward after 00827 episodes: 159.962
# Reward after 00828 episodes: 193.385
# Reward after 00829 episodes: 136.833
# Reward after 00830 episodes: 160.935
# Reward after 00831 episodes: 137.036
# Reward after 00832 episodes: 118.137
# Reward after 00833 episodes: 189.790
# Reward after 00834 episodes: 272.501
# Reward after 00835 episodes: 673.975
# Reward after 00836 episodes: -1.000
# Reward after 00837 episodes: 671.109
# Reward after 00838 episodes: 688.182
# Reward after 00839 episodes: 282.944
# Reward after 00840 episodes: -1.000
# Reward after 00841 episodes: -1.000
# Reward after 00842 episodes: 143.619
# Reward after 00843 episodes: 172.944
# Reward after 00844 episodes: 166.512
# Reward after 00845 episodes: 202.838
# Reward after 00846 episodes: 165.973
# Reward after 00847 episodes: 169.080
# Reward after 00848 episodes: 85.989
# Reward after 00849 episodes: 130.426
# Reward after 00850 episodes: 130.003
# Reward after 00851 episodes: -1.000
# Reward after 00852 episodes: 8.091
# Reward after 00853 episodes: -1.000
# Reward after 00854 episodes: 118.234
# Reward after 00855 episodes: 655.922
# Reward after 00856 episodes: 329.596
# Reward after 00857 episodes: 281.624
# Reward after 00858 episodes: 267.632
# Reward after 00859 episodes: 295.969
# Reward after 00860 episodes: 329.151
# Reward after 00861 episodes: 241.989
# Reward after 00862 episodes: 224.807
# Reward after 00863 episodes: 304.594
# Reward after 00864 episodes: 257.594
# Reward after 00865 episodes: 293.023
# Reward after 00866 episodes: 212.160
# Reward after 00867 episodes: 218.303
# Reward after 00868 episodes: 246.048
# Reward after 00869 episodes: 242.302
# Reward after 00870 episodes: 247.200
# Reward after 00871 episodes: 220.411
# Reward after 00872 episodes: 146.764
# Reward after 00873 episodes: -1.000
# Reward after 00874 episodes: 187.671
# Reward after 00875 episodes: 151.813
# Reward after 00876 episodes: 165.626
# Reward after 00877 episodes: 219.432
# Reward after 00878 episodes: 139.052
# Reward after 00879 episodes: 214.017
# Reward after 00880 episodes: 183.155
# Reward after 00881 episodes: 136.385
# Reward after 00882 episodes: 173.886
# Reward after 00883 episodes: 117.580
# Reward after 00884 episodes: 129.959
# Reward after 00885 episodes: 138.311
# Reward after 00886 episodes: 129.705
# Reward after 00887 episodes: 97.057
# Reward after 00888 episodes: 157.939
# Reward after 00889 episodes: 136.756
# Reward after 00890 episodes: 207.633
# Reward after 00891 episodes: 651.664
# Reward after 00892 episodes: 163.428
# Reward after 00893 episodes: 149.690
# Reward after 00894 episodes: 153.802
# Reward after 00895 episodes: 200.417
# Reward after 00896 episodes: 673.881
# Reward after 00897 episodes: 654.542
# Reward after 00898 episodes: 275.348
# Reward after 00899 episodes: 673.787
# Reward after 00900 episodes: 248.858
# Reward after 00905 episodes: 321.578
# Reward after 00906 episodes: 265.495
# Reward after 00907 episodes: 289.302
# Reward after 00908 episodes: 222.178
# Reward after 00909 episodes: 259.040
# Reward after 00910 episodes: 210.224
# Reward after 00911 episodes: 210.267
# Reward after 00912 episodes: 65.415
# Reward after 00913 episodes: 56.541
# Reward after 00914 episodes: 410.652
# Reward after 00915 episodes: 141.284
# Reward after 00916 episodes: 61.497
# Reward after 00917 episodes: 127.755
# Reward after 00918 episodes: 123.962
# Reward after 00919 episodes: 54.117
# Reward after 00920 episodes: 681.065
# Reward after 00921 episodes: 75.839
# Reward after 00922 episodes: 126.945
# Reward after 00923 episodes: 39.254
# Reward after 00924 episodes: 66.939
# Reward after 00925 episodes: 137.608
# Reward after 00926 episodes: 128.443
# Reward after 00927 episodes: 71.849
# Reward after 00928 episodes: 143.030
# Reward after 00929 episodes: 94.578
# Reward after 00930 episodes: 56.077
# Reward after 00931 episodes: 46.383
# Reward after 00932 episodes: 137.204
# Reward after 00933 episodes: -1.000
# Reward after 00934 episodes: 28.723
# Reward after 00935 episodes: -1.000
# Reward after 00936 episodes: 93.677
# Reward after 00937 episodes: 14.535
# Reward after 00938 episodes: -1.000
# Reward after 00939 episodes: 124.233
# Reward after 00940 episodes: 15.412
# Reward after 00941 episodes: -1.000
# Reward after 00942 episodes: -1.000
# Reward after 00943 episodes: -1.000
# Reward after 00944 episodes: -0.798
# Reward after 00945 episodes: 4.086
# Reward after 00946 episodes: -1.000
# Reward after 00947 episodes: 16.840
# Reward after 00948 episodes: -1.000
# Reward after 00949 episodes: 9.344
# Reward after 00950 episodes: -1.000
# Reward after 00951 episodes: 223.072
# Reward after 00952 episodes: 24.000
# Reward after 00953 episodes: 124.931
# Reward after 00954 episodes: 34.274
# Reward after 00955 episodes: 176.987
# Reward after 00956 episodes: 211.729
# Reward after 00957 episodes: 191.602
# Reward after 00958 episodes: 220.111
# Reward after 00959 episodes: 23.576
# Reward after 00960 episodes: 246.332
# Reward after 00961 episodes: 156.956
# Reward after 00962 episodes: -1.000
# Reward after 00963 episodes: -1.000
# Reward after 00964 episodes: -1.000
# Reward after 00965 episodes: 43.075
# Reward after 00966 episodes: -1.000
# Reward after 00967 episodes: -1.000
# Reward after 00968 episodes: -0.999
# Reward after 00969 episodes: -1.000
# Reward after 00970 episodes: 27.106
# Reward after 00971 episodes: -1.000
# Reward after 00972 episodes: 13.613
# Reward after 00973 episodes: -1.000
# Reward after 00974 episodes: -1.000
# Reward after 00975 episodes: -1.000
# Reward after 00976 episodes: -1.000
# Reward after 00977 episodes: 361.950
# Reward after 00978 episodes: 528.127
# Reward after 00979 episodes: 539.990
# Reward after 00980 episodes: 548.170
# Reward after 00981 episodes: 636.675
# Reward after 00982 episodes: 632.908
# Reward after 00983 episodes: 581.176
# Reward after 00984 episodes: 633.650
# Reward after 00985 episodes: 639.920
# Reward after 00986 episodes: 627.504
# Reward after 00987 episodes: 621.795
# Reward after 00988 episodes: 542.010
# Reward after 00989 episodes: 556.457
# Reward after 00990 episodes: 631.078
# Reward after 00991 episodes: 606.307
# Reward after 00992 episodes: 311.815
# Reward after 00993 episodes: 604.743
# Reward after 00994 episodes: 633.474
# Reward after 00995 episodes: 634.051
# Reward after 00996 episodes: 631.608
# Reward after 00997 episodes: 548.066
# Reward after 00998 episodes: 661.867
# Reward after 00999 episodes: 586.843
# Reward after 01000 episodes: 637.175
# Reward after 01001 episodes: 359.839
# Reward after 01002 episodes: 654.634
# Reward after 01003 episodes: 632.797
# Reward after 01004 episodes: 261.486
# Reward after 01005 episodes: 216.752
# Reward after 01006 episodes: 251.569
# Reward after 01007 episodes: -1.000
# Reward after 01008 episodes: 267.040
# Reward after 01009 episodes: 317.118
# Reward after 01010 episodes: 363.568
# Reward after 01011 episodes: 332.341
# Reward after 01012 episodes: 605.719
# Reward after 01013 episodes: 386.669
# Reward after 01014 episodes: 575.118
# Reward after 01015 episodes: 357.521
# Reward after 01016 episodes: 656.514
# Reward after 01017 episodes: 339.710
# Reward after 01018 episodes: 641.055
# Reward after 01019 episodes: 330.026
# Reward after 01020 episodes: 328.502
# Reward after 01021 episodes: 667.088
# Reward after 01022 episodes: 301.151
# Reward after 01023 episodes: 287.125
# Reward after 01024 episodes: 273.387
# Reward after 01025 episodes: 256.225
# Reward after 01026 episodes: 269.439
# Reward after 01027 episodes: 238.979
# Reward after 01028 episodes: 244.881
# Reward after 01029 episodes: 223.184
# Reward after 01030 episodes: 235.228
# Reward after 01031 episodes: 261.709
# Reward after 01032 episodes: 237.258
# Reward after 01033 episodes: 238.927
# Reward after 01034 episodes: 268.562
# Reward after 01035 episodes: 261.202
# Reward after 01036 episodes: 268.510
# Reward after 01037 episodes: 301.268
# Reward after 01038 episodes: 261.801
# Reward after 01039 episodes: 236.865
# Reward after 01040 episodes: 240.175
# Reward after 01041 episodes: 187.160
# Reward after 01042 episodes: 82.878
# Reward after 01043 episodes: 243.773
# Reward after 01044 episodes: 229.668
# Reward after 01045 episodes: 204.007
# Reward after 01046 episodes: 210.421
# Reward after 01047 episodes: 55.286
# Reward after 01048 episodes: 79.634
# Reward after 01049 episodes: 84.969
# Reward after 01050 episodes: 177.209
# Reward after 01051 episodes: 190.162
# Reward after 01052 episodes: 216.090
# Reward after 01053 episodes: 79.897
# Reward after 01054 episodes: 93.130
# Reward after 01055 episodes: 161.501
# Reward after 01056 episodes: 177.076
# Reward after 01057 episodes: 72.351
# Reward after 01058 episodes: 132.811
# Reward after 01059 episodes: 153.549
# Reward after 01060 episodes: 153.802
# Reward after 01061 episodes: 218.896
# Reward after 01062 episodes: 212.450
# Reward after 01063 episodes: 208.361
# Reward after 01064 episodes: 227.521
# Reward after 01065 episodes: 131.085
# Reward after 01066 episodes: 91.268
# Reward after 01067 episodes: 113.933
# Reward after 01068 episodes: 114.595
# Reward after 01069 episodes: 115.868
# Reward after 01070 episodes: 105.221
# Reward after 01071 episodes: 105.726
# Reward after 01072 episodes: 110.127
# Reward after 01073 episodes: 161.866
# Reward after 01074 episodes: 95.024
# Reward after 01075 episodes: 132.700
# Reward after 01076 episodes: 300.618
# Reward after 01077 episodes: 128.494
# Reward after 01078 episodes: 174.274
# Reward after 01079 episodes: 155.380
# Reward after 01080 episodes: 121.519
# Reward after 01081 episodes: 91.808
# Reward after 01082 episodes: 117.564
# Reward after 01083 episodes: 112.765
# Reward after 01084 episodes: 160.205
# Reward after 01085 episodes: 149.089
# Reward after 01086 episodes: 127.191
# Reward after 01087 episodes: 132.192
# Reward after 01088 episodes: 122.698
# Reward after 01089 episodes: 201.048
# Reward after 01090 episodes: 187.399
# Reward after 01091 episodes: 154.852
# Reward after 01092 episodes: 614.815
# Reward after 01093 episodes: 157.626
# Reward after 01094 episodes: 617.705
# Reward after 01095 episodes: -1.000
# Reward after 01096 episodes: -1.000
# Reward after 01097 episodes: -1.000
# Reward after 01098 episodes: 702.158
# Reward after 01099 episodes: 502.984
# Reward after 01100 episodes: 302.428
# Reward after 01101 episodes: -1.000
# Reward after 01102 episodes: 269.309
# Reward after 01103 episodes: 558.328
# Reward after 01104 episodes: 297.235
# Reward after 01105 episodes: 686.935
# Reward after 01106 episodes: 430.863
# Reward after 01107 episodes: 425.929
# Reward after 01108 episodes: 207.332
# Reward after 01109 episodes: 728.763
# Reward after 01110 episodes: 219.168
# Reward after 01111 episodes: 172.854
# Reward after 01112 episodes: 622.323
# Reward after 01113 episodes: 632.147
# Reward after 01114 episodes: 129.313
# Reward after 01115 episodes: 625.149
# Reward after 01116 episodes: -1.000
# Reward after 01117 episodes: -1.000
# Reward after 01118 episodes: -1.000
# Reward after 01119 episodes: -1.000
# Reward after 01120 episodes: 370.032
# Reward after 01121 episodes: -1.000
# Reward after 01122 episodes: 509.227
# Reward after 01123 episodes: 224.308
# Reward after 01124 episodes: -1.000
# Reward after 01125 episodes: -1.000
# Reward after 01126 episodes: -1.000
# Reward after 01127 episodes: -1.000
# Reward after 01128 episodes: 143.101
# Reward after 01129 episodes: 545.771
# Reward after 01130 episodes: 652.271
# Reward after 01131 episodes: 154.323
# Reward after 01132 episodes: 631.231
# Reward after 01133 episodes: 150.002
# Reward after 01134 episodes: 205.340
# Reward after 01135 episodes: 137.708
# Reward after 01136 episodes: 172.375
# Reward after 01137 episodes: 122.443
# Reward after 01138 episodes: 655.480
# Reward after 01139 episodes: 175.769
# Reward after 01140 episodes: 109.050
# Reward after 01141 episodes: 457.941
# Reward after 01142 episodes: 640.612
# Reward after 01143 episodes: 167.792
# Reward after 01144 episodes: 240.982
# Reward after 01145 episodes: 266.246
# Reward after 01146 episodes: 198.815
# Reward after 01147 episodes: 214.186
# Reward after 01148 episodes: 333.712
# Reward after 01149 episodes: 113.775
# Reward after 01150 episodes: 143.548
# Reward after 01151 episodes: 226.841
# Reward after 01152 episodes: 215.962
# Reward after 01153 episodes: 148.356
# Reward after 01154 episodes: 691.073
# Reward after 01155 episodes: 689.573
# Reward after 01156 episodes: 190.064
# Reward after 01157 episodes: 210.950
# Reward after 01158 episodes: 675.007
# Reward after 01159 episodes: 205.033
# Reward after 01160 episodes: 184.480
# Reward after 01161 episodes: 83.390
# Reward after 01162 episodes: 171.514
# Reward after 01163 episodes: 162.305
# Reward after 01164 episodes: 104.253
# Reward after 01165 episodes: 173.060
# Reward after 01166 episodes: 139.889
# Reward after 01167 episodes: 146.310
# Reward after 01168 episodes: 163.216
# Reward after 01169 episodes: 103.484
# Reward after 01170 episodes: 102.883
# Reward after 01171 episodes: 110.206
# Reward after 01172 episodes: 111.601
# Reward after 01173 episodes: 146.389
# Reward after 01174 episodes: 131.689
# Reward after 01175 episodes: 113.132
# Reward after 01176 episodes: 133.812
# Reward after 01177 episodes: 105.020
# Reward after 01178 episodes: 176.994
# Reward after 01179 episodes: 153.481
# Reward after 01180 episodes: 77.142
# Reward after 01181 episodes: 45.599
# Reward after 01182 episodes: 79.873
# Reward after 01183 episodes: 563.300
# Reward after 01184 episodes: 185.118
# Reward after 01185 episodes: 705.826
# Reward after 01186 episodes: 669.020
# Reward after 01187 episodes: -1.000
# Reward after 01188 episodes: 39.540
# Reward after 01189 episodes: 30.128
# Reward after 01190 episodes: 31.772
# Reward after 01191 episodes: 660.165
# Reward after 01192 episodes: 68.034
# Reward after 01193 episodes: 76.023
# Reward after 01194 episodes: 690.823
# Reward after 01195 episodes: -1.000
# Reward after 01196 episodes: 91.142
# Reward after 01197 episodes: 114.683
# Reward after 01198 episodes: -1.000
# Reward after 01199 episodes: -1.000
# Reward after 01200 episodes: -1.000
# Reward after 01201 episodes: -1.000
# Reward after 01202 episodes: -1.000
# Reward after 01203 episodes: -1.000
# Reward after 01204 episodes: -1.000
# Reward after 01205 episodes: -1.000
# Reward after 01206 episodes: -1.000
# Reward after 01207 episodes: -1.000
# Reward after 01208 episodes: -1.000
# Reward after 01209 episodes: -1.000
# Reward after 01210 episodes: -1.000
# Reward after 01211 episodes: 77.627
# Reward after 01212 episodes: 82.494
# Reward after 01213 episodes: 97.967
# Reward after 01214 episodes: 93.856
# Reward after 01215 episodes: 67.432
# Reward after 01216 episodes: 83.792
# Reward after 01217 episodes: 121.566
# Reward after 01218 episodes: 88.947
# Reward after 01219 episodes: 104.493
# Reward after 01220 episodes: 69.325
# Reward after 01221 episodes: -1.000
# Reward after 01222 episodes: 112.623
# Reward after 01223 episodes: 130.717
# Reward after 01224 episodes: 105.055
# Reward after 01225 episodes: 95.341
# Reward after 01226 episodes: -1.000
# Reward after 01227 episodes: -1.000
# Reward after 01228 episodes: -1.000
# Reward after 01229 episodes: -1.000
# Reward after 01230 episodes: -1.000
# Reward after 01231 episodes: 111.468
# Reward after 01232 episodes: 153.306
# Reward after 01233 episodes: 112.938
# Reward after 01234 episodes: 128.692
# Reward after 01235 episodes: 126.686
# Reward after 01236 episodes: 84.670
# Reward after 01237 episodes: 121.211
# Reward after 01238 episodes: 105.163
# Reward after 01239 episodes: 120.266
# Reward after 01240 episodes: 46.694
# Reward after 01241 episodes: 83.444
# Reward after 01242 episodes: 82.215
# Reward after 01243 episodes: 81.752
# Reward after 01244 episodes: 70.808
# Reward after 01245 episodes: 50.897
# Reward after 01246 episodes: 32.702
# Reward after 01247 episodes: 14.773
# Reward after 01248 episodes: 38.211
# Reward after 01249 episodes: 15.266
# Reward after 01250 episodes: 59.178
# Reward after 01251 episodes: 60.729
# Reward after 01252 episodes: 40.974
# Reward after 01253 episodes: 53.108
# Reward after 01254 episodes: 45.550
# Reward after 01255 episodes: 47.363
# Reward after 01256 episodes: 26.778
# Reward after 01257 episodes: 13.353
# Reward after 01258 episodes: 18.062
# Reward after 01259 episodes: 31.713
# Reward after 01260 episodes: 43.898
# Reward after 01261 episodes: 41.652
# Reward after 01262 episodes: 48.278
# Reward after 01263 episodes: 30.209
# Reward after 01264 episodes: 59.514
# Reward after 01265 episodes: 61.420
# Reward after 01266 episodes: 41.534
# Reward after 01267 episodes: -1.000
# Reward after 01268 episodes: -1.000
# Reward after 01269 episodes: -1.000
# ...
# Reward after 02636 episodes: 366.718
# Reward after 02637 episodes: 57.601
# Reward after 02638 episodes: 649.915
# Reward after 02639 episodes: 56.832
# Reward after 02640 episodes: 216.078
# Reward after 02641 episodes: 3.020
# Reward after 02642 episodes: 612.207
# Reward after 02643 episodes: 647.145
# Reward after 02644 episodes: -1.000
# Reward after 02645 episodes: 0.642
# Reward after 02646 episodes: 14.042
# Reward after 02647 episodes: 230.599
# Reward after 02648 episodes: 649.133
# Reward after 02649 episodes: 730.103
# Reward after 02650 episodes: 210.233
# Reward after 02651 episodes: 706.051
# Reward after 02652 episodes: 700.754
# Reward after 02653 episodes: 365.523
# Reward after 02654 episodes: 36.500
# Reward after 02655 episodes: 369.589
# Reward after 02656 episodes: 708.783
# Reward after 02657 episodes: 703.299
# Reward after 02658 episodes: 730.584
# Reward after 02659 episodes: 33.161
# Reward after 02660 episodes: 368.885
# Reward after 02661 episodes: 705.827
# Reward after 02662 episodes: 704.407
# Reward after 02663 episodes: 699.570
# Reward after 02664 episodes: 712.502
# Reward after 02665 episodes: 708.729
# Reward after 02666 episodes: 713.798
# Reward after 02667 episodes: 704.981
# Reward after 02668 episodes: 716.158
# Reward after 02669 episodes: 14.265
# Reward after 02670 episodes: 12.613
# Reward after 02671 episodes: 7.965
# Reward after 02672 episodes: 8.320
# Reward after 02673 episodes: 0.000
# Reward after 02674 episodes: 714.298
# Reward after 02675 episodes: 734.579
# Reward after 02676 episodes: 733.750
# Reward after 02677 episodes: 705.380
# Reward after 02678 episodes: 696.037
# Reward after 02679 episodes: 718.191
# Reward after 02680 episodes: 713.463
# Reward after 02681 episodes: 691.201
# Reward after 02682 episodes: 732.960
# Reward after 02683 episodes: 733.111
# Reward after 02684 episodes: 731.346
# Reward after 02685 episodes: 731.556
# Reward after 02686 episodes: 731.635
# Reward after 02687 episodes: 729.753
# Reward after 02688 episodes: 730.950
# Reward after 02689 episodes: 735.009
# Reward after 02690 episodes: 729.878
# Reward after 02691 episodes: 733.397
# Reward after 02692 episodes: 732.508
# Reward after 02693 episodes: 733.183
# Reward after 02694 episodes: 732.836
# Reward after 02695 episodes: 696.245
# Reward after 02696 episodes: 733.255
# Reward after 02697 episodes: 730.244
# Reward after 02698 episodes: 733.572
# Reward after 02699 episodes: 733.610
# Reward after 02700 episodes: 733.028
# Reward after 02701 episodes: 732.331
# Reward after 02702 episodes: 731.367
# Reward after 02703 episodes: 731.868
# Reward after 02704 episodes: 732.213
# Reward after 02705 episodes: 730.277
# Reward after 02706 episodes: 730.963
# Reward after 02707 episodes: 731.950
# Reward after 02708 episodes: 731.760
# Reward after 02709 episodes: 730.311
# Reward after 02710 episodes: 727.591
# Reward after 02711 episodes: 724.866
# Reward after 02712 episodes: 731.056
# Reward after 02713 episodes: 726.968
# Reward after 02714 episodes: 729.040
# Reward after 02715 episodes: 730.064
# Reward after 02716 episodes: 729.882
# Reward after 02717 episodes: 728.688
# Reward after 02718 episodes: 730.370
# Reward after 02719 episodes: 729.874
# Reward after 02720 episodes: 731.211
# Reward after 02721 episodes: 732.765
# Reward after 02722 episodes: 201.362
# Reward after 02723 episodes: 727.269
# Reward after 02724 episodes: 203.550
# Reward after 02725 episodes: 726.624
# Reward after 02726 episodes: 391.423
# Reward after 02727 episodes: 392.775
# Reward after 02728 episodes: 729.322
# Reward after 02729 episodes: 727.476
# Reward after 02730 episodes: 151.469
# Reward after 02731 episodes: 727.577
# Reward after 02732 episodes: -1.000
# Reward after 02733 episodes: 726.654
# Reward after 02734 episodes: 681.138
# Reward after 02735 episodes: 724.510
# Reward after 02736 episodes: 726.060
# Reward after 02737 episodes: 728.941
# Reward after 02738 episodes: 727.237
# Reward after 02739 episodes: 726.051
# Reward after 02740 episodes: 709.354
# Reward after 02741 episodes: 719.189
# Reward after 02742 episodes: 729.095
# Reward after 02743 episodes: 729.793
# Reward after 02744 episodes: 729.902
# Reward after 02745 episodes: 726.005
# Reward after 02746 episodes: 702.164
# Reward after 02747 episodes: 727.160
# Reward after 02748 episodes: 30.345
# Reward after 02749 episodes: 729.293
# Reward after 02750 episodes: 127.204
# Reward after 02751 episodes: 725.799
# Reward after 02752 episodes: 85.840
# Reward after 02753 episodes: 87.357
# Reward after 02754 episodes: -0.238
# Reward after 02755 episodes: 712.326
# Reward after 02756 episodes: 716.301
# Reward after 02757 episodes: 664.550
# Reward after 02758 episodes: 372.671
# Reward after 02759 episodes: 170.239
# Reward after 02760 episodes: 146.881
# Reward after 02761 episodes: 98.955
# Reward after 02762 episodes: 724.047
# Reward after 02763 episodes: 702.087
# Reward after 02764 episodes: 704.184
# Reward after 02765 episodes: 98.971
# Reward after 02766 episodes: 59.614
# Reward after 02767 episodes: 121.505
# Reward after 02768 episodes: 77.763
# Reward after 02769 episodes: 101.855
# Reward after 02770 episodes: 78.541
# Reward after 02771 episodes: 48.859
# Reward after 02772 episodes: 677.076
# Reward after 02773 episodes: 719.319
# Reward after 02774 episodes: 713.513
# Reward after 02775 episodes: 655.568
# Reward after 02776 episodes: 99.343
# Reward after 02777 episodes: 708.922
# Reward after 02778 episodes: 164.392
# Reward after 02779 episodes: 129.671
# Reward after 02780 episodes: 711.933
# Reward after 02781 episodes: 724.092
# Reward after 02782 episodes: 630.658
# Reward after 02783 episodes: 701.377
# Reward after 02784 episodes: 667.474
# Reward after 02785 episodes: 725.263
# Reward after 02786 episodes: 707.446
# Reward after 02787 episodes: 650.304
# Reward after 02788 episodes: 729.146
# Reward after 02789 episodes: 703.079
# Reward after 02790 episodes: 694.552
# Reward after 02791 episodes: 699.977
# Reward after 02792 episodes: 673.765
# Reward after 02793 episodes: 266.668
# Reward after 02794 episodes: 717.152
# Reward after 02795 episodes: 696.252
# Reward after 02796 episodes: 728.068
# Reward after 02797 episodes: 677.228
# Reward after 02798 episodes: 699.797
# Reward after 02799 episodes: 729.141
# Reward after 02800 episodes: 702.194
# Reward after 02801 episodes: 694.352
# Reward after 02802 episodes: 678.107
# Reward after 02803 episodes: 658.547
# Reward after 02804 episodes: 713.386
# Reward after 02805 episodes: 727.132
# Reward after 02806 episodes: 729.865
# Reward after 02807 episodes: 727.151
# Reward after 02808 episodes: 729.786
# Reward after 02809 episodes: 687.575
# Reward after 02810 episodes: 691.535
# Reward after 02811 episodes: 717.422
# Reward after 02812 episodes: 723.822
# Reward after 02813 episodes: 690.366
# Reward after 02814 episodes: 330.036
# Reward after 02815 episodes: 726.331
# Reward after 02816 episodes: 728.050
# Reward after 02817 episodes: 727.246
# Reward after 02818 episodes: 727.049
# Reward after 02819 episodes: 726.341
# Reward after 02820 episodes: 701.600
# Reward after 02821 episodes: 726.591
# Reward after 02822 episodes: 235.796
# Reward after 02823 episodes: 168.685
# Reward after 02824 episodes: 130.320
# Reward after 02825 episodes: 151.177
# Reward after 02826 episodes: 728.361
# Reward after 02827 episodes: 726.186
# Reward after 02828 episodes: 729.549
# Reward after 02829 episodes: 727.512
# Reward after 02830 episodes: 728.377
# Reward after 02831 episodes: 699.487
# Reward after 02832 episodes: 49.666
# Reward after 02833 episodes: 72.234
# Reward after 02834 episodes: 704.913
# Reward after 02835 episodes: 97.014
# Reward after 02836 episodes: 92.645
# Reward after 02837 episodes: 726.696
# Reward after 02838 episodes: 726.948
# Reward after 02839 episodes: 125.565
# Reward after 02840 episodes: 729.985
# Reward after 02841 episodes: 93.874
# Reward after 02842 episodes: 129.108
# Reward after 02843 episodes: 84.541
# Reward after 02844 episodes: 726.737
# Reward after 02845 episodes: 727.421
# Reward after 02846 episodes: 689.047
# Reward after 02847 episodes: 727.399
# Reward after 02848 episodes: 727.407
# Reward after 02849 episodes: 43.172
# Reward after 02850 episodes: 728.699
# Reward after 02851 episodes: 109.295
# Reward after 02852 episodes: 77.720
# Reward after 02853 episodes: 53.985
# Reward after 02854 episodes: 127.480
# Reward after 02855 episodes: 60.406
# Reward after 02856 episodes: 56.529
# Reward after 02857 episodes: 37.650
# Reward after 02858 episodes: 55.710
# Reward after 02859 episodes: 63.068
# Reward after 02860 episodes: 70.192
# Reward after 02861 episodes: 24.144
# Reward after 02862 episodes: 40.453
# Reward after 02863 episodes: 36.488
# Reward after 02864 episodes: 53.518
# Reward after 02865 episodes: 29.413
# Reward after 02866 episodes: 38.215
# Reward after 02867 episodes: 33.513
# Reward after 02868 episodes: 87.647
# Reward after 02869 episodes: 32.099
# Reward after 02870 episodes: 85.505
# Reward after 02871 episodes: 94.404
# Reward after 02872 episodes: 87.236
# Reward after 02873 episodes: 150.027
# Reward after 02874 episodes: 694.095
# Reward after 02875 episodes: 35.509
# Reward after 02876 episodes: 60.885
# Reward after 02877 episodes: 110.164
# Reward after 02878 episodes: 165.730
# Reward after 02879 episodes: 110.050
# Reward after 02880 episodes: 144.192
# Reward after 02881 episodes: 187.776
# Reward after 02882 episodes: 172.065
# Reward after 02883 episodes: 150.829
# Reward after 02884 episodes: 722.843
# Reward after 02885 episodes: 122.011
# Reward after 02886 episodes: 196.735
# Reward after 02887 episodes: 193.427
# Reward after 02888 episodes: -1.000
# Reward after 02889 episodes: 728.709
# Reward after 02890 episodes: 699.010
# Reward after 02891 episodes: 74.693
# Reward after 02892 episodes: 727.741
# Reward after 02893 episodes: 727.466
# Reward after 02894 episodes: 730.249
# Reward after 02895 episodes: 133.285
# Reward after 02896 episodes: 135.340
# Reward after 02897 episodes: 690.484
# Reward after 02898 episodes: 705.092
# Reward after 02899 episodes: 651.677
# Reward after 02900 episodes: 671.259
# Reward after 02901 episodes: 672.390
# Reward after 02902 episodes: 698.782
# Reward after 02903 episodes: 133.520
# Reward after 02904 episodes: 122.766
# Reward after 02905 episodes: 687.826
# Reward after 02906 episodes: 63.783
# Reward after 02907 episodes: 63.231
# Reward after 02908 episodes: 730.159
# Reward after 02909 episodes: 28.615
# Reward after 02910 episodes: 74.793
# Reward after 02911 episodes: 62.460
# Reward after 02912 episodes: 18.570
# Reward after 02913 episodes: 93.821
# Reward after 02914 episodes: 82.136
# Reward after 02915 episodes: 85.433
# Reward after 02916 episodes: 53.505
# Reward after 02917 episodes: 85.726
# Reward after 02918 episodes: 86.091
# Reward after 02919 episodes: 58.612
# Reward after 02920 episodes: 79.814
# Reward after 02921 episodes: 79.493
# Reward after 02922 episodes: 65.605
# Reward after 02923 episodes: 51.033
# Reward after 02924 episodes: 62.943
# Reward after 02925 episodes: 61.715
# Reward after 02926 episodes: 53.234
# Reward after 02927 episodes: 75.538
# Reward after 02928 episodes: 66.782
# Reward after 02929 episodes: 41.439
# Reward after 02930 episodes: 90.926
# Reward after 02931 episodes: 152.010
# Reward after 02932 episodes: 49.435
# Reward after 02933 episodes: 60.345
# Reward after 02934 episodes: 714.864
# Reward after 02935 episodes: 90.665
# Reward after 02936 episodes: 46.411
# Reward after 02937 episodes: 623.350
# Reward after 02938 episodes: 29.623
# Reward after 02939 episodes: 667.383
# Reward after 02940 episodes: 69.397
# Reward after 02941 episodes: 71.565
# Reward after 02942 episodes: 709.807
# Reward after 02943 episodes: 57.290
# Reward after 02944 episodes: 86.048
# Reward after 02945 episodes: 118.914
# Reward after 02946 episodes: 62.447
# Reward after 02947 episodes: 104.752
# Reward after 02948 episodes: 143.325
# Reward after 02949 episodes: 256.286
# Reward after 02950 episodes: 105.012
# Reward after 02951 episodes: 93.896
# Reward after 02952 episodes: 83.081
# Reward after 02953 episodes: 209.435
# Reward after 02954 episodes: 122.354
# Reward after 02955 episodes: 89.159
# Reward after 02956 episodes: 699.458
# Reward after 02957 episodes: 54.830
# Reward after 02958 episodes: 669.683
# Reward after 02959 episodes: 55.489
# Reward after 02960 episodes: 51.213
# Reward after 02961 episodes: 149.410
# Reward after 02962 episodes: 693.178
# Reward after 02963 episodes: 696.185
# Reward after 02964 episodes: 162.147
# Reward after 02965 episodes: 117.680
# Reward after 02966 episodes: 52.151
# Reward after 02967 episodes: 78.970
# Reward after 02968 episodes: 46.859
# Reward after 02969 episodes: 226.598
# Reward after 02970 episodes: 38.069
# Reward after 02971 episodes: 39.971
# Reward after 02972 episodes: 69.834
# Reward after 02973 episodes: 73.139
# Reward after 02974 episodes: 700.406
# Reward after 02975 episodes: 727.487
# Reward after 02976 episodes: 728.370
# Reward after 02977 episodes: 54.667
# Reward after 02978 episodes: 72.641
# Reward after 02979 episodes: 91.488
# Reward after 02980 episodes: 75.177
# Reward after 02981 episodes: 80.284
# Reward after 02982 episodes: 110.893
# Reward after 02983 episodes: 74.766
# Reward after 02984 episodes: 60.883
# Reward after 02985 episodes: 27.970
# Reward after 02986 episodes: 76.956
# Reward after 02987 episodes: 39.206
# Reward after 02988 episodes: 79.581
# Reward after 02989 episodes: 90.299
# Reward after 02990 episodes: 87.716
# Reward after 02991 episodes: 76.735
# Reward after 02992 episodes: 711.788
# Reward after 02993 episodes: -1.000
# Reward after 02994 episodes: 666.609
# Reward after 02995 episodes: 685.405
# Reward after 02996 episodes: 726.137
# Reward after 02997 episodes: 726.667
# Reward after 02998 episodes: 723.476
# Reward after 02999 episodes: 128.402
# Reward after 03000 episodes: 683.152
# Total execution time: 1149.2470166666667 minutes
# <br/>Waiting for W&B process to finish, PID 12686<br/>Program failed with code 1.  Press ctrl-c to abort syncing.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/host/unity_builds/run32_training/wandb/run-20210605_154708-1qddottr/logs/debug.log</code>
# Find internal logs for this run at: <code>/host/unity_builds/run32_training/wandb/run-20210605_154708-1qddottr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>reward</td><td>683.15176</td></tr><tr><td>_runtime</td><td>69067</td></tr><tr><td>_timestamp</td><td>1622977095</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>reward</td><td>▂▂▂▄▂▃▃▅▃▄▂▂▂▄▂▃▂▁▂▇▂█▃▁▁▁▁▁▁▃▂▁▂▁▁███▂█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">eager-shape-6</strong>: <a href="https://wandb.ai/ademord/pytorch-DQN/runs/1qddottr" target="_blank">https://wandb.ai/ademord/pytorch-DQN/runs/1qddottr</a><br/>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-318ae2ededa3> in <module>
#       1 # Build, train and analyze the model with the pipeline
# ----> 2 model, env = model_pipeline(config)
#
# <ipython-input-8-d0bd6fe89dd6> in model_pipeline(hyperparameters)
#      20
#      21         # and test its final performance
# ---> 22         test(model, env, config)
#      23
#      24         env.close()
#
# <ipython-input-17-6a0ed141b2e1> in test(model, env, config)
#      23
#      24         print(f"Average reward of the model after {config.NUM_TEST_STEPS} " +
# ---> 25               f"test episodes: {numpy.mean(cumulative_rewards)}%")
#      26
#      27         wandb.log({"test_average_reward": numpy.mean(cumulative_rewards)})
#
# NameError: name 'numpy' is not defined

# %% [markdown]
# # 🧹 Test Hyperparameters with Sweeps

# %% [markdown]
# ## [Check out Hyperparameter Optimization in PyTorch using W&B Sweep $\rightarrow$](https://colab.research.google.com/drive/1QTIK23LBuAkdejbrvdP5hwBGyYlyEJpT?usp=sharing)
#
# Running a hyperparameter sweep with Weights & Biases is very easy. There are just 3 simple steps:
#
# 1. **Define the sweep:** We do this by creating a dictionary or a [YAML file](https://docs.wandb.com/library/sweeps/configuration) that specifies the parameters to search through, the search strategy, the optimization metric et all.
#
# 2. **Initialize the sweep:**
# `sweep_id = wandb.sweep(sweep_config)`
#
# 3. **Run the sweep agent:**
# `wandb.agent(sweep_id, function=train)`
#
# And voila! That's all there is to running a hyperparameter sweep!
# <img src="https://imgur.com/UiQKg0L.png" alt="Weights & Biases" />

# %% [markdown]
# # 🤓 Advanced Setup
# 1. [Environment variables](https://docs.wandb.com/library/environment-variables): Set API keys in environment variables so you can run training on a managed cluster.
# 2. [Offline mode](https://docs.wandb.com/library/technical-faq#can-i-run-wandb-offline): Use `dryrun` mode to train offline and sync results later.
# 3. [On-prem](https://docs.wandb.com/self-hosted): Install W&B in a private cloud or air-gapped servers in your own infrastructure. We have local installations for everyone from academics to enterprise teams.
# 4. [Sweeps](https://docs.wandb.com/sweeps): Set up hyperparameter search quickly with our lightweight tool for tuning.

# %%
# for n in range(NUM_TRAINING_STEPS):
#   new_exp,_ = Trainer.generate_trajectories(env, qnet, NUM_NEW_EXP, epsilon=0.1)
#   random.shuffle(experiences)
#   if len(experiences) > BUFFER_SIZE:
#     experiences = experiences[:BUFFER_SIZE]
#   experiences.extend(new_exp)
#   Trainer.update_q_net(qnet, optim, experiences, 3)
#   _, rewards = Trainer.generate_trajectories(env, qnet, 100, epsilon=0)
#   cumulative_rewards.append(rewards)
#   print("Training step ", n+1, "\treward ", rewards)
#   print()


# env.close()

# # Show the training graph
# plt.plot(range(NUM_TRAINING_STEPS), cumulative_rewards)

# %%
#  class UnityEnv(gym.Env):
#     """
#     Provides Gym wrapper for Unity Learning Environments.
#     Multi-agent environments use lists for object types, as done here:
#     https://github.com/openai/multiagent-particle-envs
#     """
 
#     def __init__(
#         self,
#         environment_filename: str,
#         dimensions: int = [],   #Added
#         timescale: int = 1,     #Added
#         worker_id: int = 0,
#         use_visual: bool = False,
#         uint8_visual: bool = False,
#         multiagent: bool = False,
#         flatten_branched: bool = False,
#         no_graphics: bool = False,
#         allow_multiple_visual_obs: bool = False,
#         set_config: bool = True,    #Added
#     ):
#         """
#         Environment initialization
#         :param environment_filename: The UnityEnvironment path or file to be wrapped in the gym.
#         :param worker_id: Worker number for environment.
#         :param use_visual: Whether to use visual observation or vector observation.
#         :param uint8_visual: Return visual observations as uint8 (0-255) matrices instead of float (0.0-1.0).
#         :param multiagent: Whether to run in multi-agent mode (lists of obs, reward, done).
#         :param flatten_branched: If True, turn branched discrete action spaces into a Discrete space rather than
#             MultiDiscrete.
#         :param no_graphics: Whether to run the Unity simulator in no-graphics mode
#         :param allow_multiple_visual_obs: If True, return a list of visual observations instead of only one.
#         """
#         base_port = 5005
#         if environment_filename is None:
#             base_port = UnityEnvironment.DEFAULT_EDITOR_PORT
 
#         channel = EngineConfigurationChannel()        # Added
 
 
#         #Added
#         if set_config == True:
#             channel.set_configuration_parameters(time_scale=timescale, width=dimensions[0], height=dimensions[1])
#         #Added
 
#         self._env = UnityEnvironment(
#             environment_filename,
#             worker_id,
#             base_port=base_port,
#             no_graphics=no_graphics,
#             side_channels=[channel],        # Added
#         )
