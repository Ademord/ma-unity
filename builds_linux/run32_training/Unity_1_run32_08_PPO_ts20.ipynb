# %% [markdown]
# # 🚀 Install, Import, and Log In

# %%
import mlagents
from mlagents_envs.environment import UnityEnvironment as UE
from mlagents_envs.environment import ActionTuple, BaseEnv
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
# import matplotlib.pyplot as plt
# %matplotlib inline
import random
from functools import wraps
from time import time


import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from tqdm.notebook import tqdm
from ipywidgets import IntProgress

from typing import Tuple, Dict
from math import floor

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

############################### Import libraries ###############################


import os
import glob
import time
from datetime import datetime

from torch.distributions import MultivariateNormal
from torch.distributions import Categorical

# import roboschool
# import pybullet_envs


################################## set device ##################################

print("============================================================================================")


# set device to cpu or cuda
device = torch.device('cpu')

if(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    print("Device set to : cpu")
    
print("============================================================================================")
# Out:
# device(type='cuda', index=0)

# %%
def measure(func):
    @wraps(func)
    def _time_it(*args, **kwargs):
        start = int(round(time() * 1000))
        try:
            return func(*args, **kwargs)
        finally:
            end_ = int(round(time() * 1000)) - start
            print(f"Total execution time: {end_/(1000*60) if end_ > 0 else 0} minutes")
    return _time_it

# %% [markdown]
# ### 0️⃣ Step 0: Install W&B

# %%
# %%capture
# !pip install wandb

# %% [markdown]
# ### 1️⃣ Step 1: Import W&B and Login

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: ademord (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# # 👩‍🔬 Define the Experiment and Pipeline

# %% [markdown]
# ### 2️⃣ Step 2: Track metadata and hyperparameters with `wandb.init`

# %%
config = dict(
    epochs=5,
    classes=10,
    kernels=[16, 32],
    batch_size=128,
    learning_rate=0.001,
    dataset="MNIST",
    architecture="CNN",
    NUM_TRAINING_STEPS = int(1e4), #10000000
    NUM_TEST_STEPS = 10,
    NUM_NEW_EXP = 1000,
    BUFFER_SIZE = 10000,
    worker_id=2,
    time_scale=20,
    no_graphics = True
    )
env = None

# %%
def model_pipeline(hyperparameters):
    global env
    
    try:
        env.close()
    except:
        pass

    # tell wandb to get started
    with wandb.init(project="pytorch-DQN", config=hyperparameters):
        # access all HPs through wandb.config, so logging matches execution!
        config = wandb.config

        # make the model, data, and optimization problem
        model, env, criterion, optimizer = make(config)
        print(model)

        # and use them to train the model
        train(model, env, criterion, optimizer, config)

        # and test its final performance
        test(model, env, config)

        env.close()

    return model

# %%
def make(config):
    # Make the data
    env, spec = make_env(config)
    
    # Make the model
    # model = Agent(config.kernels, config.classes).to(device)
    model = QNetwork((44, 1), 126, 3)

    # Make the loss and optimizer
    criterion = torch.nn.MSELoss() # None # nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
    
    return model, env, criterion, optimizer

# %% [markdown]
# # 📡 Define the Env Loading and Model

# %%
def make_env(config):
    channel = EngineConfigurationChannel()
    env = UE("run32_training", seed=1, worker_id=config.worker_id, no_graphics=config.no_graphics, side_channels=[channel])
    channel.set_configuration_parameters(time_scale = config.time_scale)
    print("Environment created.")
    
    env.reset()
    behavior_name = list(env.behavior_specs)[0]
    print(f"Name of the behavior : {behavior_name}")
    
    spec = env.behavior_specs[behavior_name]
    print(f"Type of the spec : {spec}")
    
    return env, spec

# %%
################################## PPO Policy ##################################
class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
    

    def clear(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]


class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, has_continuous_action_space, action_std_init):
        super(ActorCritic, self).__init__()

        self.has_continuous_action_space = has_continuous_action_space

        if has_continuous_action_space:
            self.action_dim = action_dim
            self.action_var = torch.full((action_dim,), action_std_init * action_std_init).to(device)

        # actor
        if has_continuous_action_space :
            self.actor = nn.Sequential(
                            nn.Linear(state_dim, 64),
                            nn.Tanh(),
                            nn.Linear(64, 64),
                            nn.Tanh(),
                            nn.Linear(64, action_dim),
                            nn.Tanh()
                        )
        else:
            self.actor = nn.Sequential(
                            nn.Linear(state_dim, 64),
                            nn.Tanh(),
                            nn.Linear(64, 64),
                            nn.Tanh(),
                            nn.Linear(64, action_dim),
                            nn.Softmax(dim=-1)
                        )

        
        # critic
        self.critic = nn.Sequential(
                        nn.Linear(state_dim, 64),
                        nn.Tanh(),
                        nn.Linear(64, 64),
                        nn.Tanh(),
                        nn.Linear(64, 1)
                    )
        
    def set_action_std(self, new_action_std):

        if self.has_continuous_action_space:
            self.action_var = torch.full((self.action_dim,), new_action_std * new_action_std).to(device)
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling ActorCritic::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def forward(self):
        raise NotImplementedError
    

    def act(self, state):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            cov_mat = torch.diag(self.action_var).unsqueeze(dim=0)
            dist = MultivariateNormal(action_mean, cov_mat)
        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action = dist.sample()
        action_logprob = dist.log_prob(action)
        
        return action.detach(), action_logprob.detach()
    

    def evaluate(self, state, action):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            action_var = self.action_var.expand_as(action_mean)
            cov_mat = torch.diag_embed(action_var).to(device)
            dist = MultivariateNormal(action_mean, cov_mat)
            
            # for single action continuous environments
            if self.action_dim == 1:
                action = action.reshape(-1, self.action_dim)

        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        state_values = self.critic(state)
        
        return action_logprobs, state_values, dist_entropy


class PPO:
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std_init=0.6):

        self.has_continuous_action_space = has_continuous_action_space

        if has_continuous_action_space:
            self.action_std = action_std_init

        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.buffer = RolloutBuffer()

        self.policy = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init).to(device)
        self.optimizer = torch.optim.Adam([
                        {'params': self.policy.actor.parameters(), 'lr': lr_actor},
                        {'params': self.policy.critic.parameters(), 'lr': lr_critic}
                    ])

        self.policy_old = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()


    def set_action_std(self, new_action_std):
        
        if self.has_continuous_action_space:
            self.action_std = new_action_std
            self.policy.set_action_std(new_action_std)
            self.policy_old.set_action_std(new_action_std)
        
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling PPO::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def decay_action_std(self, action_std_decay_rate, min_action_std):
        print("--------------------------------------------------------------------------------------------")

        if self.has_continuous_action_space:
            self.action_std = self.action_std - action_std_decay_rate
            self.action_std = round(self.action_std, 4)
            if (self.action_std <= min_action_std):
                self.action_std = min_action_std
                print("setting actor output action_std to min_action_std : ", self.action_std)
            else:
                print("setting actor output action_std to : ", self.action_std)
            self.set_action_std(self.action_std)

        else:
            print("WARNING : Calling PPO::decay_action_std() on discrete action space policy")

        print("--------------------------------------------------------------------------------------------")


    def select_action(self, state):

        if self.has_continuous_action_space:
            with torch.no_grad():
                state = torch.FloatTensor(state).to(device)
                action, action_logprob = self.policy_old.act(state)

            self.buffer.states.append(state)
            self.buffer.actions.append(action)
            self.buffer.logprobs.append(action_logprob)

            return action.detach().cpu().numpy().flatten()

        else:
            with torch.no_grad():
                state = torch.FloatTensor(state).to(device)
                action, action_logprob = self.policy_old.act(state)
            
            self.buffer.states.append(state)
            self.buffer.actions.append(action)
            self.buffer.logprobs.append(action_logprob)

            return action.item()


    def update(self):

        # Monte Carlo estimate of returns
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
            
        # Normalizing the rewards
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        # convert list to tensor
        old_states = torch.squeeze(torch.stack(self.buffer.states, dim=0)).detach().to(device)
        old_actions = torch.squeeze(torch.stack(self.buffer.actions, dim=0)).detach().to(device)
        old_logprobs = torch.squeeze(torch.stack(self.buffer.logprobs, dim=0)).detach().to(device)

        
        # Optimize policy for K epochs
        for _ in range(self.K_epochs):

            # Evaluating old actions and values
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)

            # match state_values tensor dimensions with rewards tensor
            state_values = torch.squeeze(state_values)
            
            # Finding the ratio (pi_theta / pi_theta__old)
            ratios = torch.exp(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss
            advantages = rewards - state_values.detach()   
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages

            # final loss of clipped objective PPO
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
        # Copy new weights into old policy
        self.policy_old.load_state_dict(self.policy.state_dict())

        # clear buffer
        self.buffer.clear()
    
    
    def save(self, checkpoint_path):
        torch.save(self.policy_old.state_dict(), checkpoint_path)
   

    def load(self, checkpoint_path):
        self.policy_old.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
        self.policy.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))

# %% [markdown]
# # 👟 Define Training Logic

# %% [markdown]
# ### 3️⃣ Step 3. Track gradients with `wandb.watch` and everything else with `wandb.log`

# %%
@measure
def train(model, env, criterion, optimizer, config):
    wandb.watch(model, criterion, log="all", log_freq=10)
    experiences: Buffer = []

    cumulative_rewards: List[float] = []
    NUM_NEW_EXP = config.NUM_NEW_EXP
    BUFFER_SIZE = config.BUFFER_SIZE

    behavior_name = list(env.behavior_specs)[0]
        
    for episode in range(config.NUM_TRAINING_STEPS):
        new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
        random.shuffle(experiences)
        if len(experiences) > BUFFER_SIZE:
            experiences = experiences[:BUFFER_SIZE]
        experiences.extend(new_exp)
        Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
        _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
        cumulative_rewards.append(rewards)
        # print("Training step ", episode + 1, "\treward ", episode_rewards)
        train_log(rewards, episode)

# %%
print("============================================================================================")


################################### Training ###################################

config = dict(
    # Env HP
    worker_id=0,
    time_scale=20,
    no_graphics = True,
    # Generic HP
    NUM_TEST_STEPS = 10,
    NUM_TRAINING_STEPS = int(1e4),
    # Algorithm HP
    max_ep_len = 800,
    has_continuous_action_space =  False,
    K_epochs = 40               # update policy for K epochs
    eps_clip = 0.2              # clip parameter for PPO
    gamma = 0.9
    lr_actor = 0.0003,
    lr_critic = 0.001
    )
####### initialize environment hyperparameters ######

has_continuous_action_space = config.has_continuous_action_space

max_ep_len = config.max_ep_len                    # max timesteps in one episode
max_training_timesteps = config.NUM_TRAINING_STEPS   # break training loop if timeteps > max_training_timesteps

print_freq = max_ep_len * 4     # print avg reward in the interval (in num timesteps)
log_freq = max_ep_len * 2       # log avg reward in the interval (in num timesteps)
save_model_freq = int(2e4)      # save model frequency (in num timesteps)

action_std = None


#####################################################


## Note : print/log frequencies should be > than max_ep_len


################ PPO hyperparameters ################

update_timestep = max_ep_len * 4   # update policy every n timesteps
K_epochs = config.K_epochs         # update policy for K epochs
eps_clip = config.eps_clip         # clip parameter for PPO
gamma = config.gamma               # discount factor

lr_actor = config.lr_actor         # learning rate for actor network
lr_critic = config.lr_critic       # learning rate for critic network

random_seed = 0         # set random seed if required (0 = no random seed)

#####################################################



print("training environment name : " + env_name)


# state space dimension
state_dim = env.observation_space.shape[0]

# action space dimension
if has_continuous_action_space:
    action_dim = env.action_space.shape[0]
else:
    action_dim = env.action_space.n



###################### logging ######################

#### log files for multiple runs are NOT overwritten

log_dir = "PPO_logs"
if not os.path.exists(log_dir):
      os.makedirs(log_dir)

log_dir = log_dir + '/' + env_name + '/'
if not os.path.exists(log_dir):
      os.makedirs(log_dir)


#### get number of log files in log directory
run_num = 0
current_num_files = next(os.walk(log_dir))[2]
run_num = len(current_num_files)


#### create new log file for each run 
log_f_name = log_dir + '/PPO_' + env_name + "_log_" + str(run_num) + ".csv"

print("current logging run number for " + env_name + " : ", run_num)
print("logging at : " + log_f_name)

#####################################################


################### checkpointing ###################

run_num_pretrained = 0      #### change this to prevent overwriting weights in same env_name folder

directory = "PPO_preTrained"
if not os.path.exists(directory):
      os.makedirs(directory)

directory = directory + '/' + env_name + '/'
if not os.path.exists(directory):
      os.makedirs(directory)


checkpoint_path = directory + "PPO_{}_{}_{}.pth".format(env_name, random_seed, run_num_pretrained)
print("save checkpoint path : " + checkpoint_path)

#####################################################


############# print all hyperparameters #############

print("--------------------------------------------------------------------------------------------")

print("max training timesteps : ", max_training_timesteps)
print("max timesteps per episode : ", max_ep_len)

print("model saving frequency : " + str(save_model_freq) + " timesteps")
print("log frequency : " + str(log_freq) + " timesteps")
print("printing average reward over episodes in last : " + str(print_freq) + " timesteps")

print("--------------------------------------------------------------------------------------------")

print("state space dimension : ", state_dim)
print("action space dimension : ", action_dim)

print("--------------------------------------------------------------------------------------------")

if has_continuous_action_space:
    print("Initializing a continuous action space policy")
    print("--------------------------------------------------------------------------------------------")
    print("starting std of action distribution : ", action_std)
    print("decay rate of std of action distribution : ", action_std_decay_rate)
    print("minimum std of action distribution : ", min_action_std)
    print("decay frequency of std of action distribution : " + str(action_std_decay_freq) + " timesteps")

else:
    print("Initializing a discrete action space policy")

print("--------------------------------------------------------------------------------------------")

print("PPO update frequency : " + str(update_timestep) + " timesteps") 
print("PPO K epochs : ", K_epochs)
print("PPO epsilon clip : ", eps_clip)
print("discount factor (gamma) : ", gamma)

print("--------------------------------------------------------------------------------------------")

print("optimizer learning rate actor : ", lr_actor)
print("optimizer learning rate critic : ", lr_critic)

if random_seed:
    print("--------------------------------------------------------------------------------------------")
    print("setting random seed to ", random_seed)
    torch.manual_seed(random_seed)
    env.seed(random_seed)
    np.random.seed(random_seed)

#####################################################

print("============================================================================================")

################# training procedure ################

# initialize a PPO agent
ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std)


# track total training time
start_time = datetime.now().replace(microsecond=0)
print("Started training at (GMT) : ", start_time)

print("============================================================================================")


# logging file
log_f = open(log_f_name,"w+")
log_f.write('episode,timestep,reward\n')


# printing and logging variables
print_running_reward = 0
print_running_episodes = 0

log_running_reward = 0
log_running_episodes = 0

time_step = 0
i_episode = 0


# training loop
while time_step <= max_training_timesteps:
    
    state = env.reset()
    current_ep_reward = 0

    for t in range(1, max_ep_len+1):
        
        # select action with policy
        action = ppo_agent.select_action(state)
        state, reward, done, _ = env.step(action)
        
        # saving reward and is_terminals
        ppo_agent.buffer.rewards.append(reward)
        ppo_agent.buffer.is_terminals.append(done)
        
        time_step +=1
        current_ep_reward += reward

        # update PPO agent
        if time_step % update_timestep == 0:
            ppo_agent.update()

        # if continuous action space; then decay action std of ouput action distribution
        if has_continuous_action_space and time_step % action_std_decay_freq == 0:
            ppo_agent.decay_action_std(action_std_decay_rate, min_action_std)

        # log in logging file
        if time_step % log_freq == 0:

            # log average reward till last episode
            log_avg_reward = log_running_reward / log_running_episodes
            log_avg_reward = round(log_avg_reward, 4)

            log_f.write('{},{},{}\n'.format(i_episode, time_step, log_avg_reward))
            log_f.flush()

            log_running_reward = 0
            log_running_episodes = 0

        # printing average reward
        if time_step % print_freq == 0:

            # print average reward till last episode
            print_avg_reward = print_running_reward / print_running_episodes
            print_avg_reward = round(print_avg_reward, 2)

            print("Episode : {} \t\t Timestep : {} \t\t Average Reward : {}".format(i_episode, time_step, print_avg_reward))

            print_running_reward = 0
            print_running_episodes = 0
            
        # save model weights
        if time_step % save_model_freq == 0:
            print("--------------------------------------------------------------------------------------------")
            print("saving model at : " + checkpoint_path)
            ppo_agent.save(checkpoint_path)
            print("model saved")
            print("Elapsed Time  : ", datetime.now().replace(microsecond=0) - start_time)
            print("--------------------------------------------------------------------------------------------")
            
        # break; if the episode is over
        if done:
            break

    print_running_reward += current_ep_reward
    print_running_episodes += 1

    log_running_reward += current_ep_reward
    log_running_episodes += 1

    i_episode += 1


log_f.close()
env.close()




# print total training time
print("============================================================================================")
end_time = datetime.now().replace(microsecond=0)
print("Started training at (GMT) : ", start_time)
print("Finished training at (GMT) : ", end_time)
print("Total training time  : ", end_time - start_time)
print("============================================================================================")

# %%
def train_log(reward, episode):
#     loss = float(loss)
    reward = float(reward)
    episode +=1
    
    # where the magic happens
    wandb.log({"episode": episode, "reward": reward}) #, step=example_ct
    print(f"Reward after " + str(episode).zfill(5) + f" episodes: {reward:.3f}")

# %% [markdown]
# # 🧪 Define Testing Logic

# %% [markdown]
# #### 4️⃣ Optional Step 4: Call `wandb.save`

# %%
def test(model, env, config):
    model.eval()

    # Run the model on some test examples
    with torch.no_grad():
        experiences: Buffer = []
        cumulative_rewards: List[float] = []
        NUM_NEW_EXP = config.NUM_NEW_EXP
        BUFFER_SIZE = config.BUFFER_SIZE

        behavior_name = list(env.behavior_specs)[0]

        for episode in range(config.NUM_TEST_STEPS):
            new_exp,_ = Trainer.generate_trajectories(env, model, NUM_NEW_EXP, epsilon=0.1)
            random.shuffle(experiences)
            if len(experiences) > BUFFER_SIZE:
                experiences = experiences[:BUFFER_SIZE]
            experiences.extend(new_exp)
#                 Trainer.update_q_net(model, criterion, optimizer, experiences, 3)
            _, rewards = Trainer.generate_trajectories(env, model, 100, epsilon=0)
            cumulative_rewards.append(rewards)
            # print("Training step ", episode + 1, "\treward ", episode_rewards)

        print(f"Average reward of the model after {config.NUM_TEST_STEPS} " +
              f"test episodes: {numpy.mean(cumulative_rewards)}%")

        wandb.log({"test_average_reward": numpy.mean(cumulative_rewards)})

    # Save the model in the exchangeable ONNX format
    torch.onnx.export(model, [], "model.onnx")
    wandb.save("model.onnx")

# %% [markdown]
# # 🏃‍♀️ Run training and watch your metrics live on [wandb.ai](https://wandb.ai)!

# %%
# Build, train and analyze the model with the pipeline
model, env = model_pipeline(config)
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">fragrant-moon-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ademord/pytorch-DQN" target="_blank">https://wandb.ai/ademord/pytorch-DQN</a><br/>
#                 Run page: <a href="https://wandb.ai/ademord/pytorch-DQN/runs/2dq72nzi" target="_blank">https://wandb.ai/ademord/pytorch-DQN/runs/2dq72nzi</a><br/>
#                 Run data is saved locally in <code>/host/unity_builds/run32_training/wandb/run-20210604_211419-2dq72nzi</code><br/><br/>
# Environment created.
# Name of the behavior : Hummingbird?team=0
# Type of the spec : BehaviorSpec(observation_specs=[ObservationSpec(shape=(44,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='RayPerceptionSensor'), ObservationSpec(shape=(3,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='StackingSensor_size3_VectorSensor_size1')], action_spec=ActionSpec(continuous_size=0, discrete_branches=(3, 3, 3)))
# QNetwork(
#   (dense1): Linear(in_features=44, out_features=126, bias=True)
#   (dense2): Linear(in_features=126, out_features=126, bias=True)
#   (dense2_x1): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x2): Linear(in_features=126, out_features=3, bias=True)
#   (dense2_x3): Linear(in_features=126, out_features=3, bias=True)
#   (act): ReLU()
#   (act_out): Sigmoid()
# )
# Reward after 00001 episodes: -1.000
# Reward after 00002 episodes: 21.312
# Reward after 00003 episodes: 36.029
# Reward after 00004 episodes: 9.989
# Reward after 00005 episodes: -1.000
# Reward after 00006 episodes: 0.000
# Reward after 00007 episodes: -1.000
# Reward after 00008 episodes: 26.063
# Reward after 00009 episodes: 22.584
# Reward after 00010 episodes: 21.429
# Reward after 00011 episodes: 31.244
# Reward after 00012 episodes: 8.907
# Reward after 00013 episodes: 36.174
# Reward after 00014 episodes: 0.000
# Reward after 00015 episodes: 183.145
# Reward after 00016 episodes: 28.930
# Reward after 00017 episodes: 36.868
# Reward after 00018 episodes: 42.307
# Reward after 00019 episodes: 1.721
# Reward after 00020 episodes: 727.999
# Reward after 00021 episodes: 26.766
# Reward after 00022 episodes: 23.492
# Reward after 00023 episodes: 47.389
# Reward after 00024 episodes: 53.600
# Reward after 00025 episodes: 52.799
# Reward after 00026 episodes: 652.628
# Reward after 00027 episodes: 753.109
# Reward after 00028 episodes: 31.286
# Reward after 00029 episodes: 44.132
# Reward after 00030 episodes: 0.000
# Reward after 00031 episodes: 25.716
# Reward after 00032 episodes: 1.687
# Reward after 00033 episodes: 0.000
# Reward after 00034 episodes: 0.000
# Reward after 00035 episodes: 0.000
# Reward after 00036 episodes: 3.969
# Reward after 00037 episodes: -1.000
# Reward after 00038 episodes: 8.625
# Reward after 00039 episodes: 45.599
# Reward after 00040 episodes: 9.042
# Reward after 00041 episodes: 31.126
# Reward after 00042 episodes: 331.627
# Reward after 00043 episodes: 7.859
# Reward after 00044 episodes: -1.000
# Reward after 00045 episodes: 29.863
# Reward after 00046 episodes: -1.000
# Reward after 00047 episodes: -1.000
# Reward after 00048 episodes: 3.880
# Reward after 00049 episodes: 67.956
# Reward after 00050 episodes: 24.913
# Reward after 00051 episodes: 26.625
# Reward after 00052 episodes: 24.587
# Reward after 00053 episodes: 63.678
# Reward after 00054 episodes: 55.945
# Reward after 00055 episodes: 85.409
# Reward after 00056 episodes: 68.620
# Reward after 00057 episodes: 59.092
# Reward after 00058 episodes: 13.164
# Reward after 00059 episodes: 128.910
# Reward after 00060 episodes: 46.042
# Reward after 00061 episodes: 23.782
# Reward after 00062 episodes: 108.928
# Reward after 00063 episodes: 11.121
# Reward after 00064 episodes: 92.870
# Reward after 00065 episodes: 61.146
# Reward after 00066 episodes: 7.949
# Reward after 00067 episodes: 20.903
# Reward after 00068 episodes: 17.235
# Reward after 00069 episodes: 42.137
# Reward after 00070 episodes: 88.528
# Reward after 00071 episodes: -1.000
# Reward after 00072 episodes: 60.668
# Reward after 00073 episodes: -1.000
# Reward after 00074 episodes: 158.255
# Reward after 00075 episodes: -1.000
# Reward after 00076 episodes: 62.186
# Reward after 00077 episodes: 1.751
# Reward after 00078 episodes: 449.808
# Reward after 00079 episodes: 119.393
# Reward after 00080 episodes: 68.769
# Reward after 00081 episodes: 715.859
# Reward after 00082 episodes: 157.322
# Reward after 00083 episodes: 212.001
# Reward after 00084 episodes: 143.422
# Reward after 00085 episodes: 7.420
# Reward after 00086 episodes: 11.772
# Reward after 00087 episodes: 362.828
# Reward after 00088 episodes: 22.958
# Reward after 00089 episodes: 1.018
# Reward after 00090 episodes: 706.788
# Reward after 00091 episodes: 307.882
# Reward after 00092 episodes: 67.813
# Reward after 00093 episodes: 67.809
# Reward after 00094 episodes: 228.113
# Reward after 00095 episodes: 659.331
# Reward after 00096 episodes: 730.418
# Reward after 00097 episodes: 732.110
# Reward after 00098 episodes: 724.021
# Reward after 00099 episodes: 725.494
# Reward after 00100 episodes: 732.713
# Reward after 00101 episodes: 12.729
# Reward after 00102 episodes: 730.091
# Reward after 00103 episodes: 32.022
# Reward after 00104 episodes: 374.442
# Reward after 00105 episodes: 19.737
# Reward after 00106 episodes: 57.802
# Reward after 00107 episodes: 67.021
# Reward after 00108 episodes: 81.321
# Reward after 00109 episodes: 111.270
# Reward after 00110 episodes: 733.018
# Reward after 00111 episodes: 690.004
# Reward after 00112 episodes: 733.873
# Reward after 00113 episodes: 733.948
# Reward after 00114 episodes: 729.289
# Reward after 00115 episodes: 735.824
# Reward after 00116 episodes: 727.191
# Reward after 00117 episodes: 731.918
# Reward after 00118 episodes: 729.173
# Reward after 00119 episodes: 730.396
# Reward after 00120 episodes: 728.510
# Reward after 00121 episodes: 734.702
# Reward after 00122 episodes: 729.266
# Reward after 00123 episodes: 728.787
# Reward after 00124 episodes: 731.635
# Reward after 00125 episodes: 734.849
# Reward after 00126 episodes: 712.897
# Reward after 00127 episodes: 731.314
# Reward after 00128 episodes: 728.680
# Reward after 00129 episodes: 668.436
# Reward after 00130 episodes: 24.246
# Reward after 00131 episodes: 366.388
# Reward after 00132 episodes: 720.682
# Reward after 00133 episodes: 730.045
# Reward after 00134 episodes: 362.165
# Reward after 00135 episodes: 731.121
# Reward after 00136 episodes: 713.920
# Reward after 00137 episodes: 691.295
# Reward after 00138 episodes: 661.947
# Reward after 00139 episodes: 730.572
# Reward after 00140 episodes: 728.445
# Reward after 00141 episodes: 707.965
# Reward after 00142 episodes: 66.894
# Reward after 00143 episodes: 19.616
# Reward after 00144 episodes: 701.273
# Reward after 00145 episodes: 703.055
# Reward after 00146 episodes: 29.960
# Reward after 00147 episodes: 77.250
# Reward after 00148 episodes: 682.665
# Reward after 00149 episodes: 714.020
# Reward after 00150 episodes: 702.442
# Reward after 00151 episodes: 692.732
# Reward after 00152 episodes: 732.173
# Reward after 00153 episodes: 731.482
# Reward after 00154 episodes: 718.267
# Reward after 00155 episodes: 731.910
# Reward after 00156 episodes: 732.228
# Reward after 00157 episodes: 732.021
# Reward after 00158 episodes: -1.000
# Reward after 00159 episodes: 733.390
# Reward after 00160 episodes: -1.000
# Reward after 00161 episodes: 282.562
# Reward after 00162 episodes: 296.319
# Reward after 00163 episodes: 735.060
# Reward after 00164 episodes: 280.244
# Reward after 00165 episodes: 736.424
# Reward after 00166 episodes: 299.541
# Reward after 00167 episodes: 653.444
# Reward after 00168 episodes: 335.323
# Reward after 00169 episodes: 732.215
# Reward after 00170 episodes: 734.941
# Reward after 00171 episodes: 732.450
# Reward after 00172 episodes: 221.708
# Reward after 00173 episodes: 656.933
# Reward after 00174 episodes: 732.408
# Reward after 00175 episodes: 733.214
# Reward after 00176 episodes: 732.591
# Reward after 00177 episodes: 730.726
# Reward after 00178 episodes: 730.856
# Reward after 00179 episodes: 732.227
# Reward after 00180 episodes: 429.751
# Reward after 00181 episodes: 139.718
# Reward after 00182 episodes: 731.741
# Reward after 00183 episodes: 721.067
# Reward after 00184 episodes: 734.202
# Reward after 00185 episodes: 733.036
# Reward after 00186 episodes: 731.606
# Reward after 00187 episodes: 732.666
# Reward after 00188 episodes: 732.127
# Reward after 00189 episodes: 732.265
# Reward after 00190 episodes: 729.816
# Reward after 00191 episodes: 731.738
# Reward after 00192 episodes: 733.592
# Reward after 00193 episodes: 732.417
# Reward after 00194 episodes: 730.399
# Reward after 00195 episodes: 732.906
# Reward after 00196 episodes: 730.318
# Reward after 00197 episodes: 727.900
# Reward after 00198 episodes: 16.413
# Reward after 00199 episodes: 731.862
# Reward after 00200 episodes: 369.319
# Reward after 00201 episodes: 1.240
# Reward after 00202 episodes: 10.859
# Reward after 00203 episodes: 733.613
# Reward after 00204 episodes: 18.031
# Reward after 00205 episodes: 480.682
# Reward after 00206 episodes: 379.222
# Reward after 00207 episodes: 455.154
# Reward after 00208 episodes: 386.664
# Reward after 00209 episodes: 733.104
# Reward after 00210 episodes: 731.470
# Reward after 00211 episodes: 729.549
# Reward after 00212 episodes: 732.304
# Reward after 00213 episodes: 730.607
# Reward after 00214 episodes: 733.087
# Reward after 00215 episodes: 731.190
# Reward after 00216 episodes: 728.238
# Reward after 00217 episodes: 366.473
# Reward after 00218 episodes: 726.831
# Reward after 00219 episodes: 728.591
# Reward after 00220 episodes: 726.904
# Reward after 00221 episodes: 731.414
# Reward after 00222 episodes: 721.808
# Reward after 00223 episodes: 729.304
# Reward after 00224 episodes: 737.920
# Reward after 00225 episodes: 731.655
# Reward after 00226 episodes: 13.587
# Reward after 00227 episodes: 368.761
# Reward after 00228 episodes: 14.024
# Reward after 00229 episodes: 10.594
# Reward after 00230 episodes: 732.576
# Reward after 00231 episodes: 733.546
# Reward after 00232 episodes: 15.625
# Reward after 00233 episodes: 732.105
# Reward after 00234 episodes: 375.489
# Reward after 00235 episodes: 5.836
# Reward after 00236 episodes: 734.518
# Reward after 00237 episodes: 9.305
# Reward after 00238 episodes: 733.504
# Reward after 00239 episodes: 732.115
# Reward after 00240 episodes: 731.557
# Reward after 00241 episodes: 714.084
# Reward after 00242 episodes: 728.825
# Reward after 00243 episodes: 736.955
# Reward after 00244 episodes: 732.772
# Reward after 00245 episodes: 728.934
# Reward after 00246 episodes: 728.504
# Reward after 00247 episodes: 707.843
# Reward after 00248 episodes: 732.791
# Reward after 00249 episodes: 727.648
# Reward after 00250 episodes: 732.433
# Reward after 00251 episodes: 735.592
# Reward after 00252 episodes: 730.445
# Reward after 00253 episodes: 734.608
# Reward after 00254 episodes: 73.192
# Reward after 00255 episodes: 104.859
# Reward after 00256 episodes: 425.712
# Reward after 00257 episodes: 729.559
# Reward after 00258 episodes: 730.913
# Reward after 00259 episodes: 733.410
# Reward after 00260 episodes: 732.507
# Reward after 00261 episodes: 729.206
# Reward after 00262 episodes: 734.016
# Reward after 00263 episodes: 735.349
# Reward after 00264 episodes: 728.290
# Reward after 00265 episodes: 727.077
# Reward after 00266 episodes: 733.157
# Reward after 00267 episodes: 729.716
# Reward after 00268 episodes: 728.482
# Reward after 00269 episodes: 726.150
# Reward after 00270 episodes: 720.118
# Reward after 00271 episodes: 444.919
# Reward after 00272 episodes: 729.726
# Reward after 00273 episodes: 730.914
# Reward after 00274 episodes: 740.521
# Reward after 00275 episodes: -1.000
# Reward after 00276 episodes: 738.220
# Reward after 00277 episodes: 35.406
# Reward after 00278 episodes: 56.597
# Reward after 00279 episodes: 392.705
# Reward after 00280 episodes: 733.655
# Reward after 00281 episodes: 731.065
# Reward after 00282 episodes: 665.297
# Reward after 00283 episodes: 731.407
# Reward after 00284 episodes: 52.381
# Reward after 00285 episodes: 51.556
# Reward after 00286 episodes: 736.802
# Reward after 00287 episodes: 729.520
# Reward after 00288 episodes: 726.159
# Reward after 00289 episodes: 730.847
# Reward after 00290 episodes: 408.910
# Reward after 00291 episodes: 422.428
# Reward after 00292 episodes: 738.449
# Reward after 00293 episodes: 403.666
# Reward after 00294 episodes: 737.917
# Reward after 00295 episodes: 736.056
# Reward after 00296 episodes: 741.604
# Reward after 00297 episodes: 734.029
# Reward after 00298 episodes: 191.852
# Reward after 00299 episodes: 740.449
# Reward after 00300 episodes: 735.760
# Reward after 00301 episodes: 732.401
# Reward after 00302 episodes: 738.189
# Reward after 00303 episodes: 738.921
# Reward after 00304 episodes: 729.458
# Reward after 00305 episodes: 741.012
# Reward after 00306 episodes: 490.336
# Reward after 00307 episodes: 82.430
# Reward after 00308 episodes: 734.897
# Reward after 00309 episodes: 740.208
# Reward after 00310 episodes: 741.051
# Reward after 00311 episodes: 729.267
# Reward after 00312 episodes: 741.714
# Reward after 00313 episodes: 740.122
# Reward after 00314 episodes: 105.927
# Reward after 00315 episodes: 726.376
# Reward after 00316 episodes: 742.083
# Reward after 00317 episodes: 733.948
# Reward after 00318 episodes: 191.118
# Reward after 00319 episodes: 736.972
# Reward after 00320 episodes: 734.244
# Reward after 00321 episodes: 737.529
# Reward after 00322 episodes: 740.969
# Reward after 00323 episodes: 744.220
# Reward after 00324 episodes: 737.633
# Reward after 00325 episodes: 737.227
# Reward after 00326 episodes: 741.849
# Reward after 00327 episodes: 731.810
# Reward after 00328 episodes: 721.518
# Reward after 00329 episodes: 739.297
# Reward after 00330 episodes: 131.738
# Reward after 00331 episodes: 91.197
# Reward after 00332 episodes: 724.579
# Reward after 00333 episodes: 62.481
# Reward after 00334 episodes: 97.988
# Reward after 00335 episodes: 160.742
# Reward after 00336 episodes: 730.454
# Reward after 00337 episodes: 729.929
# Reward after 00338 episodes: 734.507
# Reward after 00339 episodes: 109.417
# Reward after 00340 episodes: 82.666
# Reward after 00341 episodes: 42.989
# Reward after 00342 episodes: 76.840
# Reward after 00343 episodes: 104.344
# Reward after 00344 episodes: 742.968
# Reward after 00345 episodes: 743.418
# Reward after 00346 episodes: 732.182
# Reward after 00347 episodes: 737.078
# Reward after 00348 episodes: 733.815
# Reward after 00349 episodes: 744.265
# Reward after 00350 episodes: 65.038
# Reward after 00351 episodes: 739.458
# Reward after 00352 episodes: 82.028
# Reward after 00353 episodes: 738.446
# Reward after 00354 episodes: 734.940
# Reward after 00355 episodes: 740.824
# Reward after 00356 episodes: 741.754
# Reward after 00357 episodes: 740.012
# Reward after 00358 episodes: 734.545
# Reward after 00359 episodes: 741.866
# Reward after 00360 episodes: 735.186
# Reward after 00361 episodes: 737.623
# Reward after 00362 episodes: 739.862
# Reward after 00363 episodes: 739.856
# Reward after 00364 episodes: 736.858
# Reward after 00365 episodes: 742.924
# Reward after 00366 episodes: 733.595
# Reward after 00367 episodes: 736.117
# Reward after 00368 episodes: 740.373
# Reward after 00369 episodes: 738.513
# Reward after 00370 episodes: 733.727
# Reward after 00371 episodes: 728.534
# Reward after 00372 episodes: 715.520
# Reward after 00373 episodes: 730.719
# Reward after 00374 episodes: 725.950
# Reward after 00375 episodes: 3.873
# Reward after 00376 episodes: 22.058
# Reward after 00377 episodes: 739.667
# Reward after 00378 episodes: 735.562
# Reward after 00379 episodes: 717.114
# Reward after 00380 episodes: 739.505
# Reward after 00381 episodes: 0.000
# Reward after 00382 episodes: 0.160
# Reward after 00383 episodes: 16.433
# Reward after 00384 episodes: 45.609
# Reward after 00385 episodes: 31.786
# Reward after 00386 episodes: 1.111
# Reward after 00387 episodes: 1.182
# Reward after 00388 episodes: 7.804
# Reward after 00389 episodes: 10.136
# Reward after 00390 episodes: 0.000
# Reward after 00391 episodes: 0.000
# Reward after 00392 episodes: 0.000
# Reward after 00393 episodes: 0.000
# Reward after 00394 episodes: 0.000
# Reward after 00395 episodes: 28.360
# Reward after 00396 episodes: 14.475
# Reward after 00397 episodes: 744.162
# Reward after 00398 episodes: 732.708
# Reward after 00399 episodes: 730.973
# Reward after 00400 episodes: 69.010
# Reward after 00401 episodes: 115.470
# Reward after 00402 episodes: 49.836
# Reward after 00403 episodes: 5.742
# Reward after 00404 episodes: 120.492
# Reward after 00405 episodes: 11.026
# Reward after 00406 episodes: 132.776
# Reward after 00407 episodes: 35.966
# Reward after 00408 episodes: 15.967
# Reward after 00409 episodes: 13.695
# Reward after 00410 episodes: 2.532
# Reward after 00411 episodes: 9.425
# Reward after 00412 episodes: 732.590
# Reward after 00413 episodes: 52.891
# Reward after 00414 episodes: 736.474
# Reward after 00415 episodes: 734.958
# Reward after 00416 episodes: 735.919
# Reward after 00417 episodes: 732.988
# Reward after 00418 episodes: 400.246
# Reward after 00419 episodes: 428.669
# Reward after 00420 episodes: 421.955
# Reward after 00421 episodes: 731.774
# Reward after 00422 episodes: 18.913
# Reward after 00423 episodes: 371.922
# Reward after 00424 episodes: 121.880
# Reward after 00425 episodes: 734.402
# Reward after 00426 episodes: 727.296
# Reward after 00427 episodes: 739.384
# Reward after 00428 episodes: 719.730
# Reward after 00429 episodes: -1.000
# Reward after 00430 episodes: 734.036
# Reward after 00431 episodes: 1.393
# Reward after 00432 episodes: 0.799
# Reward after 00433 episodes: 738.959
# Reward after 00434 episodes: 641.315
# Reward after 00435 episodes: 370.576
# Reward after 00436 episodes: 663.077
# Reward after 00437 episodes: 6.456
# Reward after 00438 episodes: 8.305
# Reward after 00439 episodes: 10.066
# Reward after 00440 episodes: 7.752
# Reward after 00441 episodes: 6.835
# Reward after 00442 episodes: 6.892
# Reward after 00443 episodes: 5.648
# Reward after 00444 episodes: -1.000
# Reward after 00445 episodes: 364.962
# Reward after 00446 episodes: -1.000
# Reward after 00447 episodes: -1.000
# Reward after 00448 episodes: 10.093
# Reward after 00449 episodes: 10.397
# Reward after 00450 episodes: 11.661
# Reward after 00451 episodes: 35.684
# Reward after 00452 episodes: 12.463
# Reward after 00453 episodes: 16.597
# Reward after 00454 episodes: 215.111
# Reward after 00455 episodes: 21.581
# Reward after 00456 episodes: 8.717
# Reward after 00457 episodes: -1.000
# Reward after 00458 episodes: 3.151
# Reward after 00459 episodes: 16.155
# Reward after 00460 episodes: 20.404
# Reward after 00461 episodes: 14.638
# Reward after 00462 episodes: 5.194
# Reward after 00463 episodes: 720.081
# Reward after 00464 episodes: 1.915
# Reward after 00465 episodes: 736.219
# Reward after 00466 episodes: -1.000
# Reward after 00467 episodes: -1.000
# Reward after 00468 episodes: 728.025
# Reward after 00469 episodes: -1.000
# Reward after 00470 episodes: -1.000
# Reward after 00471 episodes: 732.565
# Reward after 00472 episodes: 13.348
# Reward after 00473 episodes: 727.273
# Reward after 00474 episodes: 165.106
# Reward after 00475 episodes: 23.163
# Reward after 00476 episodes: 725.188
# Reward after 00477 episodes: 727.435
# Reward after 00478 episodes: 35.266
# Reward after 00479 episodes: 25.292
# Reward after 00480 episodes: 27.858
# Reward after 00481 episodes: 52.822
# Reward after 00482 episodes: 69.554
# Reward after 00483 episodes: 275.223
# Reward after 00484 episodes: 68.548
# Reward after 00485 episodes: 85.562
# Reward after 00486 episodes: 97.144
# Reward after 00487 episodes: 28.436
# Reward after 00488 episodes: 157.574
# Reward after 00489 episodes: 45.707
# Reward after 00490 episodes: 83.179
# Reward after 00491 episodes: 90.479
# Reward after 00492 episodes: 90.189
# Reward after 00493 episodes: 54.444
# Reward after 00494 episodes: 84.573
# Reward after 00495 episodes: 67.131
# Reward after 00496 episodes: 135.388
# Reward after 00497 episodes: 156.047
# Reward after 00498 episodes: 72.318
# Reward after 00499 episodes: 145.396
# Reward after 00500 episodes: 102.717
# Reward after 00501 episodes: 62.298
# Reward after 00502 episodes: -1.000
# Reward after 00503 episodes: -1.000
# Reward after 00504 episodes: -1.000
# Reward after 00505 episodes: -1.000
# Reward after 00506 episodes: 5.521
# Reward after 00507 episodes: 30.256
# Reward after 00508 episodes: 19.232
# Reward after 00509 episodes: -1.000
# Reward after 00510 episodes: 14.618
# Reward after 00511 episodes: -1.000
# Reward after 00512 episodes: -1.000
# Reward after 00513 episodes: -1.000
# Reward after 00514 episodes: 120.639
# Reward after 00515 episodes: 131.046
# Reward after 00516 episodes: 129.180
# Reward after 00517 episodes: 37.770
# Reward after 00518 episodes: 63.886
# Reward after 00519 episodes: 38.329
# Reward after 00520 episodes: 140.183
# Reward after 00521 episodes: 146.734
# Reward after 00522 episodes: 115.799
# Reward after 00523 episodes: 207.238
# Reward after 00524 episodes: 165.381
# Reward after 00525 episodes: -1.000
# Reward after 00526 episodes: 56.201
# Reward after 00527 episodes: 41.396
# Reward after 00528 episodes: 204.115
# Reward after 00529 episodes: 68.508
# Reward after 00530 episodes: 30.122
# Reward after 00531 episodes: 0.000
# Reward after 00532 episodes: 0.000
# Reward after 00533 episodes: 0.288
# Reward after 00534 episodes: 0.812
# Reward after 00535 episodes: 84.425
# Reward after 00536 episodes: 0.000
# Reward after 00537 episodes: 2.618
# Reward after 00538 episodes: 0.000
# Reward after 00539 episodes: 0.000
# Reward after 00540 episodes: 4.245
# Reward after 00541 episodes: 0.000
# Reward after 00542 episodes: 0.000
# Reward after 00543 episodes: 0.000
# Reward after 00544 episodes: 0.000
# Reward after 00545 episodes: 0.000
# Reward after 00546 episodes: 59.633
# Reward after 00547 episodes: 13.839
# Reward after 00548 episodes: 16.390
# Reward after 00549 episodes: 31.634
# Reward after 00550 episodes: 220.856
# Reward after 00551 episodes: 46.497
# Reward after 00552 episodes: 55.467
# Reward after 00553 episodes: 45.773
# Reward after 00554 episodes: 25.893
# Reward after 00555 episodes: 3.663
# Reward after 00556 episodes: 3.678
# Reward after 00557 episodes: 97.079
# Reward after 00558 episodes: 30.011
# Reward after 00559 episodes: 36.273
# Reward after 00560 episodes: 10.493
# Reward after 00561 episodes: 4.358
# Reward after 00562 episodes: 9.894
# Reward after 00563 episodes: 12.886
# Reward after 00564 episodes: 59.583
# Reward after 00565 episodes: 37.656
# Reward after 00566 episodes: 7.976
# Reward after 00567 episodes: 20.048
# Reward after 00568 episodes: 17.445
# Reward after 00569 episodes: 3.241
# Reward after 00570 episodes: 15.342
# Reward after 00571 episodes: 11.555
# Reward after 00572 episodes: 3.650
# Reward after 00573 episodes: 1.481
# Reward after 00574 episodes: 0.000
# Reward after 00575 episodes: 0.345
# Reward after 00576 episodes: 0.000
# Reward after 00577 episodes: 55.223
# Reward after 00578 episodes: 12.276
# Reward after 00579 episodes: 82.639
# Reward after 00580 episodes: 77.150
# Reward after 00581 episodes: 40.560
# Reward after 00582 episodes: 21.400
# Reward after 00583 episodes: 25.999
# Reward after 00584 episodes: 22.585
# Reward after 00585 episodes: 33.688
# Reward after 00586 episodes: 22.117
# Reward after 00587 episodes: 34.005
# Reward after 00588 episodes: 13.651
# Reward after 00589 episodes: 0.020
# Reward after 00590 episodes: 21.851
# Reward after 00591 episodes: 17.972
# Reward after 00592 episodes: 13.645
# Reward after 00593 episodes: 25.407
# Reward after 00594 episodes: 16.630
# Reward after 00595 episodes: 10.852
# Reward after 00596 episodes: 74.601
# Reward after 00597 episodes: 26.659
# Reward after 00598 episodes: 55.187
# Reward after 00599 episodes: 54.383
# Reward after 00600 episodes: 79.702
# Reward after 00601 episodes: 9.950
# Reward after 00602 episodes: 32.890
# Reward after 00603 episodes: 29.550
# Reward after 00604 episodes: 10.840
# Reward after 00605 episodes: 10.483
# Reward after 00606 episodes: 22.940
# Reward after 00607 episodes: 53.857
# Reward after 00608 episodes: 2.712
# Reward after 00609 episodes: 13.489
# Reward after 00610 episodes: 2.421
# Reward after 00611 episodes: 33.205
# Reward after 00612 episodes: 22.496
# Reward after 00613 episodes: 7.373
# Reward after 00614 episodes: 47.098
# Reward after 00615 episodes: 7.142
# Reward after 00616 episodes: 11.153
# Reward after 00617 episodes: 1.626
# Reward after 00618 episodes: 0.273
# Reward after 00619 episodes: 5.741
# Reward after 00620 episodes: 3.035
# Reward after 00621 episodes: 0.133
# Reward after 00622 episodes: 16.995
# Reward after 00623 episodes: 14.916
# Reward after 00624 episodes: 70.240
# Reward after 00625 episodes: -1.000
# Reward after 00626 episodes: 203.962
# Reward after 00627 episodes: 150.415
# Reward after 00628 episodes: 193.762
# Reward after 00629 episodes: 165.060
# Reward after 00630 episodes: 29.068
# Reward after 00631 episodes: 1.683
# Reward after 00632 episodes: -1.000
# Reward after 00633 episodes: 10.324
# Reward after 00634 episodes: 18.328
# Reward after 00635 episodes: 16.267
# Reward after 00636 episodes: 16.442
# Reward after 00637 episodes: 17.289
# Reward after 00638 episodes: 25.019
# Reward after 00639 episodes: 8.006
# Reward after 00640 episodes: 39.931
# Reward after 00641 episodes: 14.341
# Reward after 00642 episodes: 51.779
# Reward after 00643 episodes: 20.676
# Reward after 00644 episodes: 27.050
# Reward after 00645 episodes: 45.124
# Reward after 00646 episodes: 56.259
# Reward after 00647 episodes: 51.960
# Reward after 00648 episodes: 25.588
# Reward after 00649 episodes: 70.135
# Reward after 00650 episodes: 65.040
# Reward after 00651 episodes: 44.487
# Reward after 00652 episodes: 0.034
# Reward after 00653 episodes: 30.284
# Reward after 00654 episodes: 20.889
# Reward after 00655 episodes: 3.891
# Reward after 00656 episodes: 7.708
# Reward after 00657 episodes: 0.000
# Reward after 00658 episodes: 0.000
# Reward after 00659 episodes: 0.000
# Reward after 00660 episodes: 0.000
# Reward after 00661 episodes: 0.000
# Reward after 00662 episodes: 0.308
# Reward after 00663 episodes: 0.000
# Reward after 00664 episodes: 0.000
# Reward after 00665 episodes: 0.000
# Reward after 00666 episodes: 0.000
# Reward after 00667 episodes: 0.000
# Reward after 00668 episodes: 0.000
# Reward after 00669 episodes: 1.909
# Reward after 00670 episodes: 0.000
# Reward after 00671 episodes: 0.396
# Reward after 00672 episodes: 56.896
# Reward after 00673 episodes: 0.000
# Reward after 00674 episodes: 2.563
# Reward after 00675 episodes: 27.554
# Reward after 00676 episodes: 28.220
# Reward after 00677 episodes: 31.566
# Reward after 00678 episodes: 733.055
# Reward after 00679 episodes: 15.742
# Reward after 00680 episodes: 99.252
# Reward after 00681 episodes: 32.923
# Reward after 00682 episodes: 738.433
# Reward after 00683 episodes: 20.565
# Reward after 00684 episodes: 13.848
# Reward after 00685 episodes: 42.289
# Reward after 00686 episodes: 133.502
# Reward after 00687 episodes: 43.529
# Reward after 00688 episodes: 63.518
# Reward after 00689 episodes: 32.901
# Reward after 00690 episodes: 33.213
# Reward after 00691 episodes: 193.266
# Reward after 00692 episodes: -1.000
# Reward after 00693 episodes: -1.000
# Reward after 00694 episodes: 18.208
# Reward after 00695 episodes: 31.686
# Reward after 00696 episodes: 63.907
# Reward after 00697 episodes: 181.255
# Reward after 00698 episodes: 218.007
# Reward after 00699 episodes: 35.071
# Reward after 00700 episodes: 476.307
# Reward after 00701 episodes: 61.000
# Reward after 00702 episodes: 56.842
# Reward after 00703 episodes: 357.564
# Reward after 00704 episodes: 620.557
# Reward after 00705 episodes: 236.657
# Reward after 00706 episodes: 178.709
# Reward after 00707 episodes: 63.940
# Reward after 00708 episodes: 246.714
# Reward after 00709 episodes: 70.126
# Reward after 00710 episodes: 392.807
# Reward after 00711 episodes: 704.459
# Reward after 00712 episodes: 574.920
# Reward after 00713 episodes: 477.980
# Reward after 00714 episodes: 716.574
# Reward after 00715 episodes: 697.169
# Reward after 00716 episodes: 721.164
# Reward after 00717 episodes: 711.922
# Reward after 00718 episodes: 652.465
# Reward after 00719 episodes: 700.875
# Reward after 00720 episodes: 690.094
# Reward after 00721 episodes: 718.340
# Reward after 00722 episodes: 704.058
# Reward after 00723 episodes: 711.202
# Reward after 00724 episodes: 699.401
# Reward after 00725 episodes: 702.690
# Reward after 00726 episodes: 712.421
# Reward after 00727 episodes: 675.420
# Reward after 00728 episodes: 117.287
# Reward after 00729 episodes: 54.631
# Reward after 00730 episodes: 712.211
# Reward after 00731 episodes: 44.360
# Reward after 00732 episodes: 3.150
# Reward after 00733 episodes: 744.050
# Reward after 00734 episodes: 740.849
# Reward after 00735 episodes: 743.618
# Reward after 00736 episodes: 747.074
# Reward after 00737 episodes: 747.022
# Reward after 00738 episodes: 76.506
# Reward after 00739 episodes: 731.828
# Reward after 00740 episodes: 94.941
# Reward after 00741 episodes: 79.856
# Reward after 00742 episodes: 748.576
# Reward after 00743 episodes: 744.713
# Reward after 00744 episodes: 69.689
# Reward after 00745 episodes: 747.259
# Reward after 00746 episodes: 278.573
# Reward after 00747 episodes: 41.313
# Reward after 00748 episodes: 113.279
# Reward after 00749 episodes: 745.957
# Reward after 00750 episodes: 749.259
# Reward after 00751 episodes: 392.706
# Reward after 00752 episodes: 744.182
# Reward after 00753 episodes: 740.256
# Reward after 00754 episodes: 740.377
# Reward after 00755 episodes: 60.479
# Reward after 00756 episodes: 46.266
# Reward after 00757 episodes: 33.018
# Reward after 00758 episodes: 123.911
# Reward after 00759 episodes: 738.339
# Reward after 00760 episodes: 83.361
# Reward after 00761 episodes: 132.492
# Reward after 00762 episodes: 739.326
# Reward after 00763 episodes: 738.309
# Reward after 00764 episodes: 721.800
# Reward after 00765 episodes: 181.333
# Reward after 00766 episodes: 744.400
# Reward after 00767 episodes: 749.431
# Reward after 00768 episodes: 749.043
# Reward after 00769 episodes: 745.033
# Reward after 00770 episodes: 88.444
# Reward after 00771 episodes: 743.436
# Reward after 00772 episodes: 748.075
# Reward after 00773 episodes: 740.889
# Reward after 00774 episodes: 741.028
# Reward after 00775 episodes: 745.820
# Reward after 00776 episodes: 371.364
# Reward after 00777 episodes: 374.558
# Reward after 00778 episodes: 749.154
# Reward after 00779 episodes: 64.620
# Reward after 00780 episodes: 751.704
# Reward after 00781 episodes: 748.232
# Reward after 00782 episodes: 23.774
# Reward after 00783 episodes: 750.749
# Reward after 00784 episodes: 146.858
# Reward after 00785 episodes: 748.180
# Reward after 00786 episodes: 752.504
# Reward after 00787 episodes: 750.036
# Reward after 00788 episodes: 752.478
# Reward after 00789 episodes: 742.610
# Reward after 00790 episodes: 728.369
# Reward after 00791 episodes: 743.090
# Reward after 00792 episodes: 734.862
# Reward after 00793 episodes: 744.206
# Reward after 00794 episodes: 199.439
# Reward after 00795 episodes: 728.054
# Reward after 00796 episodes: 731.382
# Reward after 00797 episodes: 442.901
# Reward after 00798 episodes: 732.952
# Reward after 00799 episodes: 732.276
# Reward after 00800 episodes: 737.082
# Reward after 00801 episodes: 693.229
# Reward after 00802 episodes: 714.368
# Reward after 00803 episodes: 747.473
# Reward after 00804 episodes: 740.643
# Reward after 00805 episodes: 36.832
# Reward after 00806 episodes: 734.201
# Reward after 00807 episodes: 742.155
# Reward after 00808 episodes: 92.283
# Reward after 00809 episodes: 736.932
# Reward after 00810 episodes: 738.774
# Reward after 00811 episodes: 737.249
# Reward after 00812 episodes: 744.325
# Reward after 00813 episodes: 736.210
# Reward after 00814 episodes: 752.264
# Reward after 00815 episodes: 751.862
# Reward after 00816 episodes: 752.613
# Reward after 00817 episodes: 406.723
# Reward after 00818 episodes: 752.787
# Reward after 00819 episodes: 752.134
# Reward after 00820 episodes: 754.340
# Reward after 00821 episodes: 750.154
# Reward after 00822 episodes: 753.381
# Reward after 00823 episodes: 752.763
# Reward after 00824 episodes: 752.180
# Reward after 00825 episodes: 357.117
# Reward after 00826 episodes: 753.425
# Reward after 00827 episodes: 738.111
# Reward after 00828 episodes: 748.208
# Reward after 00829 episodes: 752.782
# Reward after 00830 episodes: 748.164
# Reward after 00831 episodes: 707.669
# Reward after 00832 episodes: 646.575
# Reward after 00833 episodes: 749.563
# Reward after 00834 episodes: 744.259
# Reward after 00835 episodes: 749.412
# Reward after 00836 episodes: 753.693
# Reward after 00837 episodes: 17.571
# Reward after 00838 episodes: 749.264
# Reward after 00839 episodes: 742.498
# Reward after 00840 episodes: 747.572
# Reward after 00841 episodes: 751.107
# Reward after 00842 episodes: 752.973
# Reward after 00843 episodes: 738.869
# Reward after 00844 episodes: 752.408
# Reward after 00845 episodes: 753.309
# Reward after 00846 episodes: 735.802
# Reward after 00847 episodes: 378.038
# Reward after 00848 episodes: 751.573
# Reward after 00849 episodes: 750.873
# Reward after 00850 episodes: 753.886
# Reward after 00851 episodes: 753.110
# Reward after 00852 episodes: 732.495
# Reward after 00853 episodes: 753.445
# Reward after 00854 episodes: 753.598
# Reward after 00855 episodes: 752.229
# Reward after 00856 episodes: 753.459
# Reward after 00857 episodes: 751.534
# Reward after 00858 episodes: 704.463
# Reward after 00859 episodes: 752.743
# Reward after 00860 episodes: 753.806
# Reward after 00861 episodes: 752.811
# Reward after 00862 episodes: 752.628
# Reward after 00863 episodes: 753.501
# Reward after 00864 episodes: 753.178
# Reward after 00865 episodes: 730.453
# Reward after 00866 episodes: 752.926
# Reward after 00867 episodes: 752.752
# Reward after 00868 episodes: 751.851
# Reward after 00869 episodes: 752.855
# Reward after 00870 episodes: 748.883
# Reward after 00871 episodes: 751.781
# Reward after 00872 episodes: 751.593
# Reward after 00873 episodes: 737.844
# Reward after 00874 episodes: 753.023
# Reward after 00875 episodes: 753.588
# Reward after 00876 episodes: 731.308
# Reward after 00877 episodes: 753.827
# Reward after 00878 episodes: 666.439
# Reward after 00879 episodes: 325.510
# Reward after 00880 episodes: 377.750
# Reward after 00881 episodes: 746.678
# Reward after 00882 episodes: 285.971
# Reward after 00883 episodes: 36.204
# Reward after 00884 episodes: 20.321
# Reward after 00885 episodes: 9.100
# Reward after 00886 episodes: 7.543
# Reward after 00887 episodes: 7.878
# Reward after 00888 episodes: 8.470
# Reward after 00889 episodes: 5.435
# Reward after 00890 episodes: 3.918
# Reward after 00891 episodes: 374.790
# Reward after 00892 episodes: 12.729
# Reward after 00893 episodes: 264.344
# Reward after 00894 episodes: 8.975
# Reward after 00895 episodes: 723.802
# Reward after 00896 episodes: 236.037
# Reward after 00897 episodes: 252.077
# Reward after 00898 episodes: 690.740
# Reward after 00899 episodes: 677.361
# Reward after 00900 episodes: 713.189
# Reward after 00901 episodes: 379.418
# Reward after 00902 episodes: 670.303
# Reward after 00903 episodes: 249.527
# Reward after 00904 episodes: 13.536
# Reward after 00905 episodes: 710.224
# Reward after 00906 episodes: 249.444
# Reward after 00907 episodes: 726.904
# Reward after 00908 episodes: 7.103
# Reward after 00909 episodes: 9.499
# Reward after 00910 episodes: 314.132
# Reward after 00911 episodes: 741.262
# Reward after 00912 episodes: 737.383
# Reward after 00913 episodes: 728.058
# Reward after 00914 episodes: 729.203
# Reward after 00915 episodes: 380.548
# Reward after 00916 episodes: 321.908
# Reward after 00917 episodes: 11.747
# Reward after 00918 episodes: 717.636
# Reward after 00919 episodes: 718.437
# Reward after 00920 episodes: 745.088
# Reward after 00921 episodes: 742.376
# Reward after 00922 episodes: 732.077
# Reward after 00923 episodes: 723.963
# Reward after 00924 episodes: 732.592
# Reward after 00925 episodes: 729.390
# Reward after 00926 episodes: 745.140
# Reward after 00927 episodes: 731.000
# Reward after 00928 episodes: 729.983
# Reward after 00929 episodes: 744.597
# Reward after 00930 episodes: 742.109
# Reward after 00931 episodes: 744.994
# Reward after 00932 episodes: 738.979
# Reward after 00933 episodes: 560.430
# Reward after 00934 episodes: 711.646
# Reward after 00935 episodes: 715.677
# Reward after 00936 episodes: 682.542
# Reward after 00937 episodes: 625.408
# Reward after 00938 episodes: 655.232
# Reward after 00939 episodes: 10.538
# Reward after 00940 episodes: 28.449
# Reward after 00941 episodes: 14.177
# Reward after 00942 episodes: 20.420
# Reward after 00943 episodes: 323.205
# Reward after 00944 episodes: 13.297
# Reward after 00945 episodes: 327.152
# Reward after 00946 episodes: 367.086
# Reward after 00947 episodes: 5.053
# Reward after 00948 episodes: 25.731
# Reward after 00949 episodes: 609.162
# Reward after 00950 episodes: 345.483
# Reward after 00951 episodes: 717.122
# Reward after 00952 episodes: 617.163
# Reward after 00953 episodes: 136.787
# Reward after 00954 episodes: 51.602
# Reward after 00955 episodes: 42.140
# Reward after 00956 episodes: 729.979
# Reward after 00957 episodes: 739.268
# Reward after 00958 episodes: 723.974
# Reward after 00959 episodes: 736.356
# Reward after 00960 episodes: 742.328
# Reward after 00961 episodes: 694.717
# Reward after 00962 episodes: 722.557
# Reward after 00963 episodes: 718.249
# Reward after 00964 episodes: 226.806
# Reward after 00965 episodes: 720.930
# Reward after 00966 episodes: 200.728
# Reward after 00967 episodes: 731.398
# Reward after 00968 episodes: 726.890
# Reward after 00969 episodes: 735.062
# Reward after 00970 episodes: 719.493
# Reward after 00971 episodes: 745.682
# Reward after 00972 episodes: 722.973
# Reward after 00973 episodes: 5.052
# Reward after 00974 episodes: 723.782
# Reward after 00975 episodes: 321.883
# Reward after 00976 episodes: 710.429
# Reward after 00977 episodes: 710.655
# Reward after 00978 episodes: 719.598
# Reward after 00979 episodes: 727.454
# Reward after 00980 episodes: 728.076
# Reward after 00981 episodes: 391.313
# Reward after 00982 episodes: 739.329
# Reward after 00983 episodes: 634.253
# Reward after 00984 episodes: 163.050
# Reward after 00985 episodes: 175.999
# Reward after 00986 episodes: 728.927
# Reward after 00987 episodes: 209.359
# Reward after 00988 episodes: 20.498
# Reward after 00989 episodes: 310.538
# Reward after 00990 episodes: 714.844
# Reward after 00991 episodes: 732.151
# Reward after 00992 episodes: 11.297
# Reward after 00993 episodes: 721.762
# Reward after 00994 episodes: 728.387
# Reward after 00995 episodes: 735.609
# Reward after 00996 episodes: 41.729
# Reward after 00997 episodes: 737.108
# Reward after 00998 episodes: 741.348
# Reward after 00999 episodes: 725.544
# Reward after 01000 episodes: 394.363
# Reward after 01001 episodes: 751.236
# Reward after 01002 episodes: 751.569
# Reward after 01003 episodes: 749.705
# Reward after 01004 episodes: 752.798
# Reward after 01005 episodes: 752.691
# Reward after 01006 episodes: 752.814
# Reward after 01007 episodes: 748.837
# Reward after 01008 episodes: 753.797
# Reward after 01009 episodes: 744.701
# Reward after 01010 episodes: 395.875
# Reward after 01011 episodes: 749.171
# Reward after 01012 episodes: 747.793
# Reward after 01013 episodes: 748.120
# Reward after 01014 episodes: 390.065
# Reward after 01015 episodes: 740.721
# Reward after 01016 episodes: 749.465
# Reward after 01017 episodes: 746.392
# Reward after 01018 episodes: 741.927
# Reward after 01019 episodes: 731.949
# Reward after 01020 episodes: 394.555
# Reward after 01021 episodes: 276.427
# Reward after 01022 episodes: 741.591
# Reward after 01023 episodes: 743.997
# Reward after 01024 episodes: 749.248
# Reward after 01025 episodes: 749.543
# Reward after 01026 episodes: 744.805
# Reward after 01027 episodes: 746.104
# Reward after 01028 episodes: 409.474
# Reward after 01029 episodes: 743.003
# Reward after 01030 episodes: 747.015
# Reward after 01031 episodes: 743.035
# Reward after 01032 episodes: 748.043
# Reward after 01033 episodes: 742.069
# Reward after 01034 episodes: 400.322
# Reward after 01035 episodes: 743.286
# Reward after 01036 episodes: 747.470
# Reward after 01037 episodes: 253.985
# Reward after 01038 episodes: 745.071
# Reward after 01039 episodes: 744.087
# Reward after 01040 episodes: 734.891
# Reward after 01041 episodes: 720.533
# Reward after 01042 episodes: 746.527
# Reward after 01043 episodes: 717.620
# Reward after 01044 episodes: 726.939
# Reward after 01045 episodes: 743.706
# Reward after 01046 episodes: 745.038
# Reward after 01047 episodes: 697.771
# Reward after 01048 episodes: 748.788
# Reward after 01049 episodes: 747.657
# Reward after 01050 episodes: 731.059
# Reward after 01051 episodes: 751.314
# Reward after 01052 episodes: 751.003
# Reward after 01053 episodes: 740.593
# Reward after 01054 episodes: 745.095
# Reward after 01055 episodes: 736.638
# Reward after 01056 episodes: 742.461
# Reward after 01057 episodes: 740.540
# Reward after 01058 episodes: 736.238
# Reward after 01059 episodes: 727.799
# Reward after 01060 episodes: 731.812
# Reward after 01061 episodes: 728.494
# Reward after 01062 episodes: 728.622
# Reward after 01063 episodes: 725.278
# Reward after 01064 episodes: 725.600
# Reward after 01065 episodes: 742.965
# Reward after 01066 episodes: 456.320
# Reward after 01067 episodes: 656.875
# Reward after 01068 episodes: 571.073
# Reward after 01069 episodes: 453.773
# Reward after 01070 episodes: 594.533
# Reward after 01071 episodes: 665.956
# Reward after 01072 episodes: 739.376
# Reward after 01073 episodes: 649.101
# Reward after 01074 episodes: 730.831
# Reward after 01075 episodes: 692.080
# Reward after 01076 episodes: 743.504
# Reward after 01077 episodes: 380.127
# Reward after 01078 episodes: 743.139
# Reward after 01079 episodes: 734.162
# Reward after 01080 episodes: 731.919
# Reward after 01081 episodes: 563.551
# Reward after 01082 episodes: 673.476
# Reward after 01083 episodes: 733.267
# Reward after 01084 episodes: 709.224
# Reward after 01085 episodes: 717.149
# Reward after 01086 episodes: 729.139
# Reward after 01087 episodes: 750.487
# Reward after 01088 episodes: 734.644
# Reward after 01089 episodes: 736.030
# Reward after 01090 episodes: 703.181
# Reward after 01091 episodes: 741.672
# Reward after 01092 episodes: 743.794
# Reward after 01093 episodes: 737.705
# Reward after 01094 episodes: 738.353
# Reward after 01095 episodes: 741.227
# Reward after 01096 episodes: 736.428
# Reward after 01097 episodes: 734.451
# Reward after 01098 episodes: 736.678
# Reward after 01099 episodes: 745.656
# Reward after 01100 episodes: 386.111
# Reward after 01101 episodes: 742.760
# Reward after 01102 episodes: 717.272
# Reward after 01103 episodes: 673.562
# Reward after 01104 episodes: 704.061
# Reward after 01105 episodes: 741.011
# Reward after 01106 episodes: 742.771
# Reward after 01107 episodes: 725.433
# Reward after 01108 episodes: 740.462
# Reward after 01109 episodes: 737.173
# Reward after 01110 episodes: 736.249
# Reward after 01111 episodes: 136.688
# Reward after 01112 episodes: 312.824
# Reward after 01113 episodes: 327.392
# Reward after 01114 episodes: 738.328
# Reward after 01115 episodes: 750.833
# Reward after 01116 episodes: 743.941
# Reward after 01117 episodes: 720.953
# Reward after 01118 episodes: 675.404
# Reward after 01119 episodes: 302.203
# Reward after 01120 episodes: 692.519
# Reward after 01121 episodes: 360.067
# Reward after 01122 episodes: 737.703
# Reward after 01123 episodes: 740.055
# Reward after 01124 episodes: 748.139
# Reward after 01125 episodes: 355.868
# Reward after 01126 episodes: 413.724
# Reward after 01127 episodes: 734.296
# Reward after 01128 episodes: 730.675
# Reward after 01129 episodes: 742.345
# Reward after 01130 episodes: 729.390
# Reward after 01131 episodes: 332.693
# Reward after 01132 episodes: 730.511
# Reward after 01133 episodes: 184.306
# Reward after 01134 episodes: 731.381
# Reward after 01135 episodes: 729.022
# Reward after 01136 episodes: 721.452
# Reward after 01137 episodes: 77.773
# Reward after 01138 episodes: 366.735
# Reward after 01139 episodes: 747.634
# Reward after 01140 episodes: 703.434
# Reward after 01141 episodes: 55.147
# Reward after 01142 episodes: 732.049
# Reward after 01143 episodes: 741.483
# Reward after 01144 episodes: 388.001
# Reward after 01145 episodes: 56.952
# Reward after 01146 episodes: 48.258
# Reward after 01147 episodes: 739.036
# Reward after 01148 episodes: 729.529
# Reward after 01149 episodes: 662.399
# Reward after 01150 episodes: 125.158
# Reward after 01151 episodes: 742.517
# Reward after 01152 episodes: 731.673
# Reward after 01153 episodes: 722.628
# Reward after 01154 episodes: 742.470
# Reward after 01155 episodes: 730.358
# Reward after 01156 episodes: 751.677
# Reward after 01157 episodes: 719.589
# Reward after 01158 episodes: 749.302
# Reward after 01159 episodes: 718.110
# Reward after 01160 episodes: 724.326
# Reward after 01161 episodes: 732.941
# Reward after 01162 episodes: 744.898
# Reward after 01163 episodes: 731.309
# Reward after 01164 episodes: 740.848
# Reward after 01165 episodes: 721.161
# Reward after 01166 episodes: 721.599
# Reward after 01167 episodes: 712.421
# Reward after 01168 episodes: 127.735
# Reward after 01169 episodes: 675.638
# Reward after 01170 episodes: 723.803
# Reward after 01171 episodes: 718.192
# Reward after 01172 episodes: 724.304
# Reward after 01173 episodes: 723.774
# Reward after 01174 episodes: 750.788
# Reward after 01175 episodes: 735.538
# Reward after 01176 episodes: 720.927
# Reward after 01177 episodes: 735.536
# Reward after 01178 episodes: 750.836
# Reward after 01179 episodes: 739.445
# Reward after 01180 episodes: 722.605
# Reward after 01181 episodes: 177.553
# Reward after 01182 episodes: 111.377
# Reward after 01183 episodes: 735.554
# Reward after 01184 episodes: 99.465
# Reward after 01185 episodes: 725.439
# Reward after 01186 episodes: 720.483
# Reward after 01187 episodes: 710.766
# Reward after 01188 episodes: 721.420
# Reward after 01189 episodes: 720.377
# Reward after 01190 episodes: 725.089
# Reward after 01191 episodes: 722.019
# Reward after 01192 episodes: 117.287
# Reward after 01193 episodes: 156.104
# Reward after 01194 episodes: 713.248
# Reward after 01195 episodes: 702.557
# Reward after 01196 episodes: 698.478
# Reward after 01197 episodes: 731.207
# Reward after 01198 episodes: 692.627
# Reward after 01199 episodes: 714.447
# Reward after 01200 episodes: 709.088
# Reward after 01201 episodes: 743.481
# Reward after 01202 episodes: 731.289
# Reward after 01203 episodes: 734.522
# Reward after 01204 episodes: 730.756
# Reward after 01205 episodes: 720.570
# Reward after 01206 episodes: 716.982
# Reward after 01207 episodes: 733.157
# Reward after 01208 episodes: 714.176
# Reward after 01209 episodes: 717.562
# Reward after 01210 episodes: 718.055
# Reward after 01211 episodes: 733.179
# Reward after 01212 episodes: 699.361
# Reward after 01213 episodes: 703.345
# Reward after 01214 episodes: 109.399
# Reward after 01215 episodes: 724.846
# Reward after 01216 episodes: 727.645
# Reward after 01217 episodes: 724.365
# Reward after 01218 episodes: 9.877
# Reward after 01219 episodes: 667.524
# Reward after 01220 episodes: 742.861
# Reward after 01221 episodes: 722.680
# Reward after 01222 episodes: 738.679
# Reward after 01223 episodes: 723.747
# Reward after 01224 episodes: 726.659
# Reward after 01225 episodes: 24.775
# Reward after 01226 episodes: 722.301
# Reward after 01227 episodes: 731.036
# Reward after 01228 episodes: 722.636
# Reward after 01229 episodes: 741.027
# Reward after 01230 episodes: 729.964
# Reward after 01231 episodes: 726.931
# Reward after 01232 episodes: 748.911
# Reward after 01233 episodes: 723.230
# Reward after 01234 episodes: 744.321
# Reward after 01235 episodes: 731.349
# Reward after 01236 episodes: 719.189
# Reward after 01237 episodes: 714.334
# Reward after 01238 episodes: 720.188
# Reward after 01239 episodes: 720.137
# Reward after 01240 episodes: 715.952
# Reward after 01241 episodes: 720.141
# Reward after 01242 episodes: 742.815
# Reward after 01243 episodes: 710.898
# Reward after 01244 episodes: 731.805
# Reward after 01245 episodes: 725.583
# Reward after 01246 episodes: 718.999
# Reward after 01247 episodes: 709.776
# Reward after 01248 episodes: 714.425
# Reward after 01249 episodes: 724.987
# Reward after 01250 episodes: 208.715
# Reward after 01251 episodes: 703.376
# Reward after 01252 episodes: 709.724
# Reward after 01253 episodes: 167.121
# Reward after 01254 episodes: 741.848
# Reward after 01255 episodes: 720.569
# Reward after 01256 episodes: 731.217
# Reward after 01257 episodes: 715.637
# Reward after 01258 episodes: 725.691
# Reward after 01259 episodes: 719.133
# Reward after 01260 episodes: 734.408
# Reward after 01261 episodes: 719.675
# Reward after 01262 episodes: 132.421
# Reward after 01263 episodes: 733.890
# Reward after 01264 episodes: 715.888
# Reward after 01265 episodes: 689.487
# Reward after 01266 episodes: 707.558
# Reward after 01267 episodes: 714.235
# ...
# Reward after 03001 episodes: 292.906
# Reward after 03002 episodes: 750.266
# Reward after 03003 episodes: 732.981
# Reward after 03004 episodes: 718.045
# Reward after 03005 episodes: 210.874
# Reward after 03006 episodes: 222.007
# Reward after 03007 episodes: 147.801
# Reward after 03008 episodes: 163.382
# Reward after 03009 episodes: 126.681
# Reward after 03010 episodes: 743.544
# Reward after 03011 episodes: 123.295
# Reward after 03012 episodes: 37.727
# Reward after 03013 episodes: 754.985
# Reward after 03014 episodes: 743.207
# Reward after 03015 episodes: 741.236
# Reward after 03016 episodes: 115.337
# Reward after 03017 episodes: 744.910
# Reward after 03018 episodes: 739.350
# Reward after 03019 episodes: 123.886
# Reward after 03020 episodes: 742.811
# Reward after 03021 episodes: 747.355
# Reward after 03022 episodes: 170.442
# Reward after 03023 episodes: 747.041
# Reward after 03024 episodes: 740.044
# Reward after 03025 episodes: 750.929
# Reward after 03026 episodes: 743.153
# Reward after 03027 episodes: 747.727
# Reward after 03028 episodes: 748.929
# Reward after 03029 episodes: 750.145
# Reward after 03030 episodes: 746.187
# Reward after 03031 episodes: 739.028
# Reward after 03032 episodes: 748.431
# Reward after 03033 episodes: 740.556
# Reward after 03034 episodes: 751.850
# Reward after 03035 episodes: 741.131
# Reward after 03036 episodes: 748.669
# Reward after 03037 episodes: 749.091
# Reward after 03038 episodes: 746.768
# Reward after 03039 episodes: 213.153
# Reward after 03040 episodes: 164.630
# Reward after 03041 episodes: 137.654
# Reward after 03042 episodes: 149.872
# Reward after 03043 episodes: 751.328
# Reward after 03044 episodes: 738.455
# Reward after 03045 episodes: 124.418
# Reward after 03046 episodes: 144.107
# Reward after 03047 episodes: 273.515
# Reward after 03048 episodes: 141.894
# Reward after 03049 episodes: 747.096
# Reward after 03050 episodes: 214.038
# Reward after 03051 episodes: 181.148
# Reward after 03052 episodes: 183.919
# Reward after 03053 episodes: 413.286
# Reward after 03054 episodes: 753.784
# Reward after 03055 episodes: 752.911
# Reward after 03056 episodes: 752.403
# Reward after 03057 episodes: 752.229
# Reward after 03058 episodes: 750.876
# Reward after 03059 episodes: 750.726
# Reward after 03060 episodes: 752.446
# Reward after 03061 episodes: 753.001
# Reward after 03062 episodes: 752.394
# Reward after 03063 episodes: 753.695
# Reward after 03064 episodes: 751.936
# Reward after 03065 episodes: 753.818
# Reward after 03066 episodes: 419.356
# Reward after 03067 episodes: 44.884
# Reward after 03068 episodes: 409.890
# Reward after 03069 episodes: 55.797
# Reward after 03070 episodes: 404.863
# Reward after 03071 episodes: 752.828
# Reward after 03072 episodes: 751.910
# Reward after 03073 episodes: 752.807
# Reward after 03074 episodes: 752.279
# Reward after 03075 episodes: 754.048
# Reward after 03076 episodes: 752.332
# Reward after 03077 episodes: 751.825
# Reward after 03078 episodes: 750.729
# Reward after 03079 episodes: 753.190
# Reward after 03080 episodes: 751.650
# Reward after 03081 episodes: 751.678
# Reward after 03082 episodes: 753.171
# Reward after 03083 episodes: 753.759
# Reward after 03084 episodes: 752.313
# Reward after 03085 episodes: 751.546
# Reward after 03086 episodes: 752.135
# Reward after 03087 episodes: 752.891
# Reward after 03088 episodes: 749.598
# Reward after 03089 episodes: 749.742
# Reward after 03090 episodes: 752.802
# Reward after 03091 episodes: 749.313
# Reward after 03092 episodes: 751.284
# Reward after 03093 episodes: 751.150
# Reward after 03094 episodes: 750.985
# Reward after 03095 episodes: 750.771
# Reward after 03096 episodes: 752.812
# Reward after 03097 episodes: 749.775
# Reward after 03098 episodes: 402.178
# Reward after 03099 episodes: 752.842
# Reward after 03100 episodes: 271.502
# Reward after 03101 episodes: 750.366
# Reward after 03102 episodes: 746.617
# Reward after 03103 episodes: 750.255
# Reward after 03104 episodes: 749.619
# Reward after 03105 episodes: 753.158
# Reward after 03106 episodes: 751.592
# Reward after 03107 episodes: 751.558
# Reward after 03108 episodes: 749.649
# Reward after 03109 episodes: 751.386
# Reward after 03110 episodes: 751.743
# Reward after 03111 episodes: 751.167
# Reward after 03112 episodes: 750.839
# Reward after 03113 episodes: 749.311
# Reward after 03114 episodes: 750.797
# Reward after 03115 episodes: 752.246
# Reward after 03116 episodes: 752.316
# Reward after 03117 episodes: 751.578
# Reward after 03118 episodes: 751.506
# Reward after 03119 episodes: 750.266
# Reward after 03120 episodes: 750.997
# Reward after 03121 episodes: 750.502
# Reward after 03122 episodes: 749.321
# Reward after 03123 episodes: 751.462
# Reward after 03124 episodes: 750.077
# Reward after 03125 episodes: 751.408
# Reward after 03126 episodes: 751.696
# Reward after 03127 episodes: 751.473
# Reward after 03128 episodes: 750.838
# Reward after 03129 episodes: 750.656
# Reward after 03130 episodes: 749.900
# Reward after 03131 episodes: 749.142
# Reward after 03132 episodes: 749.471
# Reward after 03133 episodes: 752.852
# Reward after 03134 episodes: 752.551
# Reward after 03135 episodes: 750.717
# Reward after 03136 episodes: 752.573
# Reward after 03137 episodes: 751.203
# Reward after 03138 episodes: 750.112
# Reward after 03139 episodes: 750.202
# Reward after 03140 episodes: 750.768
# Reward after 03141 episodes: 750.515
# Reward after 03142 episodes: 753.558
# Reward after 03143 episodes: 751.968
# Reward after 03144 episodes: 753.023
# Reward after 03145 episodes: 749.704
# Reward after 03146 episodes: 751.907
# Reward after 03147 episodes: 752.723
# Reward after 03148 episodes: 749.728
# Reward after 03149 episodes: 750.188
# Reward after 03150 episodes: 751.146
# Reward after 03151 episodes: 751.071
# Reward after 03152 episodes: 749.323
# Reward after 03153 episodes: 749.687
# Reward after 03154 episodes: 749.877
# Reward after 03155 episodes: 752.914
# Reward after 03156 episodes: 747.019
# Reward after 03157 episodes: 749.869
# Reward after 03158 episodes: 750.096
# Reward after 03159 episodes: 750.454
# Reward after 03160 episodes: 747.546
# Reward after 03161 episodes: 749.315
# Reward after 03162 episodes: 749.916
# Reward after 03163 episodes: 750.743
# Reward after 03164 episodes: 748.613
# Reward after 03165 episodes: 749.455
# Reward after 03166 episodes: 751.244
# Reward after 03167 episodes: 750.242
# Reward after 03168 episodes: 751.183
# Reward after 03169 episodes: 751.750
# Reward after 03170 episodes: 750.075
# Reward after 03171 episodes: 750.882
# Reward after 03172 episodes: 751.868
# Reward after 03173 episodes: 750.892
# Reward after 03174 episodes: 751.273
# Reward after 03175 episodes: 745.632
# Reward after 03176 episodes: 752.169
# Reward after 03177 episodes: 748.501
# Reward after 03178 episodes: 749.795
# Reward after 03179 episodes: 748.392
# Reward after 03180 episodes: 752.514
# Reward after 03181 episodes: 750.983
# Reward after 03182 episodes: 751.178
# Reward after 03183 episodes: 750.600
# Reward after 03184 episodes: 750.942
# Reward after 03185 episodes: 752.270
# Reward after 03186 episodes: 752.032
# Reward after 03187 episodes: 751.317
# Reward after 03188 episodes: 751.742
# Reward after 03189 episodes: 751.417
# Reward after 03190 episodes: 752.032
# Reward after 03191 episodes: 750.983
# Reward after 03192 episodes: 751.356
# Reward after 03193 episodes: 749.048
# Reward after 03194 episodes: 750.837
# Reward after 03195 episodes: 748.898
# Reward after 03196 episodes: 751.594
# Reward after 03197 episodes: 751.778
# Reward after 03198 episodes: 750.088
# Reward after 03199 episodes: 751.950
# Reward after 03200 episodes: 749.712
# Reward after 03201 episodes: 753.264
# Reward after 03202 episodes: 753.469
# Reward after 03203 episodes: 752.036
# Reward after 03204 episodes: 752.606
# Reward after 03205 episodes: 753.018
# Reward after 03206 episodes: 752.209
# Reward after 03207 episodes: 752.461
# Reward after 03208 episodes: 751.833
# Reward after 03209 episodes: 752.266
# Reward after 03210 episodes: 751.189
# Reward after 03211 episodes: 752.576
# Reward after 03212 episodes: 750.292
# Reward after 03213 episodes: 747.198
# Reward after 03214 episodes: 752.326
# Reward after 03215 episodes: 751.042
# Reward after 03216 episodes: 751.652
# Reward after 03217 episodes: 752.853
# Reward after 03218 episodes: 749.909
# Reward after 03219 episodes: 751.087
# Reward after 03220 episodes: 749.468
# Reward after 03221 episodes: 751.876
# Reward after 03222 episodes: 752.864
# Reward after 03223 episodes: 748.815
# Reward after 03224 episodes: 750.173
# Reward after 03225 episodes: 752.615
# Reward after 03226 episodes: 753.760
# Reward after 03227 episodes: 752.071
# Reward after 03228 episodes: 750.941
# Reward after 03229 episodes: 752.510
# Reward after 03230 episodes: 754.011
# Reward after 03231 episodes: 752.703
# Reward after 03232 episodes: 752.839
# Reward after 03233 episodes: 753.605
# Reward after 03234 episodes: 752.775
# Reward after 03235 episodes: 753.822
# Reward after 03236 episodes: 754.561
# Reward after 03237 episodes: 754.278
# Reward after 03238 episodes: 753.563
# Reward after 03239 episodes: 750.115
# Reward after 03240 episodes: 752.952
# Reward after 03241 episodes: 751.876
# Reward after 03242 episodes: 751.277
# Reward after 03243 episodes: 752.912
# Reward after 03244 episodes: 752.578
# Reward after 03245 episodes: 749.928
# Reward after 03246 episodes: 749.720
# Reward after 03247 episodes: 213.263
# Reward after 03248 episodes: 752.221
# Reward after 03249 episodes: 32.006
# Reward after 03250 episodes: 749.200
# Reward after 03251 episodes: 121.128
# Reward after 03252 episodes: 751.023
# Reward after 03253 episodes: 753.063
# Reward after 03254 episodes: 285.967
# Reward after 03255 episodes: 730.652
# Reward after 03256 episodes: 706.285
# Reward after 03257 episodes: 725.635
# Reward after 03258 episodes: 40.657
# Reward after 03259 episodes: 137.893
# Reward after 03260 episodes: 703.437
# Reward after 03261 episodes: 712.144
# Reward after 03262 episodes: 32.247
# Reward after 03263 episodes: 751.777
# Reward after 03264 episodes: 749.396
# Reward after 03265 episodes: 403.515
# Reward after 03266 episodes: 750.017
# Reward after 03267 episodes: 753.353
# Reward after 03268 episodes: 753.501
# Reward after 03269 episodes: 752.145
# Reward after 03270 episodes: 751.896
# Reward after 03271 episodes: 425.954
# Reward after 03272 episodes: 751.798
# Reward after 03273 episodes: 752.370
# Reward after 03274 episodes: 752.193
# Reward after 03275 episodes: 753.159
# Reward after 03276 episodes: 753.217
# Reward after 03277 episodes: 750.999
# Reward after 03278 episodes: 751.620
# Reward after 03279 episodes: 750.012
# Reward after 03280 episodes: 753.079
# Reward after 03281 episodes: 753.424
# Reward after 03282 episodes: 753.026
# Reward after 03283 episodes: 751.494
# Reward after 03284 episodes: 752.132
# Reward after 03285 episodes: 752.173
# Reward after 03286 episodes: 751.646
# Reward after 03287 episodes: 752.474
# Reward after 03288 episodes: 749.156
# Reward after 03289 episodes: 751.574
# Reward after 03290 episodes: 408.793
# Reward after 03291 episodes: 689.247
# Reward after 03292 episodes: 753.187
# Reward after 03293 episodes: 751.472
# Reward after 03294 episodes: 749.384
# Reward after 03295 episodes: 750.532
# Reward after 03296 episodes: 753.776
# Reward after 03297 episodes: 749.092
# Reward after 03298 episodes: 742.383
# Reward after 03299 episodes: 748.676
# Reward after 03300 episodes: 748.964
# Reward after 03301 episodes: 750.423
# Reward after 03302 episodes: 751.388
# Reward after 03303 episodes: 751.455
# Reward after 03304 episodes: 748.210
# Reward after 03305 episodes: 749.464
# Reward after 03306 episodes: 749.101
# Reward after 03307 episodes: 726.471
# Reward after 03308 episodes: 749.490
# Reward after 03309 episodes: 747.708
# Reward after 03310 episodes: 749.767
# Reward after 03311 episodes: 748.088
# Reward after 03312 episodes: 733.328
# Reward after 03313 episodes: 718.436
# Reward after 03314 episodes: 737.607
# Reward after 03315 episodes: 746.600
# Reward after 03316 episodes: 718.848
# Reward after 03317 episodes: 748.696
# Reward after 03318 episodes: 752.653
# Reward after 03319 episodes: 750.777
# Reward after 03320 episodes: 752.001
# Reward after 03321 episodes: 750.853
# Reward after 03322 episodes: 749.792
# Reward after 03323 episodes: 749.711
# Reward after 03324 episodes: 751.827
# Reward after 03325 episodes: 724.996
# Reward after 03326 episodes: 746.303
# Reward after 03327 episodes: 710.783
# Reward after 03328 episodes: 706.657
# Reward after 03329 episodes: 745.953
# Reward after 03330 episodes: 741.536
# Reward after 03331 episodes: 745.676
# Reward after 03332 episodes: 662.033
# Reward after 03333 episodes: 728.305
# Reward after 03334 episodes: 748.158
# Reward after 03335 episodes: 745.395
# Reward after 03336 episodes: 742.204
# Reward after 03337 episodes: 740.155
# Reward after 03338 episodes: 748.460
# Reward after 03339 episodes: 750.839
# Reward after 03340 episodes: 743.096
# Reward after 03341 episodes: 734.379
# Reward after 03342 episodes: 732.351
# Reward after 03343 episodes: 749.533
# Reward after 03344 episodes: 724.418
# Reward after 03345 episodes: 714.178
# Reward after 03346 episodes: 745.267
# Reward after 03347 episodes: 723.582
# Reward after 03348 episodes: 174.034
# Reward after 03349 episodes: 742.738
# Reward after 03350 episodes: 54.965
# Reward after 03351 episodes: 387.138
# Reward after 03352 episodes: 746.863
# Reward after 03353 episodes: 399.935
# Reward after 03354 episodes: 51.270
# Reward after 03355 episodes: 744.838
# Reward after 03356 episodes: 578.699
# Reward after 03357 episodes: 748.757
# Reward after 03358 episodes: 750.198
# Reward after 03359 episodes: 749.560
# Reward after 03360 episodes: 746.859
# Reward after 03361 episodes: 739.886
# Reward after 03362 episodes: 748.303
# Reward after 03363 episodes: 750.843
# Reward after 03364 episodes: 717.224
# Reward after 03365 episodes: 242.035
# Reward after 03366 episodes: 735.599
# Reward after 03367 episodes: 747.044
# Reward after 03368 episodes: 744.078
# Reward after 03369 episodes: 264.753
# Reward after 03370 episodes: 744.612
# Reward after 03371 episodes: 225.248
# Reward after 03372 episodes: 175.401
# Reward after 03373 episodes: 239.212
# Reward after 03374 episodes: 195.912
# Reward after 03375 episodes: 219.824
# Reward after 03376 episodes: 199.760
# Reward after 03377 episodes: 192.097
# Reward after 03378 episodes: 233.213
# Reward after 03379 episodes: 215.953
# Reward after 03380 episodes: 51.794
# Reward after 03381 episodes: 745.024
# Reward after 03382 episodes: 727.612
# Reward after 03383 episodes: 739.138
# Reward after 03384 episodes: 730.346
# Reward after 03385 episodes: 729.610
# Reward after 03386 episodes: 736.077
# Reward after 03387 episodes: 275.009
# Reward after 03388 episodes: 741.488
# Reward after 03389 episodes: 387.753
# Reward after 03390 episodes: 741.433
# Reward after 03391 episodes: 746.055
# Reward after 03392 episodes: 746.615
# Reward after 03393 episodes: 325.323
# Reward after 03394 episodes: 239.849
# Reward after 03395 episodes: 390.921
# Reward after 03396 episodes: 199.960
# Reward after 03397 episodes: 227.907
# Reward after 03398 episodes: 210.546
# Reward after 03399 episodes: 738.049
# Reward after 03400 episodes: 221.615
# Reward after 03401 episodes: 366.421
# Reward after 03402 episodes: 724.591
# Reward after 03403 episodes: 735.876
# Reward after 03404 episodes: 740.063
# Reward after 03405 episodes: 740.073
# Reward after 03406 episodes: 738.178
# Reward after 03407 episodes: 729.409
# Reward after 03408 episodes: 747.291
# Reward after 03409 episodes: 744.462
# Reward after 03410 episodes: 743.767
# Reward after 03411 episodes: 743.830
# Reward after 03412 episodes: 741.922
# Reward after 03413 episodes: 738.123
# Reward after 03414 episodes: 742.248
# Reward after 03415 episodes: 746.324
# Reward after 03416 episodes: 741.241
# Reward after 03417 episodes: 736.452
# Reward after 03418 episodes: 740.756
# Reward after 03419 episodes: 745.983
# Reward after 03420 episodes: 130.095
# Reward after 03421 episodes: 388.781
# Reward after 03422 episodes: 118.901
# Reward after 03423 episodes: 744.070
# Reward after 03424 episodes: 178.798
# Reward after 03425 episodes: 155.475
# Reward after 03426 episodes: 749.289
# Reward after 03427 episodes: 137.341
# Reward after 03428 episodes: 117.641
# Reward after 03429 episodes: 746.883
# Reward after 03430 episodes: 65.690
# Reward after 03431 episodes: 747.064
# Reward after 03432 episodes: 112.324

# %% [markdown]
# # 🧹 Test Hyperparameters with Sweeps

# %% [markdown]
# ## [Check out Hyperparameter Optimization in PyTorch using W&B Sweep $\rightarrow$](https://colab.research.google.com/drive/1QTIK23LBuAkdejbrvdP5hwBGyYlyEJpT?usp=sharing)
#
# Running a hyperparameter sweep with Weights & Biases is very easy. There are just 3 simple steps:
#
# 1. **Define the sweep:** We do this by creating a dictionary or a [YAML file](https://docs.wandb.com/library/sweeps/configuration) that specifies the parameters to search through, the search strategy, the optimization metric et all.
#
# 2. **Initialize the sweep:**
# `sweep_id = wandb.sweep(sweep_config)`
#
# 3. **Run the sweep agent:**
# `wandb.agent(sweep_id, function=train)`
#
# And voila! That's all there is to running a hyperparameter sweep!
# <img src="https://imgur.com/UiQKg0L.png" alt="Weights & Biases" />

# %% [markdown]
# # 🤓 Advanced Setup
# 1. [Environment variables](https://docs.wandb.com/library/environment-variables): Set API keys in environment variables so you can run training on a managed cluster.
# 2. [Offline mode](https://docs.wandb.com/library/technical-faq#can-i-run-wandb-offline): Use `dryrun` mode to train offline and sync results later.
# 3. [On-prem](https://docs.wandb.com/self-hosted): Install W&B in a private cloud or air-gapped servers in your own infrastructure. We have local installations for everyone from academics to enterprise teams.
# 4. [Sweeps](https://docs.wandb.com/sweeps): Set up hyperparameter search quickly with our lightweight tool for tuning.

# %%
# for n in range(NUM_TRAINING_STEPS):
#   new_exp,_ = Trainer.generate_trajectories(env, qnet, NUM_NEW_EXP, epsilon=0.1)
#   random.shuffle(experiences)
#   if len(experiences) > BUFFER_SIZE:
#     experiences = experiences[:BUFFER_SIZE]
#   experiences.extend(new_exp)
#   Trainer.update_q_net(qnet, optim, experiences, 3)
#   _, rewards = Trainer.generate_trajectories(env, qnet, 100, epsilon=0)
#   cumulative_rewards.append(rewards)
#   print("Training step ", n+1, "\treward ", rewards)
#   print()


# env.close()

# # Show the training graph
# plt.plot(range(NUM_TRAINING_STEPS), cumulative_rewards)

# %%
#  class UnityEnv(gym.Env):
#     """
#     Provides Gym wrapper for Unity Learning Environments.
#     Multi-agent environments use lists for object types, as done here:
#     https://github.com/openai/multiagent-particle-envs
#     """
 
#     def __init__(
#         self,
#         environment_filename: str,
#         dimensions: int = [],   #Added
#         timescale: int = 1,     #Added
#         worker_id: int = 0,
#         use_visual: bool = False,
#         uint8_visual: bool = False,
#         multiagent: bool = False,
#         flatten_branched: bool = False,
#         no_graphics: bool = False,
#         allow_multiple_visual_obs: bool = False,
#         set_config: bool = True,    #Added
#     ):
#         """
#         Environment initialization
#         :param environment_filename: The UnityEnvironment path or file to be wrapped in the gym.
#         :param worker_id: Worker number for environment.
#         :param use_visual: Whether to use visual observation or vector observation.
#         :param uint8_visual: Return visual observations as uint8 (0-255) matrices instead of float (0.0-1.0).
#         :param multiagent: Whether to run in multi-agent mode (lists of obs, reward, done).
#         :param flatten_branched: If True, turn branched discrete action spaces into a Discrete space rather than
#             MultiDiscrete.
#         :param no_graphics: Whether to run the Unity simulator in no-graphics mode
#         :param allow_multiple_visual_obs: If True, return a list of visual observations instead of only one.
#         """
#         base_port = 5005
#         if environment_filename is None:
#             base_port = UnityEnvironment.DEFAULT_EDITOR_PORT
 
#         channel = EngineConfigurationChannel()        # Added
 
 
#         #Added
#         if set_config == True:
#             channel.set_configuration_parameters(time_scale=timescale, width=dimensions[0], height=dimensions[1])
#         #Added
 
#         self._env = UnityEnvironment(
#             environment_filename,
#             worker_id,
#             base_port=base_port,
#             no_graphics=no_graphics,
#             side_channels=[channel],        # Added
#         )
